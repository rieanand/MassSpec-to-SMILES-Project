# %% [markdown]
# # Spectrum to SMILES Pair Encoding (SPE) Vector Translation

# %% [markdown]
# This notebook uses SmilesPE in order to tokenize and later vectorize the SMILES. This process was explored due to SMILES strings generation leading to complications with highly overfitting to carbons and oxygen atoms. While traditional character-level tokenization of SMILES tends to overemphasize common atomic elements, SmilesPE's approach treats chemical substructures as meaningful tokens, providing a more chemically-aware representation.
#
# This notebook explores molecule classification by converting mass spectrometry data into learned molecular embeddings that can be used for similarity searching and compound identification. The approach uses a deep learning architecture combining CNNs and Bidirectional LSTMs to create a bridge between spectral data and molecular representa

# %% [markdown]
# ### SMILES tokenization and vectorization

# %% [markdown]
# This code block is largely inspired by the example notebooks SPEC2Vec.ipynb and train_SPE.ipynb in the SmilesPE GitHub (https://github.com/XinhaoLi74/SmilesPE/tree/master)

# %%
import os
import codecs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Dropout, Reshape, LSTM, Bidirectional
)
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

from SmilesPE.learner import learn_SPE
from SmilesPE.spe2vec import SPE2Vec
from SmilesPE.tokenizer import SPE_Tokenizer
from gensim.models import Word2Vec

# %%
# load data
file_name = "dataset/gc_deepsmiles.csv"
df = pd.read_csv(file_name)

df.head()
# Out:
#                           SMILES                       DeepSMILES  \
# 0                     OCc1ccccc1                        OCcccccc6
# 1           CCCCCCCCC=CCCCCCCCCO             CCCCCCCCC=CCCCCCCCCO
# 2  Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1  CccccS=O)=O)NCCCCCC6))))))))cc6
# 3          Cc1ccc(S(N)(=O)=O)cc1               CccccSN)=O)=O))cc6
# 4          CCNS(=O)(=O)c1ccccc1C               CCNS=O)=O)cccccc6C
#
#                                             Spectrum
# 0  49:2.9 50:20 51:50.5 52:10.1 53:8.3 54:2.1 60:...
# 1  45:3.9 51:1.4 53:13.7 54:99.99 55:55.2 56:72.8...
# 2  43:5.7 44:2.7 51:3.8 53:1.9 54:6.5 55:6 62:4.1...
# 3  50:3.6 51:6.6 52:2.4 53:1.9 61:3 62:9.6 63:2.6...
# 4  44:48.8 45:1.6 50:3.3 51:6.7 52:2.2 53:1.7 57:...

# %%
# extra the smiles and spectrum column
SMILES = df['SMILES'].tolist()
Spectra = df['Spectrum'].tolist()
print('Number of SMILES:', len(SMILES))

# training
output_file = "dataset/SPE_gc_deepsmiles_filtered.txt"
output = codecs.open(output_file, 'w')

# learn spe
learn_SPE(SMILES, output, 10000, min_frequency=500, augmentation=0, verbose=True, total_symbols=True)
output.close()
print(f"SPE vocabulary saved to {output_file}")

# train the Word2Vec model
spe_vob = codecs.open(output_file, 'r')
spe_tokenizer = SPE_Tokenizer(spe_vob)
tokenized_smiles = [spe_tokenizer.tokenize(smi) for smi in SMILES]

# train Word2Vec model
word2vec_model = Word2Vec(sentences=tokenized_smiles, vector_size=100, window=5, min_count=1, workers=4)
word2vec_model_path = "spe_model.bin"
word2vec_model.save(word2vec_model_path)
print(f"Word2Vec model saved to {word2vec_model_path}")

# update SPE2Vec class to use Gensim 4.0.0 attributes
class SPE2VecUpdated(SPE2Vec):
    def __init__(self, model_path, tokenizer):
        self.model = Word2Vec.load(model_path)
        self.tokenizer = tokenizer
        self.token_keys = set(self.model.wv.key_to_index.keys())

# load the trained SPE model
spe2vec_model = SPE2VecUpdated(word2vec_model_path, spe_tokenizer)

# load csv
file_name = "dataset/gc_deepsmiles.csv"
df = pd.read_csv(file_name)

# extract the SMILES and Spectrum columns
SMILES = df['SMILES'].tolist()
Spectra = df['Spectrum'].tolist()

# tokenize and generate vectors for the SMILES strings
smiles_vectors = []
valid_smiles = []
valid_spectra = []
for smi, spectrum in zip(SMILES, Spectra):
    smivec = spe2vec_model.smiles2vec(smi, mode='average')  # You can choose other modes like 'sum', 'avg_pool', 'sum_pool'
    if smivec.shape == (100,):  # Ensure the vector has the correct shape
        smiles_vectors.append(smivec)
        valid_smiles.append(smi)
        valid_spectra.append(spectrum)
    else:
        print(f"Invalid vector shape for SMILES: {smi}, Vector shape: {smivec.shape}")

smiles_vectors_df = pd.DataFrame(smiles_vectors, index=valid_smiles)
smiles_vectors_df['Spectrum'] = valid_spectra

print(smiles_vectors_df.head())

# saving the vectors to a new CSV file
output_file = "dataset/gc_vector.csv"
smiles_vectors_df.to_csv(output_file)

smiles_vectors_df.head()
# Out:
# Number of SMILES: 18772
# Counting SMILES...
# 9088 unique Canonical SMILES
# Gettting Pair Statistics
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='9088' class='' max='9088' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [9088/9088 00:00&lt;00:00]
#     </div>
# Number of unique characters & Reducing number of merge operations by: 66
# Unique characters: {'[I-]', '6', 'P', '[Sn+]', '[c]', '#', 'B', '[O-]', 'F', '[CH3]', 's', '[CH2-]', 'O', '[Co+2]', '2', '[Sn+2]', '[Cl-]', '[CH]', '[Pd+2]', 'c', '[SiH3]', '[PH]', '[Na+]', '[Ni+2]', 'N', '.', '[CH2]', '[CH2+]', '1', 'C', 'n', '[Co+3]', '(', '3', '[F-]', '[Sn]', '[H]', '[SiH]', 'o', '[Zn+2]', '[C-]', '-', '[Se]', '[Si]', 'S', '[nH]', 'Cl', '=', '[Pt+2]', '[S+]', '[S-]', '7', '[Br-]', '[N+]', 'I', '[SiH2]', '[N-]', 'Br', '[Cu+2]', ')', '5', '[Hg]', '[Ge]', '[n+]', '[Al+3]', '4'}
# pair 0: C C -> CC (frequency 58134)
# pair 1: c c -> cc (frequency 34101)
# pair 2: O ) -> O) (frequency 19588)
# pair 3: C ( -> C( (frequency 18485)
# pair 4: C ) -> C) (frequency 15261)
# pair 5: c 1 -> c1 (frequency 14618)
# pair 6: CC CC -> CCCC (frequency 13035)
# pair 7: = O) -> =O) (frequency 10568)
# pair 8: ( C) -> (C) (frequency 8668)
# pair 9: c1 cc -> c1cc (frequency 7492)
# pair 10: C( =O) -> C(=O) (frequency 6138)
# pair 11: C 1 -> C1 (frequency 5331)
# pair 12: c ( -> c( (frequency 4831)
# pair 13: c 2 -> c2 (frequency 4750)
# pair 14: C( C) -> C(C) (frequency 4290)
# pair 15: C( O) -> C(O) (frequency 4256)
# pair 16: CC ( -> CC( (frequency 4190)
# pair 17: c1cc cc -> c1cccc (frequency 3620)
# pair 18: C O -> CO (frequency 3591)
# pair 19: c1cccc c1 -> c1ccccc1 (frequency 2951)
# pair 20: C = -> C= (frequency 2899)
# pair 21: CCCC CCCC -> CCCCCCCC (frequency 2867)
# pair 22: C(=O) O -> C(=O)O (frequency 2342)
# pair 23: CC( =O) -> CC(=O) (frequency 2246)
# pair 24: cc cc -> cccc (frequency 2138)
# pair 25: O = -> O= (frequency 2102)
# pair 26: CC 1 -> CC1 (frequency 2062)
# pair 27: C 2 -> C2 (frequency 2018)
# pair 28: CC (C) -> CC(C) (frequency 1986)
# pair 29: c1cc c( -> c1ccc( (frequency 1886)
# pair 30: cc 1 -> cc1 (frequency 1878)
# pair 31: CC O -> CCO (frequency 1827)
# pair 32: c2 cccc -> c2cccc (frequency 1457)
# pair 33: [Si] (C) -> [Si](C) (frequency 1357)
# pair 34: CC C -> CCC (frequency 1319)
# pair 35: ( =O) -> (=O) (frequency 1284)
# pair 36: [Si](C) (C) -> [Si](C)(C) (frequency 1265)
# pair 37: = O -> =O (frequency 1233)
# pair 38: CC(=O) O -> CC(=O)O (frequency 1199)
# pair 39: C(O) C(O) -> C(O)C(O) (frequency 1175)
# pair 40: c2cccc c2 -> c2ccccc2 (frequency 1164)
# pair 41: CO C(=O) -> COC(=O) (frequency 1124)
# pair 42: Cl ) -> Cl) (frequency 1041)
# pair 43: CC( O) -> CC(O) (frequency 1028)
# pair 44: N = -> N= (frequency 1027)
# pair 45: c 3 -> c3 (frequency 1022)
# pair 46: C1 O -> C1O (frequency 925)
# pair 47: C1 CC -> C1CC (frequency 919)
# pair 48: = N -> =N (frequency 916)
# pair 49: ( O) -> (O) (frequency 906)
# pair 50: C c1ccccc1 -> Cc1ccccc1 (frequency 840)
# pair 51: O= C(O) -> O=C(O) (frequency 775)
# pair 52: (C) C -> (C)C (frequency 753)
# pair 53: CC C1 -> CCC1 (frequency 723)
# pair 54: N ) -> N) (frequency 715)
# pair 55: CCO C(=O) -> CCOC(=O) (frequency 704)
# pair 56: C(C) C -> C(C)C (frequency 673)
# pair 57: c( O) -> c(O) (frequency 672)
# pair 58: c n -> cn (frequency 668)
# pair 59: c (C) -> c(C) (frequency 660)
# pair 60: C( C -> C(C (frequency 641)
# pair 61: c2ccccc2 ) -> c2ccccc2) (frequency 639)
# pair 62: c2 cc -> c2cc (frequency 630)
# pair 63: F ) -> F) (frequency 628)
# pair 64: O C) -> OC) (frequency 621)
# pair 65: CC = -> CC= (frequency 616)
# pair 66: CC C= -> CCC= (frequency 603)
# pair 67: N 1 -> N1 (frequency 574)
# pair 68: C c1cc -> Cc1cc (frequency 562)
# pair 69: CC ) -> CC) (frequency 558)
# pair 70: CC C(C) -> CCC(C) (frequency 553)
# pair 71: CCCC (C) -> CCCC(C) (frequency 534)
# pair 72: 2 ) -> 2) (frequency 528)
# pair 73: O C(=O) -> OC(=O) (frequency 526)
# no pair has frequency >= 500. Stopping
# SPE vocabulary saved to dataset/SPE_gc_deepsmiles_filtered.txt
# Word2Vec model saved to spe_model.bin
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCC1=NCC(C)N1, Vector shape: ()
# Invalid vector shape for SMILES: CC1=NCC(C)N1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC1=NCCN1, Vector shape: ()
# Invalid vector shape for SMILES: CCC1=NCCN1, Vector shape: ()
# Invalid vector shape for SMILES: CC1=NCCN1, Vector shape: ()
# Invalid vector shape for SMILES: ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(C(=O)OCC)C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1ccccc1C(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: CCOc1ccc(N=C(C)O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)=Nc1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)OC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)=Nc1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1ccccc1C(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCOC(=O)CCCCC(=O)OCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: ClC=C(Cl)C=C(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: CC(Cl)CC(C)Cl, Vector shape: ()
# Invalid vector shape for SMILES: CC(Cl)CCCCl, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)C(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccc(C=C(c2ccccc2)c2ccccc2)cc1, Vector shape: ()
# Invalid vector shape for SMILES: Brc1ccc(C=C(c2ccccc2)c2ccccc2)cc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C(=O)O)C(O)CO, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CCOC(=O)CCC(=O)OCCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)C1CCCOC1=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1ccccc1[N+](=O)[O-], Vector shape: ()
# Invalid vector shape for SMILES: O=C1CCC(=O)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: C=C1CCC2CC1C2(C)CCC=C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: c1ccc2[nH]ccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(OC)c(CC(C)N)c1, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)=Nc1ccc(OC(=O)c2ccccc2O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCCCCCCCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCCCCCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC(CCCCCC)C(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC(CCCCCC)C(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(Cl)cc1Cl, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(Cl)c(Cl)c1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(OC)c(OC)c1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccccc1Cl, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(Cl)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CC(C)Cl, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCCCl, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)C(C)N=C(O)C(CC(C)C)N=C(O)C(N=C(O)C(C)N=C(C)O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)C(=O)OC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCC(=O)OC(=O)CCC, Vector shape: ()
# Invalid vector shape for SMILES: O=C1CCCCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: O=C1CCCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCC(=O)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCCC(=O)C1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(=O)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCC(=O)CCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)CC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)OC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=COC(=O)CCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCOC(=O)CCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)CCC, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)Oc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)OC1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: C=COC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: C=CC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: C=CC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCC=Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1cccc(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: C=CCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(COC(C)=O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCOc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(C)(C)CCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: COC(C)CCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCOCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: COCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)C(C=O)C(C=O)C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)COc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: C=CC(=O)CCC=C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)C1C=CC(=O)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(O)C1CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)C1(C)CCC(C)C1(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCC(C(C)C)C(O)C1, Vector shape: ()
# Invalid vector shape for SMILES: CC(N)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CC(=O)CCC(C)COCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CC(O)CCC(C)COCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CC(O)CCC(C)CO, Vector shape: ()
# Invalid vector shape for SMILES: C=CC(C)CCC(O)CC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: COC(CC(C)C)C1CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(OC)C1CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: O=C1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CC(N=C2CCCCC2C)CC(C)(C)C1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCOCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: O=CCOCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)C=C([Si](C)(C)C)[Si](C)(C)Cl, Vector shape: ()
# Invalid vector shape for SMILES: C1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: ClC(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCCCC1=NC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)CC(C)C1CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: C=CCC(C)C1CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)C(=O)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCC(OC)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)C(C)(C)CCCO[SiH3], Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(C)C(=O)C(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=CCC1CCCC(C)C1=O, Vector shape: ()
# Invalid vector shape for SMILES: C=CCC1(C)CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(CC(C)=O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C1CCC(C(C)=O)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCCC(C)C1=O, Vector shape: ()
# Invalid vector shape for SMILES: CC1(C)CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C)CC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)CC(C)CC=O, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC[Si](C)(C)[Si](C)(C)CC, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)CC1CCCCCCCCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: COC(OC)C(C(C)=O)C(CC=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCC(=O)CCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C1CCOC(CCc2ccccc2)C1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCC(CCC)C1CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)C(C)C(OC)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)CCC(CCC(C)=O)C(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)CC(C)C1CCCCC1=O, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(C)C(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCC(C)=NC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(N)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccccc1C(O)=NCC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)C=Cc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CC(C(=O)OC)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)Cc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCC1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CC1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)C(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)C1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCc1ccc(C(=O)OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(C(C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCc1ccc(C(=O)OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1cc(C)cc(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(C)c(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1cccc(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCCCCCCCCCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCCCCCCCCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCCCCCCCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)C=Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCCCCCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCCCCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCCCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCOc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)C=CC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: C=CC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: C=CC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OC(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCc1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: O=CC=Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: C=CCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)C=CC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCOCCC, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)CC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: ClC(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: COCC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: ClC=C(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: ClCCCl, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(O)C(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(CCOC(C)=O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(CCO)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC1(O)C=CC(=O)C=C1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1cncnc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1cncnc1, Vector shape: ()
# Invalid vector shape for SMILES: c1ccc2[nH]ccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)C1CCCN1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)C1=NCCC1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc2[nH]c(C)c(C)c2c1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc2c(C)c(C)[nH]c2c1[N+](=O)[O-], Vector shape: ()
# Invalid vector shape for SMILES: C=CC[Si](C)(C)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC1(C)CC=C(C[Si](C)(C)C)CC(C)(C)C1=O, Vector shape: ()
# Invalid vector shape for SMILES: C=CCC(C)(C)C(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=CCC(C)(C)C(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: C=CCCC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)C1(C)CC=C(C[Si](C)(C)C)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1ccc([Si](C)(C)[Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C1CCC(C)(C)C(=O)C(C)(C)C1, Vector shape: ()
# Invalid vector shape for SMILES: c1ccc([SiH2]c2ccccc2)cc1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCCC(=O)C(C)(C)Br, Vector shape: ()
# Invalid vector shape for SMILES: CC[SiH](C)CC, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(OC)c(CC(=O)O[Si](C)(C)C)c1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C=CC(=O)O[Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)c1ccc(C(=O)O[Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCc1ccc(C(=O)O[Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C(=O)O[Si](C)(C)C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C(=O)O[Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc(C)c(C(=O)O[Si](C)(C)C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C(=O)O[Si](C)(C)C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCC(O)CC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCCOC(=O)CCCCCCCCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCC(O)CC, Vector shape: ()
# Invalid vector shape for SMILES: CCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(C(=O)OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)CO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCl, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC=CC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CCO, Vector shape: ()
# Invalid vector shape for SMILES: CCC(O)CO, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)CCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: O=C1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCC(N)CO, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: C1CCOC1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCCCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCCCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccccc1C(=O)OCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccccc1C(=O)OCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)c1ccccc1C(=O)OCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)c1ccccc1C(=O)OCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccccc1C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccccc1C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)COC(=O)c1ccccc1C(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)COC(=O)c1ccccc1C(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)c1ccccc1C(=O)OCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)c1ccccc1C(=O)OCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(=O)CCCCCCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(=O)CCCCCCCCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(=O)CCCCCCCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(=O)CCCCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(=O)CCCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(=O)CCCCC(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCCCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)COC(=O)CCCCC(=O)OCC(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)COC(=O)CCCCCCCCC(=O)OCC(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)COC(=O)CCCCCCCCC(=O)OCC(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)c1ccccc1C(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: Cc1cccnc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)C(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCOCCOCC, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)CC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCOCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OCC(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)C(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccc(OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC=CCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: c1ccc2cnccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc(C)c(N)c1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc2c(ccc3ccccc32)c1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc2cc(C)ccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc2cccc(C)c2c1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc2ccccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: c1ccc2ccccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: C=CC, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC, Vector shape: ()
# Invalid vector shape for SMILES: C=CCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCC, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C1CCC(C)C(O)C1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)C1CCC(C)C(O)C1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: C1CCCCCCCCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: C1CCCCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: C1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: O=C1CCCCCCCCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: O=C1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)c1ccc(C(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C)(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc(C)c(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)COC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: COC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)OCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CCOCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCOCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCC=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCC=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCC=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CC=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCC=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)[SiH](C)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)c1ccc([Si](C)(C)[Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)c1ccc([Si](C)(C)OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)c1ccc([Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)c1ccc([SiH](C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc([Si](C)(C)OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc([Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc([SiH](C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CO[Si](C)(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc([Si](C)(C)Cl)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C(=O)c2ccccc2)c(O)c1, Vector shape: ()
# Invalid vector shape for SMILES: ClCCc1ccccc1Cl, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)c1ccc(C(C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)[Si](C)(C)Cl, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(C(=O)OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(COC(C)=O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1cccc(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Oc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=CCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)OC(=O)c1ccccc1C(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)C(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: N=C(O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)COC(C)COC(C)CO, Vector shape: ()
# Invalid vector shape for SMILES: COCCOCCOCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCOCCOCCO, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)OC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(O)C(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C)Cl, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1C(C)CCC(C(C)C)C1OC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CCCCC1OC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CCCCC1OC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CC(C)CC=C1C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CC(C)CC=C1C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1C=C(C)CCC1C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1C=C(C)CCC1C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCC=C(C)CCC=C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCC=C(C)CCC=C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCC(=O)CC(=O)OC1CC(C)CCC1C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=C1CCC=C1C1C(CCC(C)=O)C1(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1cccc(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: COc1cccc(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C(=O)O[Si](C)(C)C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCc1ccc(C(=O)O[Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C(=O)O[Si](C)(C)C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C=CC(=O)O[Si](C)(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(OC)c(CC(=O)O[Si](C)(C)C)c1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc(C)c(C(=O)O[Si](C)(C)C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C(=O)O[Si](C)(C)C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)Cl, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)c1ccccc1C(=O)OCCC, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)c1ccc(Cl)cc1, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)c1ccccc1Cl, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)c1ccc(F)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccc(F)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C(=O)OCC(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)C(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: ClCCOCOCCCl, Vector shape: ()
# Invalid vector shape for SMILES: CCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: ClCC(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: ClC(Cl)C(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: ClCCCl, Vector shape: ()
# Invalid vector shape for SMILES: CC(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: CCCl, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccc(Cl)c(Cl)c1, Vector shape: ()
# Invalid vector shape for SMILES: Clc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: C=CC=O, Vector shape: ()
# Invalid vector shape for SMILES: ClC=CCCl, Vector shape: ()
# Invalid vector shape for SMILES: C=C(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccc(C(c2ccc(Cl)cc2)C(Cl)Cl)cc1, Vector shape: ()
# Invalid vector shape for SMILES: ClC(Cl)Cl, Vector shape: ()
# Invalid vector shape for SMILES: Cc1cc(O)ccc1Cl, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccc2ccccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: C=COCCCl, Vector shape: ()
# Invalid vector shape for SMILES: ClCCOCCCl, Vector shape: ()
# Invalid vector shape for SMILES: CCC1(C)CC(C)=NN1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCN1CCC=N1, Vector shape: ()
# Invalid vector shape for SMILES: CC1(C)CC=NN1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CC=NN1, Vector shape: ()
# Invalid vector shape for SMILES: CC=NN1CCCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CC=NN1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CC=C1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: COc1c(C)cccc(C)c1=O, Vector shape: ()
# Invalid vector shape for SMILES: C=CCc1ccc(OC)c(OC)c1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCc1ccc(OC)c(OC)c1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCc1ccc(O)c(OC)c1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCc1ccc(OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: C=CCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)CCOC(C)(C)CCOC(C)(C)CCO, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)CCOC(C)(C)CCO, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)COC(C)(C)COC(C)(C)CO, Vector shape: ()
# Invalid vector shape for SMILES: C=C(C)COC(C)(C)CO, Vector shape: ()
# Invalid vector shape for SMILES: N=C(O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC1(C)C2CCC1(C)C(O)C2, Vector shape: ()
# Invalid vector shape for SMILES: CC1(C)C2CCC1(C)C(O)C2, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(O)c(C(=O)CC(=O)CCc2ccccc2)c1, Vector shape: ()
# Invalid vector shape for SMILES: COc1cccc(O)c1C(=O)CC(=O)CCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)=Nc1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(O)c(C(C)=O)c1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C=CC(=O)O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc2cccnc2c1, Vector shape: ()
# Invalid vector shape for SMILES: CC1=NN=C(C)C1(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCC1=NCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CC1=NCCC1, Vector shape: ()
# Invalid vector shape for SMILES: c1cn[nH]c1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCc2ccccc2N1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C=CC(=O)c2ccccc2)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)CC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC1(C)C2CCC1(C)C(O)C2, Vector shape: ()
# Invalid vector shape for SMILES: C=CCCC, Vector shape: ()
# Invalid vector shape for SMILES: C=CCC, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)=NCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)=NC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)OC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: c1ccc(C(CCC(c2ccccc2)c2ccccc2)c2ccccc2)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC1CCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C)CO, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CCO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCO, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CO, Vector shape: ()
# Invalid vector shape for SMILES: CCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCCC(=O)CCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: CCCC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)CC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)CCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)C(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCC(C)=O, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCC(C(C)C)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCC(C(C)C)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCC2CC1C2(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCC(C(C)C)C(O)C1, Vector shape: ()
# Invalid vector shape for SMILES: C=C1CCC2CC1C2(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CC1N=C(O)C(C)N=C1O, Vector shape: ()
# Invalid vector shape for SMILES: CC1N=C(O)C(CO)N=C1O, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccccc1[N+](=O)[O-], Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1cccc(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: COCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: ClCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccccc1[N+](=O)[O-], Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1cccc(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1cccc(O)c1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(=O)c1ccc(Cl)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(=O)c1ccc(F)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(=O)c1ccccc1Br, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(=O)c1ccccc1Cl, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccccc1Cl, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)OC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccccc1Br, Vector shape: ()
# Invalid vector shape for SMILES: O=C1CCC2CCCCC2C1, Vector shape: ()
# Invalid vector shape for SMILES: C1CCC2CCCCC2C1, Vector shape: ()
# Invalid vector shape for SMILES: C1CCC2CCCCC2C1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CCC(C(C)(C)C)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CCC(C(C)(C)C)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CCCCC1C(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OC1CCCCC1C(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)C(C)N=C(O)C(CC(C)C)N=C(O)C(N=C(C)O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC1N=C(O)C(C(C)C)N=C1O, Vector shape: ()
# Invalid vector shape for SMILES: CC1N=C(O)C(C)N=C1O, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CC(N=C(C)O)C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CCC(N=C(C)O)C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)C(N=C(C)O)C(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(=O)c1ccc(O)cc1, Vector shape: ()
# ...
# Invalid vector shape for SMILES: CCOC(=O)C=CC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: Cc1cc(C)c(O)c(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CCc1ccc(O)c(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)c1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCOc1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCc1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCc1cccc(O)c1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(C)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C(C)C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCc1ccc(OC)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOc1cccc(C)c1, Vector shape: ()
# Invalid vector shape for SMILES: CCCOc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOc1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: COc1cccc(O)c1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: Cc1cc(C)cc(O)c1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCc1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: ClCCCN1CCOCC1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccc(N=C(C)O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCc1cccnc1, Vector shape: ()
# Invalid vector shape for SMILES: Cc1cccnc1, Vector shape: ()
# Invalid vector shape for SMILES: COC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCOCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CCOCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)COC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCOCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(C)CC, Vector shape: ()
# Invalid vector shape for SMILES: COCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COC(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCOCC, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)CCCCCCC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)CCCCCC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)CCCCC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)CCC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)CC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)C(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: CCN1C(=O)C(c2ccccc2)N=C1O, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(O)C(C)(O)c1ccc(Cl)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)OCCCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: ClCCCN1CCOCC1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(N=C(C)O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccc(N=C(C)O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: O=C(CCCCl)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: O=C(CCCF)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(=O)c1ccc(F)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1ccc(F)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC=C(Cl)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCCC(O)C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOCC(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)COC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: COCC(OC)C(OC)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)C=C=CC(=O)C(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)C(=O)C1C=C1C(C)(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCC1CCC(O)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCCCC1CO, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccc(Cl)cc1, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccccc1Cl, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: Clc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccc(Cl)c(Cl)c1Cl, Vector shape: ()
# Invalid vector shape for SMILES: Clc1ccc(Cl)c(Cl)c1, Vector shape: ()
# Invalid vector shape for SMILES: O=C1CCCCCCCCCCC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)C1CCCCC1O, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCC(O)C1O, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCCC(O)C1, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCCCC1O, Vector shape: ()
# Invalid vector shape for SMILES: CC1CCC(O)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)CO, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)C1CCC(O)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)(C)C1CCCCC1O, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C)C1CCCCC1O, Vector shape: ()
# Invalid vector shape for SMILES: CC1CC(O)CC(C)(C)C1, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C)C1CCC(O)CC1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)OC(=O)c1ccccc1C(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CCCCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccc(C(=O)c2ccccc2O)c(O)c1, Vector shape: ()
# Invalid vector shape for SMILES: O=Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)C(O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: c1ccc2[nH]ccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: O=C(O)c1ccc(O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(O)=Nc1ccc(Cl)cc1C(=O)c1ccccc1Cl, Vector shape: ()
# Invalid vector shape for SMILES: c1ccc2ccccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: COC(=O)c1ccc(N=C(C)O)cc1, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccc(N)cc1, Vector shape: ()
# Invalid vector shape for SMILES: ClC(Cl)Br, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)CO, Vector shape: ()
# Invalid vector shape for SMILES: COc1ccccc1[N+](=O)[O-], Vector shape: ()
# Invalid vector shape for SMILES: Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: O=Cc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(=O)c1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: ClCCOCCCl, Vector shape: ()
# Invalid vector shape for SMILES: c1ccc2ccccc2c1, Vector shape: ()
# Invalid vector shape for SMILES: ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)C=CC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)C=CC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)COC(=O)C=CC(=O)OCC(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)C=CC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)C=CC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOCCOC(=O)CCCCC(=O)OCCOCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCOC(=O)CCCCC(=O)OCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CCCCCCCOC(=O)CCCCC(=O)OCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCOC(=O)CCCCC(=O)OCCCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)COC(=O)CCCCC(=O)OCC(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)CCCCC(=O)OCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CCCCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)C(O)C(O)C(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)CCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCOC(=O)CCC(=O)OCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCC(=O)OC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)COC(=O)c1ccccc1C(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)COC(=O)c1ccccc1C(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC(=O)OCCOCCOCCOC(=O)CCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)C(=O)OCCOCCOCCOC(=O)C(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCC(C)CC(=O)OCCOCCOCCOC(=O)CC(C)CC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC(=O)OCCOCCOC(=O)CCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCC(=O)OCCO, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC(=O)OCCOCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCCCCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCOC(=O)CCCCCCCCC(=O)OCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)CCCCCCCCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCC(CC=CCCCCCCCC(=O)OCCOC)CC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCC(CC=CCCCCCCCC(=O)OC)CC(=O)O, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCC(=O)OCCOCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCC(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCC=CCCCCCCCC(=O)OCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOCCOC(=O)c1ccccc1C(=O)OCCOCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)c1ccccc1C(=O)OCc1ccccc1, Vector shape: ()
# Invalid vector shape for SMILES: CC(C)CCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC(C)C, Vector shape: ()
# Invalid vector shape for SMILES: CCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCCCOC(=O)c1ccccc1C(=O)OCCCC, Vector shape: ()
# Invalid vector shape for SMILES: CCOC(=O)c1ccccc1C(=O)OCC, Vector shape: ()
#                                       0         1         2         3  \
# OCc1ccccc1                     0.316702  0.799657  0.204286  0.235206
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1 -0.119604  0.100687 -0.129126  0.078933
# Cc1ccc(S(N)(=O)=O)cc1         -0.054107  0.213532  0.053058  0.187519
# CCNS(=O)(=O)c1ccccc1C         -0.211124  0.217528 -0.124125  0.128061
# CCNS(=O)(=O)c1ccc(C)cc1       -0.410714  0.235297 -0.168121  0.181756
#
#                                       4         5         6         7  \
# OCc1ccccc1                     0.089976 -0.071670  0.276648  0.109839
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1  0.055712 -0.213619 -0.027721  0.305306
# Cc1ccc(S(N)(=O)=O)cc1          0.044086 -0.333432 -0.020290  0.590875
# CCNS(=O)(=O)c1ccccc1C         -0.027341 -0.325366 -0.124203  0.431513
# CCNS(=O)(=O)c1ccc(C)cc1       -0.298715 -0.307213 -0.152567  0.325268
#
#                                       8         9  ...        91        92  \
# OCc1ccccc1                    -0.655304 -0.550977  ... -0.127717 -0.206205
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1 -0.343636 -0.560261  ...  0.115509  0.221045
# Cc1ccc(S(N)(=O)=O)cc1         -0.711251 -0.750661  ... -0.048266  0.445258
# CCNS(=O)(=O)c1ccccc1C         -0.469020 -0.598300  ...  0.139432  0.304743
# CCNS(=O)(=O)c1ccc(C)cc1       -0.407697 -0.555498  ...  0.132736  0.172674
#
#                                      93        94        95        96  \
# OCc1ccccc1                    -0.096286  0.128828 -0.115650 -0.143779
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1  0.106596 -0.466188  0.125060 -0.185861
# Cc1ccc(S(N)(=O)=O)cc1          0.097488 -0.950423  0.014335 -0.189448
# CCNS(=O)(=O)c1ccccc1C          0.096945 -0.450292  0.076915 -0.186304
# CCNS(=O)(=O)c1ccc(C)cc1       -0.004135 -0.419316  0.000593 -0.285284
#
#                                      97        98        99  \
# OCc1ccccc1                     0.165745  0.076912 -0.006027
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1 -0.049754 -0.391965  0.412753
# Cc1ccc(S(N)(=O)=O)cc1          0.140751 -0.341900  0.673902
# CCNS(=O)(=O)c1ccccc1C         -0.037339 -0.332494  0.473531
# CCNS(=O)(=O)c1ccc(C)cc1       -0.200960 -0.355270  0.516366
#
#                                                                         Spectrum
# OCc1ccccc1                     49:2.9 50:20 51:50.5 52:10.1 53:8.3 54:2.1 60:...
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1  43:5.7 44:2.7 51:3.8 53:1.9 54:6.5 55:6 62:4.1...
# Cc1ccc(S(N)(=O)=O)cc1          50:3.6 51:6.6 52:2.4 53:1.9 61:3 62:9.6 63:2.6...
# CCNS(=O)(=O)c1ccccc1C          44:48.8 45:1.6 50:3.3 51:6.7 52:2.2 53:1.7 57:...
# CCNS(=O)(=O)c1ccc(C)cc1        50:2.6 51:5.9 52:1.7 53:1.3 61:2 62:8.5 63:2.9...
#
# [5 rows x 101 columns]
#                                       0         1         2         3  \
# OCc1ccccc1                     0.316702  0.799657  0.204286  0.235206
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1 -0.119604  0.100687 -0.129126  0.078933
# Cc1ccc(S(N)(=O)=O)cc1         -0.054107  0.213532  0.053058  0.187519
# CCNS(=O)(=O)c1ccccc1C         -0.211124  0.217528 -0.124125  0.128061
# CCNS(=O)(=O)c1ccc(C)cc1       -0.410714  0.235297 -0.168121  0.181756
#
#                                       4         5         6         7  \
# OCc1ccccc1                     0.089976 -0.071670  0.276648  0.109839
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1  0.055712 -0.213619 -0.027721  0.305306
# Cc1ccc(S(N)(=O)=O)cc1          0.044086 -0.333432 -0.020290  0.590875
# CCNS(=O)(=O)c1ccccc1C         -0.027341 -0.325366 -0.124203  0.431513
# CCNS(=O)(=O)c1ccc(C)cc1       -0.298715 -0.307213 -0.152567  0.325268
#
#                                       8         9  ...        91        92  \
# OCc1ccccc1                    -0.655304 -0.550977  ... -0.127717 -0.206205
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1 -0.343636 -0.560261  ...  0.115509  0.221045
# Cc1ccc(S(N)(=O)=O)cc1         -0.711251 -0.750661  ... -0.048266  0.445258
# CCNS(=O)(=O)c1ccccc1C         -0.469020 -0.598300  ...  0.139432  0.304743
# CCNS(=O)(=O)c1ccc(C)cc1       -0.407697 -0.555498  ...  0.132736  0.172674
#
#                                      93        94        95        96  \
# OCc1ccccc1                    -0.096286  0.128828 -0.115650 -0.143779
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1  0.106596 -0.466188  0.125060 -0.185861
# Cc1ccc(S(N)(=O)=O)cc1          0.097488 -0.950423  0.014335 -0.189448
# CCNS(=O)(=O)c1ccccc1C          0.096945 -0.450292  0.076915 -0.186304
# CCNS(=O)(=O)c1ccc(C)cc1       -0.004135 -0.419316  0.000593 -0.285284
#
#                                      97        98        99  \
# OCc1ccccc1                     0.165745  0.076912 -0.006027
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1 -0.049754 -0.391965  0.412753
# Cc1ccc(S(N)(=O)=O)cc1          0.140751 -0.341900  0.673902
# CCNS(=O)(=O)c1ccccc1C         -0.037339 -0.332494  0.473531
# CCNS(=O)(=O)c1ccc(C)cc1       -0.200960 -0.355270  0.516366
#
#                                                                         Spectrum
# OCc1ccccc1                     49:2.9 50:20 51:50.5 52:10.1 53:8.3 54:2.1 60:...
# Cc1ccc(S(=O)(=O)NC2CCCCC2)cc1  43:5.7 44:2.7 51:3.8 53:1.9 54:6.5 55:6 62:4.1...
# Cc1ccc(S(N)(=O)=O)cc1          50:3.6 51:6.6 52:2.4 53:1.9 61:3 62:9.6 63:2.6...
# CCNS(=O)(=O)c1ccccc1C          44:48.8 45:1.6 50:3.3 51:6.7 52:2.2 53:1.7 57:...
# CCNS(=O)(=O)c1ccc(C)cc1        50:2.6 51:5.9 52:1.7 53:1.3 61:2 62:8.5 63:2.9...
#
# [5 rows x 101 columns]

# %% [markdown]
# ## Spectra Preprocessing

# %% [markdown]
# The function below takes a mass spectrometry string as input and preprocesses it into a 2D representation suitable for the 2D CNN.
#
# 1. Initializes a 2D zero matrix with dimensions `mz_bins` and `intensity_bins`.
# 2. Converts the spectrum string to a pandas DataFrame containing m/z values and intensities.
# 3. Normalizes the intensities by dividing them by the maximum intensity.
# 4. Filters out peaks with intensities below a certain threshold (`noise_threshold`).
# 5. Scales the m/z values to fit within the `mz_bins` range.
# 6. Fills the 2D matrix with 1s based on the scaled m/z values and intensities.

# %%
def preprocess_ms_to_2d(spectrum_string, mz_bins=200, intensity_bins=100, noise_threshold=0.01):
    spectrum = np.zeros((mz_bins, intensity_bins))
    
    df = pd.DataFrame([peak.split(':') for peak in spectrum_string.split()], columns=['m/z', 'intensity'])
    df = df.astype(float)
    max_intensity = df['intensity'].max()
    if max_intensity > 0:
        df['intensity'] /= max_intensity
    df = df[df['intensity'] >= noise_threshold]
    mz_values = df['m/z'].values
    intensities = df['intensity'].values
    mz_min, mz_max = mz_values.min(), mz_values.max()
    if mz_max != mz_min:
        mz_scaled = np.round((mz_values - mz_min) / (mz_max - mz_min) * (mz_bins - 1)).astype(int)
        for mz, intensity in zip(mz_scaled, intensities):
            intensity_scaled = min(int(intensity * (intensity_bins - 1)), intensity_bins - 1)
            spectrum[mz, :intensity_scaled + 1] = 1
    
    return spectrum

# %%
# for visualization used later
def plot_spectrum_and_heatmap(spectrum_string, mz_bins=200, intensity_bins=100):
    """
    Plots the original spectrum and its 2D heatmap representation.
    """
    spectrum_2d = preprocess_ms_to_2d(spectrum_string, mz_bins, intensity_bins)

    # Plot original spectrum
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    mz_values, intensities = zip(*[map(float, peak.split(':')) for peak in spectrum_string.split()])
    plt.bar(mz_values, intensities, width=1.0, color='blue', alpha=0.7)
    plt.title("Original Spectrum")
    plt.xlabel("m/z")
    plt.ylabel("Intensity (Normalized)")

    # Plot 2D heatmap
    plt.subplot(1, 2, 2)
    plt.imshow(spectrum_2d.T, aspect='auto', origin='lower', cmap='hot', extent=[0, mz_bins, 0, intensity_bins])
    plt.title("2D Heatmap Representation")
    plt.xlabel("m/z Bins")
    plt.ylabel("Intensity Bins")
    plt.colorbar(label="Presence")
    plt.tight_layout()
    plt.show()

# %%
# Load dataset
df = pd.read_csv('dataset/gc_vector.csv')

# Preprocess spectra and visualize a few examples
df['Processed_Spectrum'] = df['Spectrum'].apply(preprocess_ms_to_2d)

# Plot a few examples
test_spectra = df['Spectrum'].dropna().head(3)
for i, spectrum in enumerate(test_spectra):
    plot_spectrum_and_heatmap(spectrum)

# %%
# Convert processed spectra into arrays
spectra_array = np.stack(df['Processed_Spectrum'].values)
spectra_array = np.expand_dims(spectra_array, axis=-1)

# Extract vector data
vector_columns = [str(i) for i in range(100)]
vector_array = df[vector_columns].values.astype(np.float32)

# Print shapes for verification
print("Spectra Array Shape:", spectra_array.shape)
print("Vector Array Shape:", vector_array.shape)
# Out:
# Spectra Array Shape: (13496, 200, 100, 1)
# Vector Array Shape: (13496, 100)

# %% [markdown]
# Spectra Array Shape:
# * 13496 Spectrums
# * 200: # of bins along the m/z (mass-to-charge ratio) axis in the 2D representation.
# * 100: # of bins along the intensity axis in the 2D representation.
#
# Vector Array Shape:
# * 13496: The number of samples (matching the spectra array).
# * 100: The dimensionality of the target vector for each sample (Spe Vector)

# %% [markdown]
# ### Splitting for Test/Train & Tensorflow Dataset Preperation

# %%
# Split data
X_train_full, X_test, y_train_full, y_test = train_test_split(
    spectra_array, vector_array, test_size=0.2, random_state=42
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full, test_size=0.1, random_state=42
)

# Print split sizes
print("Training Data Shape:", X_train.shape, y_train.shape)
print("Validation Data Shape:", X_val.shape, y_val.shape)
print("Testing Data Shape:", X_test.shape, y_test.shape)
# Out:
# Training Data Shape: (9716, 200, 100, 1) (9716, 100)
# Validation Data Shape: (1080, 200, 100, 1) (1080, 100)
# Testing Data Shape: (2700, 200, 100, 1) (2700, 100)

# %%
# Prepare datasets
train_data = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(32).prefetch(tf.data.experimental.AUTOTUNE)
val_data = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(32).prefetch(tf.data.experimental.AUTOTUNE)
test_data = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(32)

# Print data pipeline example
for x_batch, y_batch in train_data.take(1):
    print("Batch X Shape:", x_batch.shape)
    print("Batch Y Shape:", y_batch.shape)
# Out:
# Batch X Shape: (32, 200, 100, 1)
# Batch Y Shape: (32, 100)
# 2024-12-13 19:36:05.607286: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## CNN + LSTM Encoder Model

# %%
def lstm_encoder(input_shape, latent_dim=128, dropout_rate=0.3):
    encoder_input = Input(shape=input_shape, name="encoder_input")

    # Convolutional layers for feature extraction
    x = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(encoder_input)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(dropout_rate)(x)

    x = Conv2D(64, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(dropout_rate)(x)

    # Flatten and reshape for LSTM input
    x = Flatten()(x)
    x = Dense(latent_dim, activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = Reshape((-1, latent_dim))(x)  # Reshape into sequences

    # Bidirectional LSTM for sequence encoding
    x = Bidirectional(LSTM(latent_dim, return_sequences=False, dropout=dropout_rate))(x)

    # Latent representation
    encoder_features = Dense(latent_dim, activation="relu", name="encoder_features", kernel_regularizer=l2(1e-4))(x)

    return Model(encoder_input, encoder_features, name="lstm_encoder")

# %% [markdown]
# ## Decoder Model

# %%
def build_decoder(vector_dim, latent_dim=128, dropout_rate=0.3):
    
    encoder_features = Input(shape=(latent_dim,), name="encoder_features_input")

    x = Dense(256, activation="relu", kernel_regularizer=l2(1e-4))(encoder_features)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(128, activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    # Output layer
    x = Dense(vector_dim, activation="linear", kernel_regularizer=l2(1e-4), name="vector_output")(x)

    return Model(encoder_features, x, name="decoder")

# %% [markdown]
# ## Combine Encoder + Decoder

# %%
input_shape = (200, 100, 1) 
latent_dim = 128  # dim of latent representation
vector_dim = 100  # dim of the target vectors

# instantiate encoder and decoder
encoder = lstm_encoder(input_shape, latent_dim)
decoder = build_decoder(vector_dim, latent_dim)

# combine to single model
encoder_input = Input(shape=input_shape, name="encoder_input")
encoder_features = encoder(encoder_input)
decoder_output = decoder(encoder_features)
model = Model(encoder_input, decoder_output, name="encoder_decoder_model")

# print model summary
model.summary()
# Out:
# Model: "encoder_decoder_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_input (InputLayer)      │ (None, 200, 100, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_encoder (Functional)       │ (None, 128)            │    10,555,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 100)            │        80,356 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,635,748 (40.57 MB)
#  Trainable params: 10,634,788 (40.57 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

# %%
# Early stopping and learning rate reduction callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=100,
    callbacks=[early_stopping, reduce_lr]
)

# After training, save predictions for the test dataset
import pandas as pd
import os

# Ensure the output directory exists
output_dir = "predictions"
os.makedirs(output_dir, exist_ok=True)

# Generate predictions
predictions = model.predict(test_data)
actuals = np.vstack([y.numpy() for _, y in test_data])  # Extract actual values from test dataset

# Save predictions to a CSV file
df = pd.DataFrame({
    "Actuals": [list(vec) for vec in actuals],
    "Predictions": [list(vec) for vec in predictions]
})
csv_path = os.path.join(output_dir, "final_predictions.csv")
df.to_csv(csv_path, index=False)

print(f"Saved final predictions to {csv_path}")
# Out:
# Epoch 1/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 56s 178ms/step - loss: 1.5893 - mean_absolute_error: 0.9671 - val_loss: 0.4105 - val_mean_absolute_error: 0.4495 - learning_rate: 1.0000e-04
# Epoch 2/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 51s 166ms/step - loss: 1.0261 - mean_absolute_error: 0.7646 - val_loss: 0.3420 - val_mean_absolute_error: 0.3952 - learning_rate: 1.0000e-04
# Epoch 3/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 51s 166ms/step - loss: 0.6818 - mean_absolute_error: 0.6059 - val_loss: 0.2550 - val_mean_absolute_error: 0.3186 - learning_rate: 1.0000e-04
# Epoch 4/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 166ms/step - loss: 0.4952 - mean_absolute_error: 0.4994 - val_loss: 0.1956 - val_mean_absolute_error: 0.2532 - learning_rate: 1.0000e-04
# Epoch 5/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 166ms/step - loss: 0.3939 - mean_absolute_error: 0.4316 - val_loss: 0.1725 - val_mean_absolute_error: 0.2226 - learning_rate: 1.0000e-04
# Epoch 6/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 164ms/step - loss: 0.3363 - mean_absolute_error: 0.3882 - val_loss: 0.1633 - val_mean_absolute_error: 0.2110 - learning_rate: 1.0000e-04
# Epoch 7/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 165ms/step - loss: 0.2973 - mean_absolute_error: 0.3571 - val_loss: 0.1581 - val_mean_absolute_error: 0.2057 - learning_rate: 1.0000e-04
# Epoch 8/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 51s 167ms/step - loss: 0.2662 - mean_absolute_error: 0.3308 - val_loss: 0.1541 - val_mean_absolute_error: 0.2019 - learning_rate: 1.0000e-04
# Epoch 9/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 164ms/step - loss: 0.2422 - mean_absolute_error: 0.3097 - val_loss: 0.1509 - val_mean_absolute_error: 0.2000 - learning_rate: 1.0000e-04
# Epoch 10/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 47s 155ms/step - loss: 0.2211 - mean_absolute_error: 0.2905 - val_loss: 0.1484 - val_mean_absolute_error: 0.1992 - learning_rate: 1.0000e-04
# Epoch 11/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 47s 155ms/step - loss: 0.2034 - mean_absolute_error: 0.2736 - val_loss: 0.1457 - val_mean_absolute_error: 0.1983 - learning_rate: 1.0000e-04
# Epoch 12/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 47s 155ms/step - loss: 0.1894 - mean_absolute_error: 0.2596 - val_loss: 0.1432 - val_mean_absolute_error: 0.1978 - learning_rate: 1.0000e-04
# Epoch 13/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 51s 167ms/step - loss: 0.1773 - mean_absolute_error: 0.2475 - val_loss: 0.1406 - val_mean_absolute_error: 0.1977 - learning_rate: 1.0000e-04
# Epoch 14/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - loss: 0.1663 - mean_absolute_error: 0.2363 - val_loss: 0.1383 - val_mean_absolute_error: 0.1975 - learning_rate: 1.0000e-04
# Epoch 15/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 165ms/step - loss: 0.1572 - mean_absolute_error: 0.2276 - val_loss: 0.1356 - val_mean_absolute_error: 0.1975 - learning_rate: 1.0000e-04
# Epoch 16/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 164ms/step - loss: 0.1488 - mean_absolute_error: 0.2194 - val_loss: 0.1323 - val_mean_absolute_error: 0.1967 - learning_rate: 1.0000e-04
# Epoch 17/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 166ms/step - loss: 0.1419 - mean_absolute_error: 0.2131 - val_loss: 0.1294 - val_mean_absolute_error: 0.1969 - learning_rate: 1.0000e-04
# Epoch 18/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 165ms/step - loss: 0.1354 - mean_absolute_error: 0.2077 - val_loss: 0.1286 - val_mean_absolute_error: 0.1999 - learning_rate: 1.0000e-04
# Epoch 19/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 162ms/step - loss: 0.1293 - mean_absolute_error: 0.2028 - val_loss: 0.1251 - val_mean_absolute_error: 0.1993 - learning_rate: 1.0000e-04
# Epoch 20/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 51s 166ms/step - loss: 0.1243 - mean_absolute_error: 0.1993 - val_loss: 0.1214 - val_mean_absolute_error: 0.1976 - learning_rate: 1.0000e-04
# Epoch 21/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 162ms/step - loss: 0.1186 - mean_absolute_error: 0.1950 - val_loss: 0.1206 - val_mean_absolute_error: 0.2003 - learning_rate: 1.0000e-04
# Epoch 22/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.1140 - mean_absolute_error: 0.1922 - val_loss: 0.1184 - val_mean_absolute_error: 0.2006 - learning_rate: 1.0000e-04
# Epoch 23/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 162ms/step - loss: 0.1093 - mean_absolute_error: 0.1894 - val_loss: 0.1164 - val_mean_absolute_error: 0.2011 - learning_rate: 1.0000e-04
# Epoch 24/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 51s 167ms/step - loss: 0.1050 - mean_absolute_error: 0.1871 - val_loss: 0.1154 - val_mean_absolute_error: 0.2035 - learning_rate: 1.0000e-04
# Epoch 25/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - loss: 0.1004 - mean_absolute_error: 0.1841 - val_loss: 0.1163 - val_mean_absolute_error: 0.2069 - learning_rate: 1.0000e-04
# Epoch 26/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 165ms/step - loss: 0.0957 - mean_absolute_error: 0.1806 - val_loss: 0.1184 - val_mean_absolute_error: 0.2119 - learning_rate: 1.0000e-04
# Epoch 27/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 162ms/step - loss: 0.0911 - mean_absolute_error: 0.1766 - val_loss: 0.1104 - val_mean_absolute_error: 0.2032 - learning_rate: 1.0000e-04
# Epoch 28/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - loss: 0.0873 - mean_absolute_error: 0.1731 - val_loss: 0.1029 - val_mean_absolute_error: 0.1947 - learning_rate: 1.0000e-04
# Epoch 29/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 51s 166ms/step - loss: 0.0830 - mean_absolute_error: 0.1692 - val_loss: 0.1145 - val_mean_absolute_error: 0.2113 - learning_rate: 1.0000e-04
# Epoch 30/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0783 - mean_absolute_error: 0.1634 - val_loss: 0.1121 - val_mean_absolute_error: 0.2091 - learning_rate: 1.0000e-04
# Epoch 31/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 164ms/step - loss: 0.0748 - mean_absolute_error: 0.1584 - val_loss: 0.0941 - val_mean_absolute_error: 0.1845 - learning_rate: 1.0000e-04
# Epoch 32/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0711 - mean_absolute_error: 0.1536 - val_loss: 0.0930 - val_mean_absolute_error: 0.1840 - learning_rate: 1.0000e-04
# Epoch 33/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 163ms/step - loss: 0.0678 - mean_absolute_error: 0.1487 - val_loss: 0.0901 - val_mean_absolute_error: 0.1815 - learning_rate: 1.0000e-04
# Epoch 34/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0652 - mean_absolute_error: 0.1452 - val_loss: 0.0878 - val_mean_absolute_error: 0.1781 - learning_rate: 1.0000e-04
# Epoch 35/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0622 - mean_absolute_error: 0.1408 - val_loss: 0.0862 - val_mean_absolute_error: 0.1777 - learning_rate: 1.0000e-04
# Epoch 36/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0597 - mean_absolute_error: 0.1372 - val_loss: 0.0844 - val_mean_absolute_error: 0.1756 - learning_rate: 1.0000e-04
# Epoch 37/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0575 - mean_absolute_error: 0.1340 - val_loss: 0.0842 - val_mean_absolute_error: 0.1742 - learning_rate: 1.0000e-04
# Epoch 38/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 50s 166ms/step - loss: 0.0556 - mean_absolute_error: 0.1310 - val_loss: 0.0851 - val_mean_absolute_error: 0.1757 - learning_rate: 1.0000e-04
# Epoch 39/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0533 - mean_absolute_error: 0.1276 - val_loss: 0.0868 - val_mean_absolute_error: 0.1788 - learning_rate: 1.0000e-04
# Epoch 40/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0519 - mean_absolute_error: 0.1251 - val_loss: 0.0815 - val_mean_absolute_error: 0.1706 - learning_rate: 1.0000e-04
# Epoch 41/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0505 - mean_absolute_error: 0.1225 - val_loss: 0.0793 - val_mean_absolute_error: 0.1671 - learning_rate: 1.0000e-04
# Epoch 42/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0494 - mean_absolute_error: 0.1207 - val_loss: 0.0828 - val_mean_absolute_error: 0.1721 - learning_rate: 1.0000e-04
# Epoch 43/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0480 - mean_absolute_error: 0.1182 - val_loss: 0.0832 - val_mean_absolute_error: 0.1730 - learning_rate: 1.0000e-04
# Epoch 44/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0464 - mean_absolute_error: 0.1159 - val_loss: 0.0822 - val_mean_absolute_error: 0.1712 - learning_rate: 1.0000e-04
# Epoch 45/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0453 - mean_absolute_error: 0.1141 - val_loss: 0.0788 - val_mean_absolute_error: 0.1671 - learning_rate: 1.0000e-04
# Epoch 46/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0447 - mean_absolute_error: 0.1135 - val_loss: 0.0805 - val_mean_absolute_error: 0.1698 - learning_rate: 1.0000e-04
# Epoch 47/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0439 - mean_absolute_error: 0.1117 - val_loss: 0.0812 - val_mean_absolute_error: 0.1713 - learning_rate: 1.0000e-04
# Epoch 48/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0428 - mean_absolute_error: 0.1098 - val_loss: 0.0773 - val_mean_absolute_error: 0.1652 - learning_rate: 1.0000e-04
# Epoch 49/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0423 - mean_absolute_error: 0.1094 - val_loss: 0.0779 - val_mean_absolute_error: 0.1666 - learning_rate: 1.0000e-04
# Epoch 50/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0417 - mean_absolute_error: 0.1090 - val_loss: 0.0770 - val_mean_absolute_error: 0.1646 - learning_rate: 1.0000e-04
# Epoch 51/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0406 - mean_absolute_error: 0.1067 - val_loss: 0.0757 - val_mean_absolute_error: 0.1635 - learning_rate: 1.0000e-04
# Epoch 52/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0404 - mean_absolute_error: 0.1068 - val_loss: 0.0765 - val_mean_absolute_error: 0.1652 - learning_rate: 1.0000e-04
# Epoch 53/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0397 - mean_absolute_error: 0.1058 - val_loss: 0.0756 - val_mean_absolute_error: 0.1645 - learning_rate: 1.0000e-04
# Epoch 54/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0390 - mean_absolute_error: 0.1043 - val_loss: 0.0756 - val_mean_absolute_error: 0.1653 - learning_rate: 1.0000e-04
# Epoch 55/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0381 - mean_absolute_error: 0.1032 - val_loss: 0.0755 - val_mean_absolute_error: 0.1649 - learning_rate: 1.0000e-04
# Epoch 56/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0377 - mean_absolute_error: 0.1028 - val_loss: 0.0758 - val_mean_absolute_error: 0.1637 - learning_rate: 1.0000e-04
# Epoch 57/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0368 - mean_absolute_error: 0.1012 - val_loss: 0.0769 - val_mean_absolute_error: 0.1676 - learning_rate: 1.0000e-04
# Epoch 58/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0367 - mean_absolute_error: 0.1010 - val_loss: 0.0756 - val_mean_absolute_error: 0.1656 - learning_rate: 1.0000e-04
# Epoch 59/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0368 - mean_absolute_error: 0.1015 - val_loss: 0.0742 - val_mean_absolute_error: 0.1641 - learning_rate: 1.0000e-04
# Epoch 60/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0359 - mean_absolute_error: 0.1002 - val_loss: 0.0731 - val_mean_absolute_error: 0.1610 - learning_rate: 1.0000e-04
# Epoch 61/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0355 - mean_absolute_error: 0.0998 - val_loss: 0.0719 - val_mean_absolute_error: 0.1597 - learning_rate: 1.0000e-04
# Epoch 62/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0351 - mean_absolute_error: 0.0990 - val_loss: 0.0767 - val_mean_absolute_error: 0.1647 - learning_rate: 1.0000e-04
# Epoch 63/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0343 - mean_absolute_error: 0.0972 - val_loss: 0.0726 - val_mean_absolute_error: 0.1609 - learning_rate: 1.0000e-04
# Epoch 64/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0340 - mean_absolute_error: 0.0969 - val_loss: 0.0734 - val_mean_absolute_error: 0.1630 - learning_rate: 1.0000e-04
# Epoch 65/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0335 - mean_absolute_error: 0.0963 - val_loss: 0.0743 - val_mean_absolute_error: 0.1660 - learning_rate: 1.0000e-04
# Epoch 66/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 162ms/step - loss: 0.0335 - mean_absolute_error: 0.0961 - val_loss: 0.0727 - val_mean_absolute_error: 0.1629 - learning_rate: 1.0000e-04
# Epoch 67/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0325 - mean_absolute_error: 0.0951 - val_loss: 0.0705 - val_mean_absolute_error: 0.1587 - learning_rate: 5.0000e-05
# Epoch 68/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 161ms/step - loss: 0.0308 - mean_absolute_error: 0.0913 - val_loss: 0.0695 - val_mean_absolute_error: 0.1570 - learning_rate: 5.0000e-05
# Epoch 69/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0295 - mean_absolute_error: 0.0896 - val_loss: 0.0685 - val_mean_absolute_error: 0.1578 - learning_rate: 5.0000e-05
# Epoch 70/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0286 - mean_absolute_error: 0.0885 - val_loss: 0.0685 - val_mean_absolute_error: 0.1569 - learning_rate: 5.0000e-05
# Epoch 71/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0280 - mean_absolute_error: 0.0879 - val_loss: 0.0686 - val_mean_absolute_error: 0.1575 - learning_rate: 5.0000e-05
# Epoch 72/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0275 - mean_absolute_error: 0.0875 - val_loss: 0.0684 - val_mean_absolute_error: 0.1574 - learning_rate: 5.0000e-05
# Epoch 73/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0268 - mean_absolute_error: 0.0870 - val_loss: 0.0667 - val_mean_absolute_error: 0.1555 - learning_rate: 5.0000e-05
# Epoch 74/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 159ms/step - loss: 0.0267 - mean_absolute_error: 0.0872 - val_loss: 0.0656 - val_mean_absolute_error: 0.1562 - learning_rate: 5.0000e-05
# Epoch 75/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 159ms/step - loss: 0.0264 - mean_absolute_error: 0.0869 - val_loss: 0.0675 - val_mean_absolute_error: 0.1563 - learning_rate: 5.0000e-05
# Epoch 76/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0257 - mean_absolute_error: 0.0859 - val_loss: 0.0705 - val_mean_absolute_error: 0.1601 - learning_rate: 5.0000e-05
# Epoch 77/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0256 - mean_absolute_error: 0.0864 - val_loss: 0.0658 - val_mean_absolute_error: 0.1561 - learning_rate: 5.0000e-05
# Epoch 78/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0251 - mean_absolute_error: 0.0855 - val_loss: 0.0660 - val_mean_absolute_error: 0.1574 - learning_rate: 5.0000e-05
# Epoch 79/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0249 - mean_absolute_error: 0.0850 - val_loss: 0.0657 - val_mean_absolute_error: 0.1562 - learning_rate: 5.0000e-05
# Epoch 80/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0245 - mean_absolute_error: 0.0844 - val_loss: 0.0649 - val_mean_absolute_error: 0.1555 - learning_rate: 2.5000e-05
# Epoch 81/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 159ms/step - loss: 0.0236 - mean_absolute_error: 0.0828 - val_loss: 0.0644 - val_mean_absolute_error: 0.1548 - learning_rate: 2.5000e-05
# Epoch 82/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0231 - mean_absolute_error: 0.0821 - val_loss: 0.0641 - val_mean_absolute_error: 0.1541 - learning_rate: 2.5000e-05
# Epoch 83/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0229 - mean_absolute_error: 0.0818 - val_loss: 0.0643 - val_mean_absolute_error: 0.1546 - learning_rate: 2.5000e-05
# Epoch 84/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0223 - mean_absolute_error: 0.0809 - val_loss: 0.0657 - val_mean_absolute_error: 0.1550 - learning_rate: 2.5000e-05
# Epoch 85/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0222 - mean_absolute_error: 0.0810 - val_loss: 0.0644 - val_mean_absolute_error: 0.1540 - learning_rate: 2.5000e-05
# Epoch 86/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0217 - mean_absolute_error: 0.0799 - val_loss: 0.0634 - val_mean_absolute_error: 0.1538 - learning_rate: 2.5000e-05
# Epoch 87/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0217 - mean_absolute_error: 0.0803 - val_loss: 0.0647 - val_mean_absolute_error: 0.1544 - learning_rate: 2.5000e-05
# Epoch 88/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0213 - mean_absolute_error: 0.0799 - val_loss: 0.0640 - val_mean_absolute_error: 0.1538 - learning_rate: 2.5000e-05
# Epoch 89/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 159ms/step - loss: 0.0213 - mean_absolute_error: 0.0799 - val_loss: 0.0643 - val_mean_absolute_error: 0.1544 - learning_rate: 2.5000e-05
# Epoch 90/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - loss: 0.0209 - mean_absolute_error: 0.0792 - val_loss: 0.0643 - val_mean_absolute_error: 0.1541 - learning_rate: 2.5000e-05
# Epoch 91/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0209 - mean_absolute_error: 0.0794 - val_loss: 0.0645 - val_mean_absolute_error: 0.1546 - learning_rate: 2.5000e-05
# Epoch 92/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0206 - mean_absolute_error: 0.0789 - val_loss: 0.0627 - val_mean_absolute_error: 0.1535 - learning_rate: 1.2500e-05
# Epoch 93/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0203 - mean_absolute_error: 0.0782 - val_loss: 0.0630 - val_mean_absolute_error: 0.1531 - learning_rate: 1.2500e-05
# Epoch 94/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0200 - mean_absolute_error: 0.0778 - val_loss: 0.0630 - val_mean_absolute_error: 0.1530 - learning_rate: 1.2500e-05
# Epoch 95/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0197 - mean_absolute_error: 0.0773 - val_loss: 0.0623 - val_mean_absolute_error: 0.1529 - learning_rate: 1.2500e-05
# Epoch 96/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0197 - mean_absolute_error: 0.0773 - val_loss: 0.0625 - val_mean_absolute_error: 0.1526 - learning_rate: 1.2500e-05
# Epoch 97/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - loss: 0.0197 - mean_absolute_error: 0.0773 - val_loss: 0.0625 - val_mean_absolute_error: 0.1526 - learning_rate: 1.2500e-05
# Epoch 98/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0192 - mean_absolute_error: 0.0765 - val_loss: 0.0622 - val_mean_absolute_error: 0.1525 - learning_rate: 1.2500e-05
# Epoch 99/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0193 - mean_absolute_error: 0.0767 - val_loss: 0.0623 - val_mean_absolute_error: 0.1523 - learning_rate: 1.2500e-05
# Epoch 100/100
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 48s 157ms/step - loss: 0.0192 - mean_absolute_error: 0.0766 - val_loss: 0.0629 - val_mean_absolute_error: 0.1526 - learning_rate: 1.2500e-05
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step
# 2024-12-13 20:57:44.576019: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Saved final predictions to predictions/final_predictions.csv

# %% [markdown]
# ## Results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("predictions/final_predictions.csv")

data['Actuals'] = data['Actuals'].apply(lambda x: np.array(eval(x)))
data['Predictions'] = data['Predictions'].apply(lambda x: np.array(eval(x)))

# give an index to check
actuals = data['Actuals'].values[64]
predictions = data['Predictions'].values[64]

plt.figure(figsize=(10, 6))
plt.plot(range(len(actuals)), actuals, label="Actuals", color="blue")
plt.plot(range(len(predictions)), predictions, label="Predictions", color="orange")
plt.title("Actuals vs Predictions (0-99)")
plt.xlabel("Index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("predictions/final_predictions.csv")

data['Actuals'] = data['Actuals'].apply(lambda x: np.array(eval(x)))
data['Predictions'] = data['Predictions'].apply(lambda x: np.array(eval(x)))

# give an index to check
actuals = data['Actuals'].values[1000]
predictions = data['Predictions'].values[1000]

plt.figure(figsize=(10, 6))
plt.plot(range(len(actuals)), actuals, label="Actuals", color="blue")
plt.plot(range(len(predictions)), predictions, label="Predictions", color="orange")
plt.title("Actuals vs Predictions (0-99)")
plt.xlabel("Index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()
