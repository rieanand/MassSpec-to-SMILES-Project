# %% [markdown]
# # SMILES Autoencoder
#
# Replicating SMILES autoencoder in this article:
# https://www.nature.com/articles/s42004-023-00932-3#Sec19
#
# Supplementary material for above paper:
# https://static-content.springer.com/esm/art%3A10.1038%2Fs42004-023-00932-3/MediaObjects/42004_2023_932_MOESM1_ESM.pdf
#
# Model architecure and training details from above supplementary material:
#
# • Bidirectional GRU with an encoder-decoder architecture and
# – number of encoder and decoder layers: 3
# – hidden dimension for encoder and decoder: 512
# – Dimensionality of the embedding space: 512
# – nonlinearity: tanh
#
# Training Hyperparameters:
# • Batch size: 256
# • Learning rate: 0.0001
#
# Training - The autoencoder is trained as a translation model by translating from a randomized SMILES version of a molecule
# to its canonical version. The model is trained on 135M molecules from Pubchem and ZINC12 datasets.
# The architecture of the translation model and latent dimension of 512 is similar to the one used in Winter et al.
# In order to make the learnt representations more meaningful, we also jointly trained a regression model to predict some
# molecular properties that can be calculated using the molecular structure. The regression model uses two fully connected layers
# with dimensions 512 and 128 and ReLU non-linearity. The properties that are predicted are: logP, molar refractivity, number
# of valence electrons, number of hydrogen bond donors and acceptors, Balaban’s J value, topological polar surface area, drug
# likeliness (QED) and synthetic accessibility (SA).

# %% [markdown]
# - try mol2vec

# %%
# IMPORT NECESSARY PACKAGES
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import seaborn as sns
np.random.seed(42)

# %%
# LOAD DATASETS AND PAD SMILES STRINGS TO LEN=77

# load dataset
in_random_smiles_df = pd.read_csv('dataset/smiles.csv')     # smiles.csv file with 706863 rows
out_canon_smiles_df = pd.read_csv('dataset/sanitized_smiles.csv')       # sanitized_smiles.csv file with 706863 rows
out_canon_smiles_df.rename(columns={'SMILES': 'smiles'}, inplace=True)

# calculate the length of each string in the 'smiles' column
in_random_smiles_df['length'] = in_random_smiles_df['smiles'].apply(len)
out_canon_smiles_df['length'] = out_canon_smiles_df['smiles'].apply(len)

# filter dataframes to only keep input random SMILES with length 77 or less
in_filtered_random_smiles_df = in_random_smiles_df[in_random_smiles_df['length'] <= 77]
out_filtered_canon_smiles_df = out_canon_smiles_df.loc[in_filtered_random_smiles_df.index]

# filter dataframes to only keep output random SMILES with length 77 or less
out_filtered_canon_smiles_df = out_filtered_canon_smiles_df[out_filtered_canon_smiles_df['length'] <= 77]
in_filtered_random_smiles_df = in_filtered_random_smiles_df.loc[out_filtered_canon_smiles_df.index]

# pad the strings in the 'smiles' column to the desired length using " "
max_length = 77

in_filtered_random_smiles_df['smiles_padded'] = in_filtered_random_smiles_df['smiles'].apply(lambda x: x.ljust(max_length, ' '))
out_filtered_canon_smiles_df['smiles_padded'] = out_filtered_canon_smiles_df['smiles'].apply(lambda x: x.ljust(max_length, ' '))

# Find the maximum length
max_length_random = in_filtered_random_smiles_df['length'].max()
max_length_canon = out_filtered_canon_smiles_df['length'].max()

# Print the maximum length
print(f"The maximum length of a string in the input random 'smiles' column is: {max_length_random}")
print(f"The maximum length of a string in the output canon 'smiles' column is: {max_length_canon}")

print(f"Number of SMILES sequences for input random dataframe: {len(in_filtered_random_smiles_df)}")
print(f"Number of SMILES sequences for output canonical dataframe: {len(out_filtered_canon_smiles_df)}")
# Out:
# The maximum length of a string in the input random 'smiles' column is: 77
# The maximum length of a string in the output canon 'smiles' column is: 77
# Number of SMILES sequences for input random dataframe: 650200
# Number of SMILES sequences for output canonical dataframe: 650200

# %%
# TOKENIZE SMILES STRINGS (CONVERT STRING OF CHARACTERS TO LIST OF FLOATS), CONVERT TO INPUT/OUTPUT TENSORS, SAMPLE 5 SMILES SEQUENCES

# Convert SMILES strings to list of characters tokens
in_filtered_random_smiles_df['smiles_tokenized_lists'] = in_filtered_random_smiles_df['smiles_padded'].apply(lambda x: list(x))
out_filtered_canon_smiles_df['smiles_tokenized_lists'] = out_filtered_canon_smiles_df['smiles_padded'].apply(lambda x: list(x))

# combines each list of SMILES characters into one list
flattened_list_all_random_smiles = [item for sublist in in_filtered_random_smiles_df['smiles_tokenized_lists'] for item in sublist]
flattened_list_all_canon_smiles = [item for sublist in out_filtered_canon_smiles_df['smiles_tokenized_lists'] for item in sublist]

# get unique characters
unique_characters_random = set(flattened_list_all_random_smiles)
unique_characters_canon = set(flattened_list_all_canon_smiles)

# convert back to list
unique_characters_random = list(unique_characters_random)
unique_characters_canon = list(unique_characters_canon)

# make one unique characters list
unique_characters = unique_characters_random + unique_characters_canon
unique_characters = set(unique_characters)
unique_characters = list(unique_characters)
#unique_characters = sorted(unique_characters)
print(f"Number of unique characters: {len(unique_characters)}")

# mapping from characters to integers
char_to_int = {char: i for i, char in enumerate(unique_characters)}

# convert SMILES tokenized lists into integer lists
int_lists_random_smiles = [
    [char_to_int[char] for char in sublist]
    for sublist in in_filtered_random_smiles_df['smiles_tokenized_lists']
]

int_lists_canon_smiles = [
    [char_to_int[char] for char in sublist]
    for sublist in out_filtered_canon_smiles_df['smiles_tokenized_lists']
]

in_filtered_random_smiles_df['smiles_integer_lists'] = int_lists_random_smiles
out_filtered_canon_smiles_df['smiles_integer_lists'] = int_lists_canon_smiles

# convert the tokenized sequences to tensors
int_lists_random_smiles = in_filtered_random_smiles_df['smiles_integer_lists'].tolist()
int_lists_canon_smiles = out_filtered_canon_smiles_df['smiles_integer_lists'].tolist()

in_smiles_tensor = torch.tensor(int_lists_random_smiles, dtype=torch.float32)
out_smiles_tensor = torch.tensor(int_lists_canon_smiles, dtype=torch.float32)

print(f"Shape of input SMILES tensor: {in_smiles_tensor.shape}")
print(f"Shape of output SMILES tensor: {out_smiles_tensor.shape}")

# create random sample of tensors

# five random indices between 0 and 643167
random_indices = torch.randint(0, 643167, (1000,))

# take the random sample of five rows from each tensor
sample_in_smiles_tensor = in_smiles_tensor[random_indices]
sample_out_smiles_tensor = out_smiles_tensor[random_indices]

# Print shape of sampled rows
print(f"Shape of sampled input SMILES tensor: {sample_in_smiles_tensor.shape}")
print(f"Shape of sampled output SMILES tensor: {sample_out_smiles_tensor.shape}")
# Out:
# Number of unique characters: 64
# Shape of input SMILES tensor: torch.Size([650200, 77])
# Shape of output SMILES tensor: torch.Size([650200, 77])
# Shape of sampled input SMILES tensor: torch.Size([1000, 77])
# Shape of sampled output SMILES tensor: torch.Size([1000, 77])

# %%
print(char_to_int)
# Out:
# {'8': 0, '7': 1, 'l': 2, 't': 3, 'i': 4, 'A': 5, 'I': 6, 'O': 7, 'M': 8, 'n': 9, 'C': 10, 'W': 11, 'c': 12, '3': 13, ' ': 14, '+': 15, '9': 16, '1': 17, '%': 18, '/': 19, 'e': 20, '[': 21, '-': 22, '.': 23, 'p': 24, '<': 25, 'G': 26, '@': 27, 'P': 28, 'H': 29, '*': 30, 'r': 31, 'o': 32, 'L': 33, 'D': 34, 's': 35, '5': 36, 'K': 37, 'a': 38, '4': 39, 'S': 40, 'b': 41, 'Y': 42, 'R': 43, '>': 44, '2': 45, '(': 46, '\\': 47, ')': 48, 'u': 49, '6': 50, '#': 51, 'g': 52, 'B': 53, 'd': 54, 'Z': 55, 'N': 56, 'y': 57, '=': 58, ']': 59, '0': 60, 'T': 61, 'F': 62, 'V': 63}

# %%
print(f"Sampled input SMILES tensor: {sample_in_smiles_tensor}")
# Out:
# Sampled input SMILES tensor: tensor([[56., 56., 10.,  ..., 14., 14., 14.],
#         [ 7., 58., 10.,  ..., 14., 14., 14.],
#         [10.,  7., 12.,  ..., 14., 14., 14.],
#         ...,
#         [10.,  7., 10.,  ..., 14., 14., 14.],
#         [10., 21., 10.,  ..., 14., 14., 14.],
#         [ 7., 10., 46.,  ..., 14., 14., 14.]])

# %%
class bidirectional_GRU_AE(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers=3, embedding_dim=10):
        super(bidirectional_GRU_AE, self).__init__()

        # TEST WHETHER CHAR_TO_INT DICT IS NECESSARY WITH THIS
        # embedding layer to convert integer indices to dense float vectors
        self.embedding = nn.Embedding(input_size, embedding_dim)

        self.encoder = nn.GRU(
            input_size=embedding_dim, 
            hidden_size=hidden_size, 
            num_layers=num_layers, 
            bidirectional=True,
            # input and output tensors are (batch_size, seq_len) format
            batch_first = True      
        )

        self.decoder = nn.GRU(
            # for bidirectional GRU, input size is doubled (each hidden layer as forward and backward state)
            input_size=hidden_size * 2,     
            hidden_size=hidden_size, 
            num_layers=num_layers, 
            bidirectional=True, 
            batch_first = True
        )

        # fully connected layer
        # passing through Tanh activation function (self.tanh = nn.Tanh) for nonlinearity
        self.fc = nn.Sequential(
            nn.Linear(hidden_size * 2, input_size),  # Linear layer
            nn.Tanh(),  # Tanh activation
        )

    def prob_to_char_out(self, output):
        _, predicted_classes = torch.max(output, dim=2)
        return predicted_classes     

    def forward(self, x):
        # encoding
        # embed input integer indices to floating point vectors
        # after embedding, shape of x becomes (batch size, sequence length, embedding dimensions)
        x = self.embedding(x)

        # encoder_output shape is (batch size, sequence length, hidden_size * 2)
        # hidden shape is (num_layers * 2, batch size, hidden_size)
        encoder_output, hidden = self.encoder(x)
        
        # for bidirectional GRU, there are two separate hidden states for each hidden layer
        # forward state goes from start to end of sequence and backward state goes from end to start of sequence
        # we can concatenate forward and backward directions from last hidden layers or pass the hidden layers to the decoder directly
        # we are currently passing hidden layers to decoder directly

        # decoding
        # encoder_output has shape (batch size, sequence length, hidden_size * 2)
        # decoder output has shape (batch size, sequence length, hidden_size * 2)
        decoder_output, _ = self.decoder(encoder_output, hidden)
        print(f"Output shape after decoder: {decoder_output.shape}")

        # pass decoder output through the fully connected layer
        # output has shape of (batch size, sequence length, vocab size) = (5, 77, 64)
        output = self.fc(decoder_output)
        print(f"Output shape after fully connected layer: {output.shape}")

        # Define custom order of classes (e.g., reversing the class order)
        custom_order = list(range(64))
        custom_order = torch.tensor(custom_order)  # This means class 3 comes first, then class 2, etc.

        # Reorder the vocab_size dimension of the output tensor based on custom_order
        reordered_output = output[:, :, custom_order]

        predicted_classes = self.prob_to_char_out(reordered_output)
        print(f"Predicted classes: {predicted_classes}") 

        return reordered_output
    

def decode_smiles(tensor):
    decoded_smiles = []
    for sequence in tensor:
        smiles = ''.join([int_to_char[int(idx)] for idx in sequence if int(idx) in int_to_char])
        decoded_smiles.append(smiles.strip())  # Remove trailing spaces
    return decoded_smiles

# %%
# Hyperparameters
seq_len = 77
input_size = len(unique_characters)  # vocabulary size
embed_dim = 64    
hidden_dim = 64  
num_layers = 3
batch_size = 1000
learning_rate = 0.0001

# training data
input = sample_in_smiles_tensor.long()
target = sample_out_smiles_tensor.long()

# instantiate model
model = bidirectional_GRU_AE(input_size, hidden_dim, num_layers, embed_dim)

# optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss(ignore_index=char_to_int[' '])  # ignore " " padding indices

# training loop
losses = []
for epoch in range(10):
    model.train()
    optimizer.zero_grad()
    output = model(input)
    output = output.contiguous().view(-1, input_size)  # Flatten for loss calculation
    target = target.contiguous().view(-1)  # Flatten targets

    loss = criterion(output, target)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())

    print(f"Epoch [{epoch+1}/10], Loss: {loss.item():.4f}")

    # Decode and print the predicted SMILES
    model.eval()
    with torch.no_grad():
        predicted_indices = torch.argmax(output.view(batch_size, seq_len, input_size), dim=2)
        predicted_smiles = decode_smiles(predicted_indices)
        actual_smiles = decode_smiles(input)
        print("\nActual vs Predicted SMILES:")
        for actual, predicted in zip(actual_smiles, predicted_smiles):
            print(f"Actual: {actual}")
            print(f"Predicted: {predicted}")
            print("-" * 30)

print(losses)
# Out:
# Output shape after decoder: torch.Size([1000, 77, 128])
# Output shape after fully connected layer: torch.Size([1000, 77, 64])
# Predicted classes: tensor([[34, 27, 27,  ..., 19, 33, 33],
#         [27, 27, 27,  ..., 33, 33, 33],
#         [46, 15, 27,  ..., 33, 33, 33],
#         ...,
#         [34, 47, 47,  ..., 33, 33, 33],
#         [46, 27, 27,  ..., 56, 56, 56],
#         [46, 47, 47,  ..., 33, 33, 33]])
# Epoch [1/10], Loss: 4.1792
#
# Actual vs Predicted SMILES:
# Actual: NNC(=O)/C(=C/c1ccc(Cl)cc1Cl)NC(=O)c1ccccc1
# Predicted: D@@@@@HHHHHH///////aaaaaaaaaa@@@@@@33333///////33333333333333333333////////LL
# ------------------------------
# Actual: O=C(N[C@@H](Cc1ccccc1)C(=O)O)c1cccnc1
# Predicted: @@@@@@@@@@@@@////////NNHHHHHH@@333/////////33333333333333333333333333333**LLL
# ------------------------------
# Actual: COc1ccccc1C(C(=O)NCc1ccccc1)N(C(=O)c1csnn1)C1CC1
# Predicted: (+@@@@/////NHHHH@@@@@////////GHHHHHHHHHH@@///////////////333333333////////LLL
# ------------------------------
# Actual: Cc1nc(NCC#N)nc(n1)n2c(Nc3cc[nH]n3)nc4ccccc24
# Predicted: (@@@@@@@@@@@@@@HHNNN@@@@@@@@\\\\\DDD@3333333/333333333333333333333/////////ao
# ------------------------------
# Actual: CC(=O)c1c(C)[nH]c(C(=O)OCC(=O)NCCc2ccc(Cl)cc2)c1C
# Predicted: (\@@@HHNNNN@@@@@@NNHHH\\\\\\\\@@@@@@@aNNN/333///////////3333333333333333**LLL
# ------------------------------
# Actual: COc1ccccc1CN(C)CCCOc2cccc(c2)C3=CC(=O)c4c(OC)c(OC)c(OC)cc4O3
# Predicted: (+@@@@@///aaaaaaaaa@@@@@@/NNNNNNNNNHHHHNNNNNNNNNNNNNNN@@@/////////////////LLL
# ------------------------------
# Actual: O=C(Cn1c(=O)oc2cc(S(=O)(=O)NC3CCCC3)ccc21)Nc1ccc(F)c(F)c1
# Predicted: (@\\\HNNNNHHHHNNNNNHHHHH\\\\\\\\\HHH//////////////////////////////333333**LLL
# ------------------------------
# Actual: CCCCN1CCC(CNC(=O)c2c3OCCCn3c4cc(O)ccc24)CC1
# Predicted: DD@@@BB@@@@@@@@HHH\\\\\\\\NNNNNNN@@3333////////////33333333333333333333333LLL
# ------------------------------
# Actual: Cc1occc1c2nc(N)c(OC[C@@H](N)Cc3c([nH]c4ccccc34)C(=O)N)cc2c5cnc6[nH]nc(C)c6n5
# Predicted: \\/////////N@@@@@@@@@@@@@@@@@@@@@@@@@@+//////GGGNNHH@@@@@@@@@@@@G\NNNNNNNNooL
# ------------------------------
# Actual: O=C1C=COc2ccc(OCc3cccc(c3)C#N)cc12
# Predicted: D\\\NNNHH@@@@@@@//////////@@@@/////////3333333333333333333333333333333///LLLL
# ------------------------------
# Actual: COc1cccc(N2C(=O)N(C[C@H](N)c3ccccc3)C(=O)N(Cc4ccccc4Cl)C2=O)c1F
# Predicted: \@@@@@@@@@@@@@@@@@@@@@@@///////////NNHH\\\@@@@@33aGGGNNNNN////////////////LLL
# ------------------------------
# Actual: CCN(CC)C(=O)C1CCC(CC1)N(Cc2ccc(cc2)C(=O)NCCC(=O)O)C(=O)Nc3ccc(OC(F)(F)F)cc3
# Predicted: DDD@@@@@@@@@\\\\\\\@@@@@@@@@@@///NNNNNNNNNNNNNHHHHHHHHH@@@@@@@NN/////@@@@@@LL
# ------------------------------
# Actual: CCOCCOC(=O)NCCCCCCNC(=O)OCCOCC
# Predicted: DDDDNNNN@@@@@@@@NNNNNNNNNNNNNN/////////3333333333333333333333333333333333*L1L
# ------------------------------
# Actual: O=C(Nc1cccc([N+](=O)[O-])c1)Nc1ccc2c(c1)OCCO2
# Predicted: (@@@@@@@@@@@@GGGGHH\\\\\///////////GGGNNNNNNL/////3333333333333333333333**LLL
# ------------------------------
# Actual: CCc1ccc2c(CN3CCOCC3)cc(=O)oc2c1
# Predicted: (@@@@@@@aaa\\\\\\NNNNNNNNH//////////33333333333333333333333333333/////////LLL
# ------------------------------
# Actual: CC1=[N+]([O-])C2(N)CCc3nonc3C2(O)C1
# Predicted: \@@@@HHHGG\\\\\\\\\\NNNNNNNNNNNN///////////33333333333333333333333////////ooN
# ------------------------------
# Actual: COc1ccc(C(c2sc3nc(C)nn3c2O)N2CCC(C(N)=O)CC2)cc1OC
# Predicted: (@@@@@@@/HHHNNNNNNNNNNNNNN@@@@@@NNN@@@@@@@@@@@//////////3333333333////////LLL
# ------------------------------
# Actual: CC(C)(C)OC(=O)Nc1ccc(cc1)c2onc(c2)C(=O)NCCCCCCC(=O)NO
# Predicted: DD\\NNNN\\HHHH@@/////////NNNNNNNNNNNN@@@@NNNNNNNN@@/////////////33333333**LLL
# ------------------------------
# Actual: CCN(CC)S(=O)(=O)c1cccc(C(=O)NN/C=C2\C=CC(=O)C(O)=C2O)c1
# Predicted: DD@@@@@HHHHHHHHHH@@@@@HHHHH@@@@@@@@@@@NNNHHHHHHHHHH////////////3333333333*LLN
# ------------------------------
# Actual: CCCCN1CCc2c(N)c3cc(Br)ccc3nc12
# Predicted: D\\\@@@@@@@@//////////333333//////3333333333333333333333333333333333333333LLL
# ------------------------------
# Actual: C/C(=N\NC(=O)c1ccccc1NC(=O)c1ccc(Cl)cc1)c1ccncc1
# Predicted: /@@@@@@@@@////////////////////////////////////////////3333333333333////////LN
# ------------------------------
# Actual: COC(=O)c1cccc(N)c1CN1CCCCC1
# Predicted: D\\\\HH///////////@@@///LLL/////////333333333333333333333333333333333333**LLL
# ------------------------------
# Actual: Clc1ccc(/C=C/c2ncc3ccccn23)cc1
# Predicted: (+@////////HH//////////////////////333333333333333333333333333333//////////LL
# ------------------------------
# Actual: COc1ccc(OC)c(S(=O)(=O)Nc2ccccc2SC)c1
# Predicted: (@@@@@@@NNNHHHHHHHHHHH@@@3333///////////////3333333333333333333333////////LLL
# ------------------------------
# Actual: CCCCCOC(=O)C1=C(C)N(C)C(=O)NC1c1cc(Br)c(O)c(OC)c1
# Predicted: DDDNNNNNHHHHNNNN@@@@@@@@@\\\@@@///////@@@@@@@@3/////////333333333333333333L1L
# ------------------------------
# Actual: O=C([C@@H]1CC1(c1ccccc1)c1ccccc1)N1CCOCC1
# Predicted: (@@@@@@@@///////////////////////GGGNNNLL//////////3333333333333333333333**LLL
# ------------------------------
# Actual: COc1ccc(-n2c(C)nc3sc4c(c3c2=O)CCCC4)cc1
# Predicted: (@@///////NNNNNNNNNNNNNNNNNNNNNNNNN///////////33333333333333333333////////LLL
# ------------------------------
# Actual: O=C(COC(=O)CNC(=O)c1ccc(Cl)c([N+](=O)[O-])c1)NCC1CCCO1
# Predicted: D@@\\\\\\\\\HHHHHHH//aaaaaaaaGGGGGHH\\\\GGGG@@@@@@LLLLL//////////3333333**LLL
# ------------------------------
# Actual: CC(C)CCn1c(/C=C/c2ccccc2)nc2ccccc21
# Predicted: DD\\\NNNNNNHHHHH///////NN33333333333333333333333333333333333333333333333**LLL
# ------------------------------
# Actual: CCc1cc(-c2nnc(SCC(=O)NC3CC3)n2C)cs1
# Predicted: (@/////////NNNNNNNN\\\\\\NNNLL@@///////////33333333333333333333333////////LLL
# ------------------------------
# Actual: Cc1cc(C)cc(-n2c(C)cc(C(=S)N3CCOCC3)c2C)c1
# Predicted: (/////////////NNN@@NNNNNGG\\\\\\NNNL////////////33333333333333333/////////GLL
# ------------------------------
# Actual: CNC(=S)N(CCc1cccc(C)c1)Cc1cc2cc(OC)c(OC)cc2[nH]c1=O
# Predicted: /@@@@@@@@@@//////////////////NNNNNNNNNN@@@@@@@@3/////////33333333333///////LN
# ------------------------------
# Actual: CC(C)CNC(=O)CCSc1nc(-c2ccc3c(c2)OCO3)cc(C(F)(F)F)n1
# Predicted: DD@@@@@@@@HHHHHHH//////////NNGGG\\\\\@NNNN////////////////333333333333333*LLL
# ------------------------------
# Actual: CC(C)(C)c1onc(n1)C(=O)[C@@H]2CCCN2C(=O)CNC(C)(C)CO
# Predicted: (/\\\NHHHNNNNNNNNNNHHHH@@@@@@@@@@@@@@@@@@@@NN@@N////////////333333333333**LLL
# ------------------------------
# Actual: CC(=O)N(CC1CCCO1)C1(C(=O)NC2CCCC2)CCCCC1
# Predicted: D@@@@@\\\\\\\\LLNNNNNH@@@@@@@NNNNN@LLLLLL/////////3333333333333333333333**LLL
# ------------------------------
# Actual: COc1cc(ccc1Nc2ncc(Cl)c(n2)c3cnc4cc(ccn34)C#N)N5CCN(CC5)C(=O)C
# Predicted: (+@/////////////NNNNNNNNNNNN@@@@@//GGGGGGGG@@@@@@@@@@@@@@@////////////////LLL
# ------------------------------
# Actual: C[C@]12CC[C@H]3[C@@H](CC[C@@]4(O)[C@@H](O)C(=O)CC[C@]34C)[C@@H]1CCC2=O
# Predicted: ///////gg@@@@@@@@@@@@@@@@//////@@@@@@@@@\\\\\\\\\\\//////@@@@@@@@@/////////NN
# ------------------------------
# Actual: CC1Cc2ccccc2N1C(=O)COC(=O)c1n[nH]c(=O)c2ccccc12
# Predicted: \\@@@@@@@@@@@NNNNNNN\\HHHHHHNNNHHHHHHH33333333/////333333333333333////////LLL
# ------------------------------
# Actual: Cc1ccc(C(C(=O)NC(C)(C)C)N(Cc2ccco2)C(=O)CCC(=O)Nc2ccccn2)cc1
# Predicted: (@@@@@@NNN@@@@@\\\\\\\@@@@@@@@NNNNNNNNNNNNNHHHH@@@@@@3333/////////////////GLL
# ------------------------------
# Actual: Cc1ccccc1NC(=O)NC1(C(=O)N2CCN(C)CC2)CCCCC1
# Predicted: (++////////@@@@HHHHHH@@@@@@@@@@@@@@@@@LLLLL/////////3333333333333/////////GLL
# ------------------------------
# Actual: COc1ccc(-n2nc(C(=O)NCC(=O)NC(C)C)c3ccccc3c2=O)c(OC)c1
# Predicted: (@@@////NNNNNNNN@@@@@@@@H\\\\\\H////////NNNNNNN@@@3/////////333333////////LLL
# ------------------------------
# Actual: CC(C)(C)CN([C@H]1CCNC1)C(=O)c2cccc(Cl)c2Cl
# Predicted: //\\\@@@@@@@@@@@@@@@///NHHH@@@@@@@NNN33333/33333333333333333333333333333**LLL
# ------------------------------
# Actual: O=C(NC(=S)Nc1ccccc1)c2ccccc2
# Predicted: @@@@@@///////////////333333333333333333333333333333333333333333333333333**LLL
# ------------------------------
# Actual: Clc1ccc2cnc(CCCCCCC(=O)c3ccccc3)n2n1
# Predicted: (+@@@@@@@@@@NNNNNNNNHHHHH@/////////////33333333333333333333333333//////////LL
# ------------------------------
# Actual: O=C1OCCC1=CN1CCCCC1
# Predicted: D\\\\\\@@@@@@@@LLLL/////////3333333333333333333333333333333333333333333//LLLL
# ------------------------------
# Actual: COC(c1ccccc1)c1nnc(CCC(=O)N2CCN(CCOc3ccccc3)CC2)o1
# Predicted: (\\@//////////NNNNNNNNNHH@@@@@@@@@@@@@@///NNNN////////////33333333333333**LLL
# ------------------------------
# Actual: CCCC(=O)N(Cc1cc2ccccc2[nH]c1=O)c1ccccc1OC
# Predicted: DD@@@@HH@@@@@@@@@@@@@@GGG\H/////333333/////////333333333333333333333333333LLL
# ------------------------------
# Actual: COCCCNC(=O)CSc1nc(-c2ccc(OC)cc2)[nH]c1-c1ccc(OC)cc1
# Predicted: DDD@@@@@@HHHHHH///////NNNNNNNNN\\\\\//////////////////////333333333333333*LLL
# ------------------------------
# Actual: c1ccc(Cn2nnc3c(NCC4CC4)ncnc32)cc1
# Predicted: (@@@@NNNNNNNN@@NNNNNNNNNNNN///////////333333333333333333333333333/////////GGL
# ------------------------------
# Actual: O=C(Cc1ccc(NS(=O)(=O)c2ccc(Cl)c(Cl)c2)cc1)NCCN1CCOCC1
# Predicted: (@@@@@@@//////HHHHHHHHH@aaaaaaaaaa////@@@@@@@@@@@LLLL///////////33333333**LLL
# ------------------------------
# Actual: CCCN(CCC)c1cc(C)nc2nc(-c3ccc(Cl)cc3)nn12
# Predicted: DDD@@@@@@///NNNNHHHH/////////NNNNNN////////3333333333333333333333333333333LLL
# ------------------------------
# Actual: Cc1ccc(-n2nc3ccc(NC(=O)c4cccc([N+](=O)[O-])c4C)cc3n2)cc1
# Predicted: (///////////@@@@@@@@@@@@@@@@aaGGGGGGGGGGGGGGGGN///////////////////////////GLL
# ------------------------------
# Actual: CC(=O)Nc1ccc(NC(=O)c2nc(S(=O)(=O)Cc3ccc(F)cc3)ncc2Cl)cc1
# Predicted: D@@@@@@@@@@@@@@@@HHHHHHHHHHHHHHHHHHH////////////333333//////////33333333**LLL
# ------------------------------
# Actual: COc1ccc(-c2noc(CSc3nc4sc(C)c(C)c4c(=O)n3-c3ccccc3)n2)cc1
# Predicted: (@@///////NNNNNNNNNGG/NNNNNNNNNNNNNHH\\\\//////////////////////333////////LLL
# ------------------------------
# Actual: CC(C)[C@H](NC(=O)OCc1ccc(Cl)cc1Cl)C(=O)NC(CC(=O)O)C(=O)CF
# Predicted: (\\@@@@@@@@@@@@@\\@@@@//aaaaaaaaaNNN@@@@\\NNNNNNNNNNNNN//////////////3333*LLL
# ------------------------------
# Actual: C/N=c1\sc2ccccc2n1C[C@@H](O)COCc1ccco1
# Predicted: @@@@@//+++++@@@@NNNNNN@@@@\\\@@@@@///////////33333333333333333333//////////oN
# ------------------------------
# Actual: CS(=O)(=O)Cn1cnc2c(nc(cc12)c3cnc(N)nc3)N4C5CCC4COC5
# Predicted: /@@@HHHHH\\HHHHHHHHHH///////NNNNNGGGGGGGGaaaNNNNNN////////3333333//////////aN
# ------------------------------
# Actual: Cc1cc(C)cc(NC(=O)c2nccnc2C(=O)O)c1
# Predicted: (///////@@@@@HHHHHHHNNNNNNNNNNN/////////3333333333333333333333333/////////GLL
# ------------------------------
# Actual: COC(=O)[C@@H]([C@H]1CCCCN1Cc2ccccc2)c3ccccc3
# Predicted: D\\\\\@@@@@@@@@@@@@@@@@@@////////////33333//////333333333333333333333333**LLL
# ------------------------------
# Actual: Cc1cc(C)cc(NC(=O)C2CCN(c3cc(C)nc4c(-c5ccc(Cl)cc5)c(C)nn34)CC2)c1
# Predicted: (//////@@@@@@@@\\\\\@@@@@@NNNN/////////////NGGNNNNNNNNNNNNNN//////////////GLL
# ------------------------------
# Actual: CCc1ncnc(c2cc(F)c(C(=O)N3CCC4(CC3)CNC4)c(F)c2)c1C#Cc5ccc(N)nc5
# Predicted: \\@@NNN////////@@@@@@@\\\\\aaaaaaaaa//////////@@@@@@@@@@@//////////////////LL
# ------------------------------
# Actual: Cc1cccn2c(=O)c3c(nc12)N1CCCCC1C1(C3)C(=O)N(C)C(=O)N(C)C1=O
# Predicted: (@@@//NNNHHHHHHHHHH//@@@@@@BLLLLNNNNN@@@@@@@@@@@@@@@@@////////////////////GLL
# ------------------------------
# Actual: O=C(O)Cn1nnnc1SCC(=O)Nc1ccc(OC(F)(F)F)cc1
# Predicted: (@\\\\\\HHH@@NNNNHHHH@@@@@@@////////3333////////333333333333333333333333**LLL
# ------------------------------
# Actual: Cn1c(-c2cc3c(C(F)(F)F)nn(C)c3s2)n[nH]c1=S
# Predicted: /////////////N////@@@@@@@@@@NNNNN@@@@/////////////3333333333333333/////////o1
# ------------------------------
# Actual: CCOc1cc(C2C(C(=O)N3CCCCC3)=C(C)NC3=C2C(=O)CC(C)(C)C3)ccc1O
# Predicted: D\@@@@@NNNNNN@@@\\\\\\NNNNNN@@@@@@NNNNNNNNNNN\\\\\H@//////////////////////LLL
# ------------------------------
# Actual: O=C(NCCCN1CCCCC1)c1ccc2c(c1)NC(=O)C(N1CCCCC1)S2
# Predicted: D@@@@@@@@@@@LLLL///////////GGG@@@@@@@@@@@///////////////3333333333333333**LLL
# ------------------------------
# Actual: O=C1NC(=Nc2ncccc12)CCCCCCCc3ccccc3
# Predicted: @@@@@@@@@@@@/////NNNNaaaaN@@@//////////333333333333333333333333333333////LLLo
# ------------------------------
# Actual: CC1CCN(C(c2cc3cc4c(cc3[nH]c2=O)OCO4)c2nnnn2CC2CCCO2)CC1
# Predicted: D\\\@@@@@@////////aaGGGGGNNNNNNNNNNNNNNNNNNNNNNNNLLLLLL///////////////////LLN
# ------------------------------
# Actual: COc1ccccc1NC(=O)CCSc1nnnn1C
# Predicted: (@@@@@@@///GG@HHHHHNNNNN////////3333333333333333333333333333333333////////LLL
# ------------------------------
# Actual: C(=N/Nc1nc2ccccc2s1)\c1cccn1CCOc1ccccc1
# Predicted: /@@@@@/////@@@3/////+++++aaaaa@@3333/////////3333333333333333333333//////**oo
# ------------------------------
# Actual: CC(C)(C)n1nnnc1C(c1ccc2ncccc2c1)N1CCSCC1
# Predicted: (\\\\\\\\HHHHHH@@////////3333/////////////////////3333333333333333333333**LLL
# ------------------------------
# Actual: C=C1CSc2nc(=O)c3c(C)c(C)sc3n21
# Predicted: D@@@NNNNNNNHHHHHNNNHHHHHN/////////33333333333333333333333333333333/////////LN
# ------------------------------
# Actual: CN(Cc1ccccc1)C(=O)c1cccc(NC(=O)Cc2ccc(NC(=O)C3CCCN(C(=O)c4ccccc4)C3)cc2)c1
# Predicted: \\@@//////////HHHHH@@@@@@@@@@H@@@@@@@@@@@@\\\\\\\NNHH@@@@@////////////////NNN
# ------------------------------
# Actual: O=S(=O)(NCCCCN1CCN(CC1)c2noc3ccccc23)c4cccc5scnc45
# Predicted: @@@@@@@@@@@@@@@@@@@@L/NNNNN////////GGG33333333333/333333333333333333/////**Lo
# ------------------------------
# Actual: CN(C(=S)NC(=O)/C=C/c1ccc(F)cc1)C1CCCCC1
# Predicted: /@@@@@@@@@HHHHHHHH///////////////NN/LLL/////////33333333333333333333/////**oN
# ------------------------------
# Actual: CCCCN(C(=O)CC1CCCC1)c1c(N)n(CCC)c(=O)[nH]c1=O
# Predicted: DD@@@@@@@@@\\\\NLLL//////N@@NNNNNNNNHH@@@@/////////33333333333333333333333L1L
# ------------------------------
# Actual: COc1ccc(-c2oc3ccccc3c2C(=O)OCc2ccc([N+](=O)[O-])cc2)cc1
# Predicted: (\/////////////////NNNNNNN\\@@@@@@@@GGGGH\\\\GG//3333////////33333////////LLL
# ------------------------------
# Actual: CCS(=O)(=O)c1ccc(O)c(NC(=O)CCCC(=O)O)c1
# Predicted: D@@/HHHHHHHHHHHHH@@@@@@@NNNNNNNNNHHH/////////333333333333333333333/////////LN
# ------------------------------
# Actual: COc1cccc(c1)S(=O)(=O)N(Cc2ccc(cc2F)N3CCN(CC3)C(=O)C)C4CCC4
# Predicted: (@@///////////HHHHHH\\\@@@@@/////@@@@@@@@\\NNNNNNNNNNNNNN/////////////////LLL
# ------------------------------
# Actual: Cc1nn(C(C)C(=O)NCC2CCCO2)c(C)c1[N+](=O)[O-]
# Predicted: (@@B@@@@@@@@@@@\\NNNNNNNNN@@@@@@@GGHHHH/////////333333333333333333/////////a1
# ------------------------------
# Actual: CCC(=O)N1CCc2cc(S(=O)(=O)N(C)c3ccc(OC)cc3OC)ccc21
# Predicted: D\\\\\@@@@@@@@@//HHHHHHH\\\\\@@@@@NNNNNNNN@@33333////33333333333333333333*LLL
# ------------------------------
# Actual: COCOc1c2c(c(OCOC)c3c(OCOC)cccc13)/C(=N/N[S+](=O)([O-])c1ccc(C)cc1)C1=C2CCCC1
# Predicted: \\\\\NNNNNNNN\\\\NNNNN\\@@@/////NNH@@@@@@@@HHHHH\\\\//////////////NNNNNNLLLLL
# ------------------------------
# Actual: CC1CC=CC2C1C(=O)N(Cc1ccccc1)C2c1ccc2ccccc2c1C=Cc1ccccc1
# Predicted: D\@@@NNNNNNN@@@@@@@@///////////////33333333333333333//////////3333333/////LLN
# ------------------------------
# Actual: COc1ccc(/N=C2\CCCN2CC(N)=O)cc1
# Predicted: (@@@@@@@@@@@@@@@@@@@@@@@@@//////////333333333333333333333333333333////////LLL
# ------------------------------
# Actual: Cc1nccc(NC(=O)C[N+]23CCC(CC2)[C@H](C3)OC(=O)C4(CCCCCC4)C5=CC=CC5)n1
# Predicted: (@@@@@@@@@@@@\\\\\\\\\\NNNN@@@@@@@\\\\\@@@@@@aaaaaaNNNNNNNNNNNN////////////LL
# ------------------------------
# Actual: Cc1ccc2oc(C(=O)Nc3ccc(S(=O)(=O)N(C)c4ccccc4)cc3)cc(=O)c2c1
# Predicted: (@@@//NNNNNHHH@@@@@////HHHHHH\\\\\@@@//////////////33333333///////////////GLL
# ------------------------------
# Actual: COc1ccc(C2Nc3ccccc3C(=O)N2CCO)cc1COc1ccc(NC(C)=O)cc1
# Predicted: (@@@@@//////3/////NNNHHH\\\\\@@@@@@@@@@@@@@////////////////3333333////////LLL
# ------------------------------
# Actual: CC(C)c1c(C(=O)N/N=C/c2cccc3ccccc23)nnn1-c1nonc1N
# Predicted: (\\@@///NNHHHHH@@@@/////////////NNNN\\NNNNNNN//////////33333333333333333**LLL
# ------------------------------
# Actual: CCCCn1c(=O)c(CCC(=O)OCC(=O)Nc2cc(Cl)ccc2OC)nc2ccccc21
# Predicted: D\\\NNNNNNNNNNNNNNNN\\\HHHH@@@@aaaNN@@NNNNNN@333333333//333333333333333333L1N
# ------------------------------
# Actual: COc1ccc(OCCn2c(=O)sc3ccccc32)cc1
# Predicted: (@@@@@@NNNNNNNNHHHHH/////////////////33333333333333333333333333333////////LLL
# ------------------------------
# Actual: COc1ccc2OC[C@H](Oc2c1)[C@@H]3CCCN3C
# Predicted: \@@@@@@@NN@@@@@@@@@@@@@@@@@@@@@/////////////3333333333333333333333////////LLL
# ------------------------------
# Actual: CC(C)Cn1cc(cn1)c2c[nH]c3ncc(nc23)c4ccncc4
# Predicted: (\\\\\HH/NNNNNNNN@GG\\\\HHHNNNNGG@@33333////3333333333333333333333333333**LLL
# ------------------------------
# Actual: CCC1CN(S(=O)(=O)c2cc(-c3cc(C)no3)ccc2OC)c2cc(Cl)ccc2O1
# Predicted: D@@@@@@@HHHHHHHHHH///////NNNNNNNNNNNNNNNNaaaaN@33333333333333333333///////LLN
# ------------------------------
# Actual: Cc1oc(cc1)c2nc(NC(=O)COc3ccc(F)cc3)cc(n2)c4nccs4
# Predicted: (//////////NNNNNNN\\\\\\H//////////NNNNN@@33333/////3333333333333/////////GLL
# ------------------------------
# Actual: CC(C)Sc1nc2c([nH]c3ccccc32)c(=O)n1C
# Predicted: ///////NNNNNN@\\\+///////NNNNNNN/////////33333333333333333333333333////////LL
# ------------------------------
# Actual: Cc1ccc2[nH]c(=O)c(CN(Cc3ccco3)Cc3nnnn3Cc3ccco3)cc2c1
# Predicted: (@@@@@@@@@@@@@@@@@\\\@////NNNNNNN\\\\\\NNNNNN////////////33333333/////////GLL
# ------------------------------
# Actual: CC(C)=C1C2C=CC1C1C(=O)N(c3ccc4c(c3)OCO4)C(=O)C21
# Predicted: (\\\@@@@NN@@@NNNNNHHHH@@@@@////GGGGGNNNNNNNNN33//////3333333333333333333**LLL
# ------------------------------
# Actual: COc1ccc(CC2CCOCC2)c(Nc3nc4ccccc4nc3NS(=O)(=O)C)c1
# Predicted: (@@@@@@NNNNNNNNNNN@@@@@@@@@@/////GGGGGGHHHHHH///////////3333333333////////LLL
# ------------------------------
# Actual: S=C(NCCc1ccccn1)Nc1ccc(Cl)c(Cl)c1
# Predicted: (@@@@@@@///////////////aGG/////////////333333333333333333333333333////////Gao
# ------------------------------
# Actual: CCC(=O)N1CCN(c2ccc(NC(=O)c3cc4ccccc4o3)cc2Cl)CC1
# Predicted: D\\\@\\@@@@@@@@@@@@@//HHHH/////////////GGGGNN////////////3333333333333333*LLL
# ------------------------------
# Actual: CC(C)[C@H](NC(=O)c1cccc(S(=O)(=O)N2CCOCC2)c1)C(=O)Nc1nc2ccccc2s1
# Predicted: D\\@@@@@@@@@@@@@@@///////HHHHHHH\\\\\\\NNNNNNNNHHHHH@@@@3333333////////33/LLL
# ------------------------------
# Actual: COc1ccccc1C(=O)Nc2ccc(cc2)C(=O)N3Cc4cccn4Cc5ccccc35
# Predicted: (+@@@//////HHHH@@@@@@///NNN\\\\\\a@aaaaaaa333333333333333333333333////////LLL
# ------------------------------
# Actual: CN(C)S(=O)(=O)c1ccc(NC(=O)COC(=O)C2COc3ccccc3O2)cc1
# Predicted: /@@///HHHHHHHHH@@@@@@NNNN\\\\\\\\\\\\\@@@333333333//////33333333333////////LN
# ------------------------------
# Actual: C/C(=N\NC(N)=S)c1ccc2c(c1)OCCO2
# Predicted: /@@@@@@@//////////////GNNNNNNNL/////333333333333333333333333333333/////////LN
# ------------------------------
# Actual: COc1ccc(S(=O)(=O)N2CCOCC2)cc1NC(=O)C1CCCN1C(=O)c1cccs1
# Predicted: (@@@@////HHHHHHH\\\\\\\@@@@@@@@@@@\\\\aNNNHH@@@@@33///////////3333////////LLL
# ------------------------------
# Actual: N#C/C(=C\c1ccco1)C(=O)NCC1CCCO1
# Predicted: D@@@@@@@@//////NNNNHH@@@@@@LLLLL////////33333333333333333333333333/////////NN
# ------------------------------
# Actual: Cc1nn(Cc2ccc(NC(=O)OCc3ccccc3)cc2Cl)c(C)c1CC(=O)O
# Predicted: D@\\@@@@@@@@@@NNH\\\\\H////////GGGaaa@@@NNNNNNN///////33333333333//////////Lo
# ------------------------------
# Actual: C[C@]1(CCSC(=N1)N)c2cc(NC(=O)c3ccc(Cl)cn3)ccc2F
# Predicted: //////////////////@@@@@@@//HH/////NNNNNN@3333333333333333333333333/////////oN
# ------------------------------
# Actual: COC(=O)c1ccc(NC(=O)c2c(NCc3ccc(C)o3)sc3c2CCCC3)cc1
# Predicted: D\\\\@@@@@@@@//HHHHH@@@@@@///////HHNNNNNNNNNL/////////////33333333333333**LLL
# ------------------------------
# Actual: COc1ccc(-c2ccc(-c3cc(=O)oc4cc(OC)c(OC)c(OC)c34)cc2)cc1F
# Predicted: (\/////////////////NNNNNNNNNNNNNNNNNNNNN\\NNN////33/////////333333////////LLL
# ------------------------------
# Actual: COc1cccc(NC(=O)C2CC(=O)OC23CCOC(C)(C)C3)c1
# Predicted: (@@@@@@@@@@@NHNNNNNNNN\\\\\\NNNNNNN@//////////////3333333333333333////////LLL
# ------------------------------
# Actual: CN(C)C(=O)[C@@H](NC(=O)N1C(=O)N(CCN2CCOCC2)c3ccccc13)C(C)(C)C
# Predicted: D@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\\\\\NNNN@/////////NNNNNN/////////////////LN
# ------------------------------
# Actual: COC1(CCc2ccc(OCc3ccc4ccccc4c3)cc12)c5cncs5
# Predicted: \\\\\@@@@@@aaaaa@++///////////////GG33333///3333333333333333333333333333**LLo
# ------------------------------
# Actual: CC(C)C[C@H](NC(=O)Cn1ccc2cc(ccc12)c3cccnc3)C(=O)O
# Predicted: D\\\@@@@@@@@@@@@\\\H@////////////////GNNNNNNNNNN////333333333333333333333*LLL
# ------------------------------
# Actual: [O-][N+](=O)c1cccc(\C=C\2/S\C(=N/c3nsc4ccccc34)\NC2=O)c1
# Predicted: \\\\\\\\//////@@@@@GGGGGGGGG@@@@//////////GGGGGGG333///////////////////////oo
# ------------------------------
# Actual: COc1ccccc1OCC(=O)NNC(=O)c1c(-c2ccccc2Cl)noc1C
# Predicted: (+@@@@@@@@NNN@@@@@@HHHHHHH/////33333NNNNNN///////////3333333333333////////LLL
# ------------------------------
# Actual: CN(Cc1cccc(O)c1)C(=O)c2ccc(s2)c3cccc(O)c3F
# Predicted: (@@@@////////HNNNHHHHHH@///////////////////333333333333333333333333////////LN
# ------------------------------
# Actual: CC1=NNC(=O)C1CC(=O)N/N=C/C(C)=C/c1ccccc1
# Predicted: @@@@@@@@@@HHHNNHHH@@@@@@@@@@@@////////////////33333333333333333333////////ooN
# ------------------------------
# Actual: Cc1ccc2nc(-c3ccc(SCC(=O)Nc4nnc(C)s4)nc3)[nH]c2c1
# Predicted: (@///////////////NNNNNH@@@@NNNNNNNNNNNNNG@@3333//////333333333333/////////GLL
# ------------------------------
# Actual: COc1cccc(NS(=O)(=O)c2cc3c(cc2C)N(C(C)=O)CCO3)c1
# Predicted: (@@@@@@/////HHHHHHHHHHH//@@@@@@@@NNNNNNHHHNL//////////333333333333////////LLL
# ------------------------------
# Actual: Cc1nn(C)c2NC(=O)C3=C(CSC3)c12
# Predicted: (@@\\@@@@@@@@@@@HHHHHH/////////////333333333333333333333333333333//////////LN
# ------------------------------
# Actual: CCC(CC)c1cc(C)n2N=C(NC(=O)c12)c3ccc(OC)cc3C
# Predicted: DD\\@@@@@@NNNN@@@@@@@@HHHHH/////@@@@@@@3//////////333333333333333333333333LLL
# ------------------------------
# Actual: CCn1nc(C)cc1C(=O)N1CCCC(C(=O)c2ccc3ccccc3c2)C1
# Predicted: D\\\NN@@@@@NNNH@@@@NNNNNNHHHHH///33333333////////////333333333333333///////11
# ------------------------------
# Actual: COc1cc(Br)c(CC(=O)NC(=N)N[C@H](CC(C)C)C(=O)NCc2cccc(c2)c3nnn[nH]3)cc1OC
# Predicted: \\@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@NNNNNH@@@@@@@@@/NNNNNN\\\\\\\@@@//////LLLL
# ------------------------------
# Actual: CC(C)c1nc(c2nccs2)c3sccc3n1
# Predicted: (\\\/HHHNHHHHH//N/3333//////////3333333333333333333333333333333333333333//LLL
# ------------------------------
# Actual: CCCCN1C(=O)S\C(=C/c2cc(Br)c(OCC=C(C)C)cc2OC)\C1=O
# Predicted: D@@@@@@@@@@@@@@@HH@@@@@@@@@@@@@@NNNN@@@@@@@@@N/////////3333333333333333333LLN
# ------------------------------
# Actual: COc1cccc(OCCNC(=O)C)c1
# Predicted: (@@@@@@@@@@@NNN@@@///////////3333333333333333333333333333333333333////////LLL
# ------------------------------
# Actual: CCOC(=O)c1ccc(NC(=O)CCCn2c(=O)c3cccn3c3cccnc32)cc1
# Predicted: DD\\\HH@@@@@@@@@NNN\NNNNNNNHHHHHHHHHH///33333333///////33333333333333333**LLL
# ------------------------------
# Actual: O=C(NCC(=O)N1CCN(Cc2ccccc2)CC1)c1ccc(Br)cc1
# Predicted: D@@@@@@@@@@@@@@@@@@@@@//////////////////////////333333333333333333333333**LLL
# ------------------------------
# Actual: CC(CC(=O)Nc1ccc2c(c1)OCO2)c1ccccc1
# Predicted: D\\\\@HH@@@@//////GNNN\\\@333333////////33333333333333333333333333333333**LLL
# ------------------------------
# Actual: COc1cc2CCN(CCc3ccc(NC(=O)c4cccc5ccccc45)cc3)Cc2cc1OC
# Predicted: D@@@@@@@@@@@@@@@@@@@////@@//////3///////G33333333//////////3333333////////LLL
# ------------------------------
# Actual: COc1ccc(Cl)cc1NC(=O)CSc1nc(=O)cc(-c2ccccc2)[nH]1
# Predicted: (@@@////aa@@@@@@@@HHHHHHHHHHHHHH///3333333@@33////////333333333333////////LLL
# ------------------------------
# Actual: Cc1cc(NC(=O)C2CCC(CNS(=O)(=O)c3ccc(Br)s3)CC2)ccc1Br
# Predicted: (@@@@@@@@@@@@@@@@@@@@HHHHHHHHHHHHHHH/////@@@33333///////3333333333////////GLL
# ------------------------------
# Actual: COC(=O)C(C)(C)ONC(=O)Nc1ccc(Br)cc1
# Predicted: DD\\\\\\\\\\\\\\\@@@@@@@@@@////////////333333333333333333333333333333333**LLL
# ------------------------------
# Actual: COc1ccccc1-c1noc(-c2ccc(N3CCOCC3)c([N+](=O)[O-])c2)n1
# Predicted: (+++/////////////////@@GG\\\\\\\a@@@@GGGGHGGGG////////////3333333/////////LLL
# ------------------------------
# Actual: COc1cc(CN(C)Cc2ccccc2)cc(OC)c1O
# Predicted: (@@@@@@@@@@@@@@@@@@/@@@@@@@3/////////33333333333333333333333333333////////LLL
# ------------------------------
# Actual: Brc1ccc(N2CCN(Cc3cccc(c3)C#N)CC2)c(NC(=O)C4=Cc5ccccc5O/C/4=N\c6ccccc6)c1
# Predicted: D@@@@@@@@@@@@@@////////GGG\@@@@@@@@@@@@@@@aaaaa@@@aGGGHH@@@////////////////aa
# ------------------------------
# Actual: N1c2ccccc2c3nnc(c4occc4)n3c5cccnc15
# Predicted: (@@//////GGNNNNNNNN/////GGG333333////3333333333333333333333333333/////////GGo
# ------------------------------
# Actual: CC(=O)Nc1cc(Cl)c(C(=O)Nc2ccnc(NC(=O)C3CC3)c2)c(Cl)c1
# Predicted: /@@@@@@@///aaaNNNNH@@@@@@@@@@@@@\\\\\\\\HHN////////////////3333333333333**LLL
# ------------------------------
# Actual: S=c1[nH]nc(-c2ccc(Cl)cc2)n1-c1cccnc1
# Predicted: (@@\\\\\\\////////NNN////33333333/////////33333333333333333333333////////GGGG
# ------------------------------
# Actual: Cc1ccc(C(=O)C2=C(O)C(=O)N(Cc3cccnc3)C2c2ccc(N(C)C)cc2)o1
# Predicted: (@@@@@NNNNHNNNNNNNHHHHH\\\\@@/////NNNN@@@@@@@/N@@@////////////////////////GLL
# ------------------------------
# Actual: CS(=O)(=O)N1CCC(C(=O)Nc2ccc(Cl)c(C(F)(F)F)c2)CC1
# Predicted: /@@@HHHH\\\\\NNNHHH@@@@@@@@@aNNNNN/////@@@@@@////////////33333333//////////aN
# ------------------------------
# Actual: Cc1ccc(-c2csc(NC(=O)c3ccc4c(=O)n5c(nc4c3)CCCCC5)n2)cc1
# Predicted: (////////////NNNNHHHH@@@///NNNGGGGGGGGNNNNNNNNNNL/////////////333/////////GLL
# ------------------------------
# Actual: Cc1c(C(=O)N2CCN(Cc3ccc4c(c3)OCO4)CC2)sc2ncnc(N3CCN(c4ccccc4F)CC3)c12
# Predicted: /@@/NNHHH@\\\\@@@@@@////GGGGGG\\NNNNNNNNNNN@@@\@@@@@@/////////////////////LLL
# ------------------------------
# Actual: CCCn1c(SCC(=O)NC2CCCCC2)nnc1-c1ccccn1
# Predicted: DD@@@NNNNNNNH@@NNNNNNNLLLLL//33333////////333333333333333333333333333333//L1N
# ------------------------------
# Actual: O=C(O)c1ccccc1[Se][Se]c1ccccc1C(=O)O
# Predicted: (\\\\@////////GGGGGG//////33//NN///////33333333333333333333333333333333/**LLL
# ------------------------------
# Actual: Cc1c(Cc2cccc(OCC(=O)O)c2)c3cc(OC(F)(F)F)ccc3n1C(=O)c4ccc(Cl)cc4
# Predicted: (@@/@+++@@@@NNNNNNHHHHHH@@@@@NNNN////@@@@@@@@NNNN@@@@@aaa3333/////////////GLL
# ------------------------------
# Actual: FC(F)(F)c1ccc(CNc2ccc(cc2)[C@H]3CNCCO3)cn1
# Predicted: //////@@@@@@@@@@////////@GG\\\\\\\\@LLL//////////33333333333333333/////////oo
# ------------------------------
# Actual: CCCCCC(C1=C(O)c2ccccc2OC1=O)C3=C(O)c4ccccc4OC3=O
# Predicted: DD\\NNNNNNNHHH@@@@@@@@\NNNN\\NHHHH@@@@33333333////333333333333333333333333L1L
# ------------------------------
# Actual: Cc1ccccc1CCN(CC(=O)NC1CCCCC1)C(=O)c1csnn1
# Predicted: (+++@@@@@aaa@@@@@@@@@@@NNNNNNNHH@@@@@@////////3333333333333333333/////////GLL
# ------------------------------
# Actual: CS(=O)(=O)Nc1ccc(OC[C@@H](O)CNCCc2cccc(O)c2)cc1
# Predicted: ////HHHHHH@@@@@@@@@@@@@@@@@\@@@@@@@@@/////3333//////33333333333333/////////aN
# ------------------------------
# Actual: Cc1cc(C)n2c(SCC(=O)Nc3ccccc3)nnc2n1
# Predicted: (@///NNNNNNNNNNNHHHH///////NNNN3//////333333333333333333333333333/////////GLL
# ------------------------------
# Actual: CN(Cc1ccccc1F)c1cc2c(c3c1ccn3C)C1CCC2O1
# Predicted: (@@@//////////////////////GG\\\NNNLLLLLL//////333333333333333333333////////LN
# ------------------------------
# Actual: O=C(c1ccco1)N1CCN(S(=O)(=O)c2cc(Cl)ccc2Cl)CC1
# Predicted: (@@@@/////////@@@@@HHHHHHHHHHHaaaaG@@@@NNN////////////3333333333333333///*LLL
# ------------------------------
# Actual: CC(C)(C)OC(=O)N\C(=N\C(=O)OC(C)(C)C)\NCCCC(=O)NCc1ccc(cc1)S(=O)(=O)N
# Predicted: D\\\NN\\\\@@@@@@@@@@@@@@@\\\\\\\\@@@@@@@@@@@@@@@@//////////NHHHHH/////////LLL
# ------------------------------
# Actual: CCN1CCN(CC1)C(CO)c2ccc(cc2)C#C[C@]3(CN4Cc5ccc(OC)cc5C4=O)NC(=O)NC3=O
# Predicted: D@@@@@@@@@NNNNNN@@@@@@//NNN\\\\\\aaaaaaaaa@@@NNNNNNNNNNNHHHHHHHHH/////////LLN
# ------------------------------
# Actual: COc1cc2c3c(n(CCCNCCCN)c(=O)c2cc1OC)-c1cc2c(cc1C3=O)OCO2
# Predicted: (@@@@@@@@@@@@@@@@@@@NNHHHHHHHHHH\\//////////NNNNNNNNNNL///33333333////////LLL
# ------------------------------
# Actual: CC(=O)NCC(=O)NC(C(=O)Nc1ccc2c(c1)OCCO2)c1ccccc1
# Predicted: D@@@@@@@@@@@@@@HHHHHH@@@/////GGNNNN\\\@@33333////////3333333333333333333**LLL
# ------------------------------
# Actual: COc1ccc2c(c1)c(Cc3cccc(OCC(=O)O)c3)c(C)n2C(=O)c4ccc(Cl)cc4
# Predicted: (@@////////////++++@@@NNNNNHHHHHHNNNNNNNNNNN@@@@@aaa33333/////33333///////LLL
# ------------------------------
# Actual: O=[N+]([O-])c1ccc(S(=O)(=O)NNc2ncccc2[N+](=O)[O-])cc1
# Predicted: @@@\\\\\\///////////HHHHHHH@@@@@@@@@@@GGGGGGGG/////////////333333333/////*LLo
# ------------------------------
# Actual: CN(NC(=O)c1ccccc1)c1nc2ccccc2nc1C(F)(F)F
# Predicted: D@@@@@/////////////////@@@@33////////////333333333333333333333333333/////**oN
# ------------------------------
# Actual: CCOc1ccccc1NC(=O)CCn1nc(C)c(S(=O)(=O)N2CCCCC2)c1C
# Predicted: \\@@@@@@@@//NNHHH\HHNNNNNNHHHHHHHHHHH\\\@@@@LL////////////33333333////////LLL
# ------------------------------
# Actual: COc1ccc(OC)c(-c2csc(NC(=O)C3COc4ccccc4O3)n2)c1
# Predicted: (@@@@@//HHHHH/@@@@NNNNN\\\\\\aaa@@////////////////3333333333333333////////LLL
# ------------------------------
# Actual: CN1C(=O)N(C)P(OCCN(CCOP2N(C)C(=O)N(C)C(=O)N2C)P2(=O)NCCCO2)N(C)C1=O
# Predicted: D@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\\HHHHHHHHHH@@@@@@@@@@@@@@@@@///////////LN
# ------------------------------
# Actual: O=C(C(Cl)Cl)N1CCN(Cc2ccc3c(c2)OCO3)CC1
# Predicted: (@\\\\\\\\\aaaaa@@@@@///NNGGGG\\\\NL///////////3333333333333333333333333**LLL
# ------------------------------
# Actual: Fc1ccc2c(noc2c1)C3CCN(CC4CC(=O)c5cnc(nc5C4)c6ccccc6)CC3
# Predicted: (@@@@@/NNNNNNNNNaaaaaaaaaNNNNHHHHHHNNNNGGG/////////////////////////////////Go
# ------------------------------
# Actual: CC1CCC2[C@@H](C)C(=O)OC3O[C@]4(C)CCC1C32OO4
# Predicted: D\\gggNN@@@@@@@@@\\\\\\\\\\@@@@@\\\NNNNNN///////3333333333333333333///////LLN
# ------------------------------
# Actual: CS(=O)(=O)OC1Cn2cc(C=O)c3ccc4c5ccccc5n(C1)c4c23
# Predicted: (@@@HHHH\\\\\NNNNNNNNHHH///////33333333333333////33333333333333333/////////aN
# ------------------------------
# Actual: CCOC(=O)N1CCN(Cc2nc3cc(NC(=O)CC(C)C)ccc3n2C)CC1
# Predicted: DD\\\\\\\@@@@@@@@@@@@@@@@@@N\\\NNNN@@@NNNNN/////////////3333333333333333**LLL
# ------------------------------
# Actual: COc1ccc(-c2csc(/C=C/c3ccc4c(c3)OCO4)n2)cc1OC
# Predicted: (@@////////////////////////GGGGGNNNNNN@@3//////////333333333333333////////LLL
# ------------------------------
# Actual: Nc1cnc(cn1)c2ccc(C3CCC3)c(OCc4ccc(Cl)cn4)c2F
# Predicted: (@@/////////@@@aaa\\\NNNaaaa@@aaaNNNNNN33333333333333333333333333//////////Go
# ------------------------------
# Actual: CC(O)c1cncc(c1)c2cc(F)c3c(CCc4nnc(C)n34)c2
# Predicted: (\\\\////////////////@@@@@@NNNNNNNNNNN////33333333333333333333333333333/**LLL
# ------------------------------
# Actual: CCN(CC)CCc1cc(C)c2NC(=O)\C(=N/NC(=O)C(C)c3ccc(F)cc3)\c2c1C
# Predicted: DDD@@@@@@@@//@@@@@@@@@@@@@@@@@@@@@\\\\\H//////////333333////////////33333*LLN
# ------------------------------
# Actual: Cc1cc(NC(=O)CSc2ccc(-c3ccc(F)cc3)nn2)no1
# Predicted: (@@@@/////HHH/////////////////NNNNNNNN///////33333333333333333333/////////GLL
# ------------------------------
# Actual: CCCCOc1cc(ccc1CNC(=O)C(C)c2ccc(NS(=O)(=O)C)c(F)c2)C(F)(F)F
# Predicted: DD\\@@@@@@@@@@@NNNHHHHH@@@@@@@@///HHHHHHHHHNNN@@@@@////////333///////33333LLL
# ------------------------------
# Actual: NC(=N)c1ccc(CNC(=O)[C@@H]2CCCN2C(=O)[C@@H](CC3CCCCC3)NCC(=O)O)cn1
# Predicted: /@@@@@@@@@@@@@@@HHH@@@@@@@@@@@@@@@@@@@@@@@@\\\\\\NNNNNNNN@@@@@@////////////LL
# ------------------------------
# Actual: COC(=O)CNC(=O)C1CCCN1C(=O)OC(C)(C)C
# Predicted: DD\\\\\\@@@H\\\\\NNNNNNNNNNNN@@@@///////////3333333333333333333333333333**LLL
# ------------------------------
# Actual: CCCCOc1ccc(CNC(=O)C2CCN(c3nnc(-n4cccc4CNc4ccc(C)cc4)s3)CC2)cc1
# Predicted: DDD@@@@@@@@@@@@@HH\\\@HHHHHHHNDDDDDD3333//////////GGGNNNN/////////////3333LLL
# ------------------------------
# Actual: COC(=O)C1=C(CSCc2ccco2)NC(=O)NC1c1cc(C)ccc1C
# Predicted: D\\\\\HHNNNN@@@NNNNNNNNN@@@@@@@////////////////////333333333333333333333**LLL
# ------------------------------
# Actual: CSc1ccccc1C(=O)C1CCCN(C(=O)c2cc(C(C)C)no2)C1
# Predicted: (//////////NHHH\aaaNN@@@@@@@@@NNNNNNNNNNN///////////3333333333333//////////aL
# ------------------------------
# Actual: Ic1cccc(c1)N2C(=O)C=CC2=O
# Predicted: (+////////NGGNN@@NNNNNNN///////333333333333333333333333333333333//////////GGL
# ------------------------------
# Actual: COc1ccc(\C=C\C(=O)CC(=O)\C=C\c2ccc(cc2[N+](=O)[O-])N(C)C)cc1O
# Predicted: (@@@@@@@@@GGGGHHHH\\\\\\\\@@@@@@@@@@@3GGGGGGGGG\\GG\\@@@@/////////////////LLL
# ------------------------------
# Actual: Cc1ccnc(NC(=O)CNC(=O)c2ccc3ccccc3c2)c1
# Predicted: (@@@@@@@@@@@@HHHHHHHHHH//333333333////////33333333333333333333333/////////GLL
# ------------------------------
# Actual: Cc1c2[nH]c3ccc(OCCN(C)C)cc3c2c(C)c2cnccc12
# Predicted: \@@@@\\@@@@@@@@@@\\\\\//////NNNNN@@33333//////3333333333333333333//////////LL
# ------------------------------
# Actual: CCCCOCC1CN(CCCC)S(=O)(=O)c2c(Oc3ccc(SC)c(C)c3)cccc2O1
# Predicted: DDDBBBB@@@@@@@NNNHHHHHHHHHHHH@@///////////////3333333333333333333333333333L1L
# ------------------------------
# Actual: COc1ccccc1NC(=O)C(=O)Nc1ccccn1
# Predicted: (@@@@@@@@//NNHHHHHHH@@@@@33/////////333333333333333333333333333333////////LLL
# ------------------------------
# Actual: CCN1CCC[C@H]1CNC(=O)C2=CN(C3CCCC3)C(=O)c4c2c5ccccc5n4C
# Predicted: D@@@gg@@@@@@@@@@@@@@@@@@@\\\\\\NNNNNNHH@aaa3333333333///333333333333//////LLN
# ------------------------------
# Actual: COc1cc2[C@@H]3CN(CCCC(=O)c4ccc(F)cc4)CC[C@@H]3N5CCN(C)c(c1)c25
# Predicted: \@@@@@@@@@@@@@@@@@@@@@@@@@//////////@@@@@@@@@@@@@@@@@@///////////3////////LLL
# ------------------------------
# Actual: Cn1c(CCc2nc3ccccc3[nH]2)nnc1SCC#N
# Predicted: (\\\NNNNNNNN@@@@NNNGGGGGG@@@@@@///////////3333333333333333333333333////////o1
# ------------------------------
# Actual: CN(C)c1ccc(C(C(=O)NCC2CCCO2)N(C(=O)c2snc(C(N)=O)c2N)c2ccccc2)cc1
# Predicted: /@@@@@@@@@@@NNHH@@\\NNNNNN@@@@@@@@@@HHNNNNNNNHHHH@@@@@33333333/////////////LN
# ------------------------------
# Actual: COC(=O)[C@@H](NCc1cccc(CN[C@H](C(=O)OC)c2ccccc2)c1)c1ccccc1
# Predicted: D\\\\\@@@@@@@@@@@@@@@@@@@@@@@@@@@H\\\\H@@@///////////333//////////3333333*LLL
# ------------------------------
# Actual: Cc1cc(C)nc(-n2nc(C)cc2NC(=O)c2ccc(S(=O)(=O)N3CCOCC3)cc2)n1
# Predicted: (////NNNNNNNNNNNNN@@@@@@@@@@@@@@//NHHHHHH\\\\\\\\NNN@/////////////////////GLL
# ------------------------------
# Actual: CC(=O)OCC1OC(C#Cc2ccc(C)cc2C)C=CC1OC(C)=O
# Predicted: DD\\\\\\\\\\\@@@@@@@@@@@@@NNNNNNNNNNNNN/////////333333333333333333333333**LLL
# ------------------------------
# Actual: CCN(C(=O)COC(=O)c1c2c(nc3ccccc13)CCC2)c1c(N)n(Cc2ccccc2)c(=O)[nH]c1=O
# Predicted: DD@@@@@HH\\HHHHHHHHH////////////NNNN/////NNN@@@@@@@33NNNNNNN@@@@@3////////LLN
# ------------------------------
# Actual: CC(=O)Nc1ccc(-c2ccnc3c2CC(C)(C(=O)Nc2ccc(C(C)C)cc2)O3)cc1
# Predicted: /\\@@@/////////////GNNNNNNNNNN@@@@@@@@@@NNNNNNNNNN/////////////////33333/*LLL
# ------------------------------
# Actual: Oc1cc(Cl)cc2cc(Br)cnc12
# Predicted: (@///aaaa@@@@@@@@33333/////333333333333333333333333333333333333333////////LLL
# ------------------------------
# Actual: COC(=O)c1ccc(NC(=O)CSc2ccc(-c3sc(-c4ccccc4)nc3C)nn2)cc1
# Predicted: D\\\\@@@@@@@@@//HHHHH/////////////////////GNNNNNNN////////////3333333333**LLL
# ------------------------------
# Actual: O=C(CC1CCCCC1)NCCS(=O)(=O)N1CCN(c2ccccc2)CC1
# Predicted: (@@\\@@NNNNLLL@@@@HHHHHHH\\\\@@@@@@@@33/////////////33333333333333333333**LLL
# ------------------------------
# Actual: COc1cc(NS(=O)(=O)c2ccc3c(c2)n(C)c(=O)n3C)cc(OC)c1
# Predicted: (@@@@@////HHHHHHHHHH///NNNNNNNNNNNNN\\\NNNNN@@//////////3333333333////////LLL
# ------------------------------
# Actual: CCc1cccc(NC(=O)CN(C)S(=O)(=O)c2ccc3[nH]c4c(c3c2)CCCC4)c1
# Predicted: (@@@@@@@@@@@@@@@@@HHHHHHHHHHHHH@@@GGGGGG////GGGNNNNN//////////////////////LLL
# ------------------------------
# Actual: CCCc1ccccc1Oc2cc(C)ncc2CN(C)C
# Predicted: (\@@/////////@NNNNN@@@@@@@////////////3333333333333333333333333333////////LLL
# ------------------------------
# Actual: ONC(=O)CCCCc1ccn(Cc2ccc(cc2)n3ccc4ccccc34)n1
# Predicted: DD@@@@\\\@@@@NNNN@@////////GGGG3333333/////////3333333333333333333333333**LLL
# ------------------------------
# Actual: COc1ccc(N2CC(NC(=O)c3ccc(S(=O)(=O)N4CCOCC4)cc3)CC2=O)cc1
# Predicted: (@@@@@@@@@@@@@@@@@@@@@///HHHHHHHHNaaaaaaNNNNNNNNNNN///////////////////////LLL
# ------------------------------
# Actual: COc1cc2c(ncnc2cc1OCCCN3CCCCC3)N4CCN(CC4)\C(=N/c5ccc(cc5)C(C)(C)C)\NC#N
# Predicted: \\@@@@NNNNH@@@@@Naaaaaaaaaaaaaa@@@@@@@@@@@@/////////////NNNN\@@@@@@@@//////LL
# ------------------------------
# Actual: CCOC(=O)c1c(C)[nH]c(C)c1S(=O)(=O)N(C)CC(=O)Nc1cccc(Cl)c1C
# Predicted: DD\\\HHHHNNNNN@@@@@H/////HHHHHHH\\\\\\HHHH@@@@@////////////////////333333*LLL
# ------------------------------
# Actual: COc1ccc(CNC(=O)CN2C(=O)CCn3nc(-c4cn(C)c5ccccc45)cc32)cc1
# Predicted: (@@@@@@@@@@@@HHHHHNNN\\\\\\NNNNN//NNN//3333////33333333///////3333////////LLL
# ------------------------------
# Actual: COc1ccc(-c2cnc(C)o2)cc1S(=O)(=O)Nc1c(C)cc(C)cc1C
# Predicted: (\@////////NNNNNNN/////NNHHHHHHHH@//////////////////////3333333333////////LLL
# ------------------------------
# Actual: CCN1C(=O)N(Cc2ccccc2F)C3(CCN(Cc4ccc(cc4)n5ccnc5)CC3)C1=O
# Predicted: D\@@@@@@@@@@@@@@@@/@@@@@@@@@@@@@///////GGGGGGGNNNNNNNN////////////////////LLN
# ------------------------------
# Actual: COc1ccc(N(CC(=O)NCC2CCCO2)C(=O)CCC(=O)Nc2nccs2)cc1
# Predicted: (@@@@@@@@@@@@@@@@\NNNNNNNNNNNNNNNNHHHH@@@@@@@///////////3333333333////////LLL
# ------------------------------
# Actual: CCOC(=O)C1C(c2ccccc2)N(C)OC1(O)C(F)(F)F
# Predicted: DD\\\\\\\\HH///@@@@GGG@\\\\\NNNN@@//////33333333333333333333333333333333**LLL
# ------------------------------
# Actual: O=C(Cc1cccs1)N/N=C/C=C/c1ccccc1
# Predicted: (@@@@@@////////@@@@@@@///////////////33333333333333333333333333333333333**LLL
# ------------------------------
# Actual: CN1CCc2c(C#N)c(N3CCCCC3)nc(NCc3ccccc3)c2C1
# Predicted: D@@@@@@@@@@@@@@@@\\\\NNNN@@@@///////////////////333333333333333333/////////LN
# ------------------------------
# Actual: C(N1CC[C@H](C1)Nc2cccc3cnccc23)c4cccc(c4)C5CC5
# Predicted: /\@@@@@@@@@@////////////////GGGGG@3//GGG/////////333333333333333333////////oN
# ------------------------------
# Actual: Cc1csc(CNC(=O)C2CCC(=O)N(CCc3cccc(F)c3)C2)n1
# Predicted: @@@@@@@NNNNNNNNNNNNN@@@@\@@@//////////////////////333333333333333/////////GLL
# ------------------------------
# Actual: COC(=O)c1ccc(Br)c(CSc2nc3ccccc3n2CC(=O)O)c1
# Predicted: D\\\\@@@@@@////////////////@NNNNNNNNNNH@/////////33333333333333333333333**LLL
# ------------------------------
# Actual: CN(C(=O)C=C)c1nc2c(Cc3ccc(F)c(Cl)c3)ncnc2cc1OCCCN4CCOCC4
# Predicted: D@@@@@HHHHHHHHHHH//////////////NNNNNNN@@@@@aNNNNNNNNNNN///////////33333/***oN
# ------------------------------
# Actual: CCNC(=O)Nc1nc2cc(C3=CC(=O)N(C)C(=C3)C)c(OCC4CCOC4)nc2s1
# Predicted: D@@@@@@@@@@@@@@@@NNNNNHHHH@\\\\\\\NNNNNaaaNNNNNNNNN@///////////33333333333LLN
# ------------------------------
# Actual: O=C1/C(=C/NNc2cccc3cccnc23)C=Cc2ccccc21
# Predicted: (@@@@@@@@@@@////////////NNNN@@@333333333/333333333333333333333333333//////LLo
# ------------------------------
# Actual: COc1ccc(N(CC(=O)NC2CCCC2)C(=O)Cn2nnc(-c3ccc(F)cc3)n2)cc1OC
# Predicted: (@@@@@@@@@@@@@@@@@@NNNNNNNNNNNNHHHHNN///////////////@@@///////////////////LLL
# ------------------------------
# Actual: COc1ccc(-n2nc([N+](=O)[O-])/c(=N/CCc3ccc(C)cc3)n2O)cc1
# Predicted: (@@@///NNNNH@@@@HHHHHHHHHH////@///////////NNNNNNN////////////33333////////LLL
# ------------------------------
# Actual: CCOC(=O)Cc1csc(SCc2nc3sc4c(c3c(=O)[nH]2)CCC4)n1
# Predicted: DD\\\@@@@@@@////NNNNNNNN//NNNNNNNGG\\\NNNNNN//////////333333333333333333**LLL
# ------------------------------
# Actual: CCOC(=O)c1ccc(N2C(=O)c3n[nH]c(C)c3C2c2ccccc2)cc1
# Predicted: DD\\\HHH@@@@@@@NNN@@\\\\\\\\\\\\\NNN3333333333///////3333333333333333333**LLL
# ------------------------------
# Actual: COc1ccc(Cc2n[nH]c(=O)c3ccccc23)cc1OC
# Predicted: (@@@@@@@NNNNNNNNHHHHHH///3333333//////////333333333333333333333333////////LLL
# ------------------------------
# Actual: COc1ccc(-n2c(=O)c3ccccc3n(CC(=O)Nc3ccccc3OC)c2=O)cc1
# Predicted: (@@//////////HHHH@@@@@/NNNN\HHHHH@@@@@@NNNNNNN@@33////////33333333////////LLL
# ------------------------------
# Actual: CN1CCc2cc(O)cc3c2[C@H]1Cc4ccc(O)c(O)c34
# Predicted: D\@@@@NNNNN@@@@@\\\\\@@@//////NNNNN333///3333333333333333333333333/////////LL
# ------------------------------
# Actual: C[C@H](NC(=O)OC(C)(C)C)[C@@H](O)c1ccco1
# Predicted: (@@@@@@@@@@@@\\\\\\NNNNN@@@@@@@@@@////////////33333333333333333333////////NNN
# ------------------------------
# Actual: CNS(=O)(=O)c1cccc(C(=O)OCC(=O)c2ccc(S(=O)(=O)N3CCCCC3)cc2)c1
# Predicted: D@@@/HHHHHHH@@@@@NNNNNNN\NHHHH@@@@//HHHHHHH\\\\\\\NNN//////////////////////NN
# ------------------------------
# Actual: Cc1nc2nc(C(F)(F)F)[nH]n2c(=O)c1Cc1ccccc1
# Predicted: (@@@@NNNNNNNN@@@@@@@@@@@@HHHHH/333333/////////3333333333333333333//////////Lo
# ------------------------------
# Actual: O[C@H]1C[C@@H](OC2(N(Cc3ccc(cc3)C#N)C(=O)c4ccccc24)c5ccc(Cl)cc5)C=C1
# Predicted: (\\\\@@@@@@@@@@@\\\@@@@///////GGG\\\\@@@@@@@//////GGGGGaaaGG33333/////////LLL
# ------------------------------
# Actual: CCOC(=O)C1(C)CCCN(C(=O)c2c(F)cccc2F)C1
# Predicted: DD\\\\\\\\NN@@@@@@@HHHHH//@@@333333//////////333333333333333333333333333**LLL
# ------------------------------
# Actual: Clc1ccc(-c2nnc(CSc3nnc(-c4cccs4)o3)o2)cc1
# Predicted: (++/////////NNNNNNNNNNNN/////NNNNNN////////////333333333333333333//////////LL
# ------------------------------
# Actual: Nc1nccn2c(nc(c3ccc4ccc(nc4c3)c5ccccc5)c12)[C@@H]6C[C@@H](C6)N7CCCCC7
# Predicted: @@@@@/NHHHHH////////////////////////////NNN@@@@@@@@@@@@@@@@@@@@@@N/////////GL
# ------------------------------
# Actual: Cc1ccc2cc3cc(C(=O)N4CCC5(CC4)OCCO5)oc3nc2c1
# Predicted: (+/////////NNNNN@@aaaaaaNNNNNNNNNNNNNN//////////33333333333333333/////////GLL
# ------------------------------
# Actual: CCC1CN2CCC1CC2[C@H](O)c3cc(nc4ccc(OC)cc34)c5ccc(Cl)cc5Cl
# Predicted: D\\\@@g@LLLLLLNN@@@@@@@@@@@@@////NNNN//////GGGaaaG33333333333333333333333/LLN
# ------------------------------
# Actual: Clc1ccc(Oc2ccc(OC[C@H]3CCCN3)cc2)cc1
# Predicted: (+++@@@@@@@@@@@@\\\\\\\\\/////////////////33333333333333333333333//////////LL
# ------------------------------
# Actual: NC(=O)c1ccccc1OCC(=O)N2CCc3ccccc3C2
# Predicted: (@@@@@@@@@@@@aNNNNHH\\\\@@@@@33/////////333333333333333333333333333///////*LL
# ------------------------------
# Actual: c1ccc2c(N3CCCC3)nc(-c3ccncc3)nc2c1
# Predicted: (@@////GG\\\\\NNH//////////N33333/////333333333333333333333333333/////////GGL
# ------------------------------
# Actual: CN(C)C[C@@H]1C[C@@H](C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(N)nccn26
# Predicted: /@@@@@@@@@@@@@//@@@///////////////////////////////////GG@@@@@@@@///////////LN
# ------------------------------
# Actual: CN1C[C@@H]2CCCC[C@@]2(C1)c3ccc(Cl)c(Cl)c3
# Predicted: D@@@@@@@@@@@@@@////////////////aGGNN/////////333333333333333333333/////////oN
# ------------------------------
# Actual: c1ccc([P+](c2ccccc2)(c2ccccc2)c2ccc([P+](c3ccccc3)(c3ccccc3)c3ccccc3)cc2)cc1
# Predicted: \+////////////////////333/////////////////////////////////////////////////aVV
# ------------------------------
# Actual: CCCCCNC(=O)Nc1c(C)cccc1CS(=O)CCn2cnc(c2C)c3ccccc3
# Predicted: DDD@@@@@@@@@////////////NNNNNNNNNNNNNNN///3333////////33333333333333333333LLL
# ------------------------------
# Actual: Cc1cc(OCc2nc(N)nc(N)c2-c2ccc(Cl)c(Cl)c2)ccc1[N+](=O)[O-]
# Predicted: (@@@@@@@NNNNN@@H////////////aaaaaaaaaaa333@@GGGGGGHH//////////333/////////GLL
# ------------------------------
# Actual: COc1ccc(-c2nnn(CC(=O)N(CCO)C(C(=O)NC3CCCC3)c3ccncc3)n2)cc1
# Predicted: (@@@////NNNNNNN@@@@@@@@\\\\\\\\\\\\\\\\\\HHH/////NNN//////////////////////LLL
# ------------------------------
# Actual: COc1ccc(OC)c(CCNC(=O)c2sc3nc4n(c(=O)c3c2C)CCC4)c1
# Predicted: (@@@@@@@@@@@@@@NHHHHHHHHNNNNNNNNHHHHNNNNNNNNN///////////3333333333////////LLL
# ------------------------------
# Actual: NC(=O)CSCc1cccc(Br)c1
# Predicted: D@@@@@@@@@@@//////////////33333333333333333333333333333333333333333//////**LL
# ------------------------------
# Actual: Nc1cnc(cn1)c2ccc(cc2F)c3ccccc3S(=O)(=O)N4CCC(O)(C4)c5ccccc5
# Predicted: (@@///////////////////333//////GHHHHHH@@NNNNNN\Na@@@3333333333333//////////Go
# ------------------------------
# Actual: N[C@@H](Cc1ccc(cc1)c2ccc(F)cc2F)C(=O)N3CCC[C@H]3C#N
# Predicted: (@@@@@@@////////////////////@@@@@@@@@\\\\@@@@]]]///////////3333333////////NNN
# ------------------------------
# Actual: O=C(NNS(=O)(=O)c1ccccc1F)c1cccc(S(=O)(=O)N2CCOCC2)c1
# Predicted: @@@@@@@HHHHHHHHH/////////////////HHHHHHH\\\\NN@LLL//////////33333333333/**LLL
# ------------------------------
# Actual: Cc1ccc(CN2CC[C@H](C2)NC(=O)CNC(=O)c3cc(ccc3N)C(F)(F)F)cc1
# Predicted: (@@@@@@@@@@@@@@@@@@@@@@@@@@\\HHHHHHH/////////////////33///////////////////GLL
# ------------------------------
# Actual: CCOc1ccccc1NC(=O)NS(=O)(=O)c1ccc(C)cc1
# Predicted: \\@@@@@@@@///@@HHHHHHHHHHHHH////////////////33333333333333333333333///////LLL
# ------------------------------
# Actual: COc1cccc(C(=O)CC(=O)C(=O)Nc2ccc(C)cc2Cl)c1
# Predicted: (@@@@@@@NNNNNNNNNHHHHHHHH@@@@@@@@@@333//////////333333333333333333////////LLL
# ------------------------------
# Actual: Cc1ccc(S(=O)(=O)N2CCCCC2)cc1NC(=O)COC(=O)C1(C)CC1(Cl)Cl
# Predicted: (@///////HHHHHH\\\\\NN@@@@@@@NNNNHH\\\\\\\\\\\\NNNNN//////////3///////////GLL
# ------------------------------
# Actual: COc1ccc2c(c1)CC/C(=C\Nc1ccc3c(c1)OCO3)C2=O
# Predicted: (@@@////////aaaaa@@@@@///////GGGGNNNNNNNN//////3333333333333333333////////LLL
# ------------------------------
# Actual: Oc1c(Cl)cc(cc1Cl)C2(OC(=O)c3cccc4cccc2c34)c5cc(Cl)c(O)c(Cl)c5
# Predicted: //////////aaaaaaNNN\\\\\\\\@@@/////////GGGGGGGaaNNNNNNNNNN/3333333////////LLL
# ------------------------------
# Actual: CN1CCc2c(sc3c2c(=O)n(-c2ccccc2)c2nnc(SCc4ccc(Cl)cc4)n32)C1
# Predicted: \@@@@@@@@//NNNNNNHH\\N33333//NNGGGGG@@@@aaaaaNNGG//////////////////////////LN
# ------------------------------
# Actual: C[C@@H]1CN(C[C@H](C)O1)C2=CC(=O)N3C=Cc4ccccc4C3=N2
# Predicted: (@@@@@@@@@@@@@@@@@\\\\@NNNNNHHH\\\\@@@@@3333333///////333333333333////////NNN
# ------------------------------
# Actual: Fc1ccccc1c2cccc(CNc3cnccc3OC4CCNCC4)n2
# Predicted: (@/////////////@@@@@@@@@@GNNNNNNNNN////////3333333333333333333333/////////Goo
# ------------------------------
# Actual: CO/N=C(\Cn1ncc(N2CCOCC2)c(Br)c1=O)c1ccc(Cl)cc1
# Predicted: (@@\\\\\\@@@@@@@NNNNNNNNN@@/////////////////////////3333333333333333333//*LLo
# ------------------------------
# Actual: Cc1cc(C#N)c(SCC(N)=O)nc1-c1ccc(F)cc1
# Predicted: (@@@@@@@@@@@@@@HHHHHHH////////////////////33333333333333333333333/////////GLL
# ------------------------------
# Actual: CCOc1ccccc1-n1c(SCC(N)=O)nnc1-c1cccnc1
# Predicted: (\@@/////////////NNNHHHHHHHHH33333//////////3333333333333333333333////////LLL
# ------------------------------
# Actual: O[C@@]12CC3CC(C1)[C@H](NC(=O)c4cccc(n4)N5CCN(Cc6ccccn6)CC5)C(C3)C2
# Predicted: /////////\\\\LLL@@@@@@@@@@@@@@@@@@//GGGG@@@@@@@@@@@@GGNNNNNNNN////////////LLL
# ------------------------------
# Actual: O=C(CCSCCc1ccccn1)Nc1ccc(Cl)cc1
# Predicted: D@@@@@@@@////////////////////////////33333333333333333333333333333333333**LLL
# ------------------------------
# Actual: O=C(N1CCCC1)N1CCN(c2ncnc3c(-c4ccc(Cl)cc4)nsc23)CC1
# Predicted: (@@@@@@@@@@@@@@@@@@HHHHHN////////aGGGGGGGGG////////////////3333333333333**LLL
# ------------------------------
# Actual: COC(=O)c1ccccc1NC(=O)N1CCC(n2c(C)nc3cccnc32)CC1
# Predicted: D\\\\HH@@@///////@@@@@\\NNNNNNNNNNN@@@@NN//////////////33333333333333333**LLL
# ------------------------------
# Actual: C[C@]12N[C@H](Cc3ccccc13)c4ccccc24
# Predicted: /////@@@@@@@@@////////////3333333333333333333333333333333333333333/////////oN
# ------------------------------
# Actual: COc1ccc(C(CC(=O)O)N2C(=O)CCC2=O)cc1
# Predicted: (@@@@@@@NNNNNHHHHH\\\NNNNNNNNNN@/////////3333333333333333333333333////////LLL
# ------------------------------
# Actual: C/C(N)=C(/C#N)C(=O)COC(=O)C1Cc2ccccc2CN1S(C)(=O)=O
# Predicted: //@@@@@@@@@@@@@@@@\\\\\\\\\HH@@@@@@@@@@//NNNNHH////////333333333333////////LN
# ------------------------------
# Actual: CC(=O)N(C1CC(C)C(C#N)(C#N)C1(C#N)C#N)N(C)C
# Predicted: (@@@@@@@@@@@@a@@@@@@@@@@@@@@@@@@@@@@@@@////////////333333333333333333333**LLN
# ------------------------------
# Actual: Cc1ccc(C)c(S(=O)(=O)N2CCN(C(=O)CCCc3c[nH]c4ccccc34)CC2)c1
# Predicted: (@/////////HHHHHHHH\\@@@@@@@@\\\\\NNNN@@@@@///////////////////////////////GLL
# ------------------------------
# Actual: CNS(=O)(=O)c1cccc(C(=O)OCc2cc(=O)n3cc(Br)ccc3n2)c1
# ...
# ------------------------------
# Actual: CC(C)CN1CCCC2(CCN(C(=O)c3ccncc3)CC2)C1
# Predicted: (((cccccccccccccccccccccccccccccccccc3333333333333333333333333333333333333311
# ------------------------------
# Actual: O=C(CS(=O)c1ccc(F)cc1)N1CCOCC1
# Predicted: (((ccccccccccccccccccccccccc33333333333333333333333333333333333333333333333Lo
# ------------------------------
# Actual: Cc1csc2cc(-c3cccc([N+](=O)[O-])c3)c(-c3cccc([N+](=O)[O-])c3)c[n+]12
# Predicted: (((((ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc333333333)/1L
# ------------------------------
# Actual: COCOc1c2c(c(OCOC)c3c(OCOC)cccc13)/C(=N/N[S+](=O)([O-])c1ccc(C)cc1)C1=C2CCCC1
# Predicted: ((ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc@@1L
# ------------------------------
# Actual: NCCC(=O)NCCOc1cc2ncnc(Nc3ccc(Br)cc3F)c2cc1NC(=O)C=C
# Predicted: (((cccccccccccccccccccccccccccccccccccccccccccccccc33333333333333333333333311
# ------------------------------
# Actual: CCN(c1ccc(NC(=O)COC(=O)c2ccc3ccccc3n2)cc1)C(C)C
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccc333333333333333333333333333311
# ------------------------------
# Actual: CC1NC(=O)C(C)C(c2ccccc2)N(N=O)C1c1ccccc1
# Predicted: ((((cccccccccccccccccccccccccccccccccc333333333333333333333333333333333333111
# ------------------------------
# Actual: CCc1cccc(CC)c1CC(=O)Nc2ccc3[nH]nc(c4cccc(c4)S(=O)(=O)N)c3c2
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccccccccccccccc333333333333333111
# ------------------------------
# Actual: COc1ccc2c(c1)O[C@H](c1ccc3c(c1)OCO3)[C@@H](OC(=O)NCc1ccc3c(c1)OCO3)C2=O
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc3333LL
# ------------------------------
# Actual: CC(Oc1ccccc1C2CCCC2)C3=NCCN3
# Predicted: ((((cccccccccccccccccccccc333333333333333333333333333333333333333333333333311
# ------------------------------
# Actual: CNC(=O)c1cccn(Cc2cc(C(F)(F)F)cc(C(F)(F)F)c2)c1=O
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccc33333333333333333333333333311
# ------------------------------
# Actual: O=C(NCCN1CCN(C(=O)c2cccc(Br)c2)CC1)C(=O)NCc1ccccc1
# Predicted: (((cccccccccccccccccccccccccccccccccccccccccccccc33333333333333333333333333Lo
# ------------------------------
# Actual: CCn1cc(C=C2C(=O)c3ccccc3C2=O)c2ccccc21
# Predicted: ((((ccccccccccccccccccccccccccccccccc3333333333333333333333333333333333333111
# ------------------------------
# Actual: CCc1nnc(NC(=O)C2CC(=O)N(c3ccc(C)cc3)C2)s1
# Predicted: (((((ccccccccccccccccccccccccccccccccccc3333333333333333333333333333333333111
# ------------------------------
# Actual: Cc1ccc(NC(=O)/C(=C/C=C/c2ccccc2)NC(=O)c2ccccc2)cc1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccccc3333333333333333333333333/11
# ------------------------------
# Actual: O=S(=O)(Nc1ccc(S(=O)(=O)N2CCCCC2)cc1)c1ccc(Br)s1
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333**o
# ------------------------------
# Actual: Cn1c2ccccc2c2nnc(SCC(=O)Nc3cccc(C(=O)O)c3)nc21
# Predicted: (((((cccccccccccccccccccccccccccccccccccccccc33333333333333333333333333333/11
# ------------------------------
# Actual: CN(CCOc1ccc(cc1c2cccs2)c3ccc4OCCc4c3)CC(=O)O
# Predicted: (((cccccccccccccccccccccccccccccccccccccccccc33333333333333333333333333333311
# ------------------------------
# Actual: CCOc1ccc(/C=C2/C(=N)N3OC(C)=CC3=NC2=O)cc1OC
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333333111
# ------------------------------
# Actual: COc1cccc(CNC(=O)Cn2c(=O)ccc3cc(S(=O)(=O)N4CCC(C)CC4)ccc32)c1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccccccccccccccc333333333333333311
# ------------------------------
# Actual: COc1ccc(-c2cn3cccnc3n2)cc1NC(=O)C1CC1
# Predicted: ((((ccccccccccccccccccccccccccccccc333333333333333333333333333333333333333111
# ------------------------------
# Actual: CN(C)CCC(NC(=O)c1cc(C)c(C)cc1C)c2ccc(Cl)cc2
# Predicted: (((cccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333333311
# ------------------------------
# Actual: CCCCc1ccc(OCC[C@H](N[C@H](C)C(=O)O)C(=O)N2NCCC[C@H]2C(=O)NC)cc1
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccccccccccccccccccc333333333333111
# ------------------------------
# Actual: CC(Sc1nnnn1C)C(=O)Nc1ccc2c(c1)OCCO2
# Predicted: (((ccccccccccccccccccccccccccccccc333333333333333333333333333333333333333331N
# ------------------------------
# Actual: CC(C)c1ccc(C2CC(=O)c3cnc(N4CCc5ccccc5C4)nc3C2)cc1
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccc33333333333333333333333333311
# ------------------------------
# Actual: COc1cccc(-c2cnc(C(O)c3ccc(C)cc3)[nH]2)c1
# Predicted: ((((ccccccccccccccccccccccccccccccccccc33333333333333333333333333333333333111
# ------------------------------
# Actual: C[C@H](O)Cc1cc2ccccc2c(=O)o1
# Predicted: ((((cccccccccccccccccccccccc3333333333333333333333333333333333333333333333311
# ------------------------------
# Actual: CCOc1ccc(C=NN2CCCCCC2)cc1OCC
# Predicted: ((((cccccccccccccccccccccccc3333333333333333333333333333333333333333333333111
# ------------------------------
# Actual: Nc1ccnc(c1)c2cc(Cl)ccc2Oc3cc(F)c(cc3Cl)S(=O)(=O)Nc4ncns4
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccccccccccccc3333333333333333////o
# ------------------------------
# Actual: COc1ccc(/N=C2\S/C(=C\c3ccc(N4CCOCC4)o3)C(=O)N2CCc2c[nH]c3ccccc23)cc1
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc33333331o
# ------------------------------
# Actual: Cc1cc(C)cc(NC(=O)CCCCC(=O)NO)c1
# Predicted: ((((cccccccccccccccccccccccccc33333333333333333333333333333333333333333333/11
# ------------------------------
# Actual: COc1ccc(NC(=O)c2oc3ccc(S(=O)(=O)N4CCOCC4)cc3c2C)c(OC)c1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccccccccccc3333333333333333333111
# ------------------------------
# Actual: CN1CCN(CC1)c2ccc3[nH]nc(c3c2)S(=O)(=O)c4cccs4
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333311
# ------------------------------
# Actual: CCC(=O)n1nc(NCc2ccc(OC)c(OC)c2)nc1NCc1ccc(OC)c(OC)c1
# Predicted: (((cccccccccccccccccccccccccccccccccccccccccccccccc33333333333333333333333111
# ------------------------------
# Actual: O=C(CN1CCCCC1)N/N=C/c1ccc(Cl)cc1Cl
# Predicted: (((ccccccccccccccccccccccccccccc3333333333333333333333333333333333333333333Lo
# ------------------------------
# Actual: CCOc1ccc(C(=O)N2CCN(c3ncccn3)CC2)cc1
# Predicted: ((((ccccccccccccccccccccccccccccccc333333333333333333333333333333333333333111
# ------------------------------
# Actual: CC(=O)N/C(=C\c1ccccc1)C(=O)OCC(=O)NC1CCCC1
# Predicted: (((ccccccccccccccccccccccccccccccccccccc3333333333333333333333333333333333311
# ------------------------------
# Actual: CN(C)c1ccc(NC(=O)c2ccc3c(c2)nnn3C)cc1
# Predicted: (((ccccccccccccccccccccccccccccccccc33333333333333333333333333333333333333311
# ------------------------------
# Actual: COc1ccc(C2C3C=CCC(c4cccc(-c5ccc(C)cc5)c4)C3C(=O)N2Cc2ccccc2)cc1Cl
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc3333333333311
# ------------------------------
# Actual: CC(=O)Nc1cccc(/C(C)=N/NC(=O)c2cccc(S(=O)(=O)N3CCCC3)c2)c1
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccccccccccc333333333333333333311
# ------------------------------
# Actual: NCCNC(=O)c1ccc(Nc2nccc(n2)c3cc4ccccc4s3)cc1
# Predicted: (((cccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333333311
# ------------------------------
# Actual: O=C(O)Cc1cn(-c2ccccc2)nc1-c1ccccc1
# Predicted: (((cccccccccccccccccccccccccccccc333333333333333333333333333333333333333333LL
# ------------------------------
# Actual: CC1(c2ccc3ccccc3c2)NC(=O)N(CC(=O)N2CCCC(C(F)(F)F)C2)C1=O
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccccccccccc3333333333333333333331o
# ------------------------------
# Actual: COc1ccccc1CCn1c(=O)c(-c2ccc(F)cc2)nc2cncnc21
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333333111
# ------------------------------
# Actual: Cc1ccc(Cl)cc1c2c[nH]nn2
# Predicted: ((((cccccccccccccccccc3333333333333333333333333333333333333333333333333333/1L
# ------------------------------
# Actual: O=C(O)CSc1cnc2ccccc2n1
# Predicted: (((cccccccccccccccccc333333333333333333333333333333333333333333333333333331LL
# ------------------------------
# Actual: COc1ccc2[nH]cc(CCNc3nc(-c4cccc(NS(C)(=O)=O)c4)nc4ccccc34)c2c1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccccccccccccccccc3333333333333111
# ------------------------------
# Actual: CCc1nnc(NC(=O)CSc2nnc(CNc3ccc(C)cc3)n2C)s1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccc333333333333333333333333333333333111
# ------------------------------
# Actual: C[C@@H](Oc1cc(cc2ncccc12)c3cnn(c3)C(F)(F)F)[C@H]4CNC(=O)C4
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccccccccccccccc3333333333333333111
# ------------------------------
# Actual: Cc1cccc(C)c1NC(=O)C1CCCCN1C
# Predicted: ((((cccccccccccccccccccc33333333333333333333333333333333333333333333333333/1L
# ------------------------------
# Actual: CC(C)(C)n1nc(c2ccc(Cl)cc2)c3c(N)ncnc13
# Predicted: (((cccccccccccccccccccccccccccccccccc3333333333333333333333333333333333333313
# ------------------------------
# Actual: CC(=O)N1CCN([C@@H]2c3cccc4cccc(c34)[C@H]2NS(=O)(=O)c2ccccc2)CC1
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc333333333333311
# ------------------------------
# Actual: [O-][N+](=O)c1ccc(cc1)c2csc(NN=C3CCCCCC3)n2
# Predicted: ((((((cccccccccccccccccccccccccccccccccccc3333333333333333333333333333333//oo
# ------------------------------
# Actual: C=CCN1CCN(c2ccncc2S(=O)(=O)N2CCOCC2)CC1
# Predicted: (((cccccccccccccccccccccccccccccccccc333333333333333333333333333333333333311L
# ------------------------------
# Actual: COc1ccc(Cl)cc1S(=O)(=O)N1CCN(Cc2ccc3c(c2)OCO3)CC1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccc333333333333333333333333333111
# ------------------------------
# Actual: O=C1CC2(CCc3ccccc23)C(=O)N1CC#CCN4CCCC4
# Predicted: ((((cccccccccccccccccccccccccccccccccc3333333333333333333333333333333333333Lo
# ------------------------------
# Actual: OC[C@@H]1NC[C@@H](O)[C@H]1O
# Predicted: ((((ccccccccccccccccccccc3333333333333333333333333333333333333333333333333311
# ------------------------------
# Actual: c1ccc(C2CC3CC(c4ccco4)N2O3)cc1
# Predicted: ((((ccccccccccccccccccccccccc33333333333333333333333333333333333333333333//LV
# ------------------------------
# Actual: Cc1nnc2sc(-c3cc4ccccc4o3)nn12
# Predicted: (((((ccccccccccccccccccccccc333333333333333333333333333333333333333333333//11
# ------------------------------
# Actual: CCN(C(=O)COC(=O)CNS(=O)(=O)c1ccc2ccccc2c1)C1CCCCC1
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccc33333333333333333333333333311
# ------------------------------
# Actual: CC(=O)c1cccc(NC(=O)C(C)OC(=O)CNC(=O)c2ccc(C)s2)c1
# Predicted: (((cccccccccccccccccccccccccccccccccccccccccccccc3333333333333333333333333311
# ------------------------------
# Actual: COc1cc(C(=O)OCc2nc(=O)c3sccc3[nH]2)c([N+](=O)[O-])cc1OC
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccccccccccc3333333333333333333111
# ------------------------------
# Actual: CCC(CC)Nc1c2CCCc2nc3c(c(C)nn13)c4ccc(cc4C)N(C)C
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccc33333333333333333333333333111
# ------------------------------
# Actual: CC(C)c1nc(C(=O)N)c(Nc2ccc(cc2)N3CCN(C)CC3)nc1Oc4cccc(NC(=O)C=C)c4
# Predicted: (((cccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc333333333311
# ------------------------------
# Actual: O=C(NCCc1ccccc1)c1cc(Sc2cccc(Cl)c2)nc2ccccc12
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333333LL
# ------------------------------
# Actual: CCc1ccc(C2CC(c3ccccc3)N3NC=NC3=N2)cc1
# Predicted: ((((cccccccccccccccccccccccccccccccc33333333333333333333333333333333333333111
# ------------------------------
# Actual: COc1ccc2nc(NC(=O)CN3CCN(C)CC3)sc2c1
# Predicted: ((((cccccccccccccccccccccccccccccc3333333333333333333333333333333333333333111
# ------------------------------
# Actual: COc1ccccc1C2=C3CCCCN3C(=O)N(CCCCN4CCC(CC4)c5c(C)[nH]c6ccccc56)C2=O
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc3333333331o
# ------------------------------
# Actual: CCCC(N1CCCC1)C(=O)c2ccc(cc2)c3occc3
# Predicted: ((((ccccccccccccccccccccccccccccccc333333333333333333333333333333333333333111
# ------------------------------
# Actual: CCOc1ccc(-c2c(C(=O)N/N=C/c3sccc3C)nnn2-c2nonc2N)cc1
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccccccc333333333333333333333333111
# ------------------------------
# Actual: Cn1ncc(NC(=O)c2nc(cnc2Nc3cncnc3)C4CC4)c1C(=O)N
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333111
# ------------------------------
# Actual: CC(=O)c1ccc(F)c(-c2cc(C)cc3c2OC(CNC(=O)c2ccnn2C)C3)c1
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccccccc3333333333333333333333311
# ------------------------------
# Actual: CSc1ccc(CN2CCC(C)(Oc3ccc(-n4ccnc4)cc3)C2)cc1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccc333333333333333333333333333333//11
# ------------------------------
# Actual: O=C(/C=C/c1ccc2ccccc2n1)N1CCN(c2ccccc2)CC1
# Predicted: (((cccccccccccccccccccccccccccccccccccccc3333333333333333333333333333333333Lo
# ------------------------------
# Actual: CCCCCCN(CCCCCC)C(=O)C(=O)c1c([nH]c2ccc(OC)cc12)c3ccccc3
# Predicted: (((cccccccccccccccccccccccccccccccccccccccccccccccccccc3333333333333333333111
# ------------------------------
# Actual: [O-][N+](=O)c1ccc(cc1)C(=O)Cn2ccnc2c3ccccc3
# Predicted: ((((((ccccccccccccccccccccccccccccccccccccc333333333333333333333333333333//oo
# ------------------------------
# Actual: N#CCCN(C(=O)COC(=O)c1ccc2ccccc2n1)c1ccccc1
# Predicted: (((@ccccccccccccccccccccccccccccccccccccc333333333333333333333333333333333111
# ------------------------------
# Actual: CCOS(=O)(=O)\C=C\c1ccc(OC)c(OCCCCNc2nc(c3ccccc3)c(s2)c4ccccc4)c1
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc3333333333111
# ------------------------------
# Actual: COc1cc(OC)c(OC)cc1CN1CCCC(n2cc(C(=O)N3CCCCC3)nn2)C1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccccccc3333333333333333333333333111
# ------------------------------
# Actual: Cc1nc2cc(C(F)(F)F)ccc2n1C1CCN(C(=O)N2CCOCC2)CC1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333//11
# ------------------------------
# Actual: O=C(COc1ccccc1)N1CCCCCCC1
# Predicted: (((cccccccccccccccccccc3333333333333333333333333333333333333333333333333331LL
# ------------------------------
# Actual: Cc1ccc(NS(=O)(=O)c2ccc(Cl)s2)cc1S(=O)(=O)N(C)C
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccc3333333333333333333333333333/1L
# ------------------------------
# Actual: CN(C)C(=O)C1CCN(CC1)c2nccnc2C3CN(C3)C(=O)c4nc5ccccc5[nH]4
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccccccccccc333333333333333333311
# ------------------------------
# Actual: COC(=O)c1ccc(N2CCOCC2)c(F)c1
# Predicted: (((cccccccccccccccccccccccc33333333333333333333333333333333333333333333333311
# ------------------------------
# Actual: CCCCN(CCCC)/C(N)=N/c1nc(C)cc(C)n1
# Predicted: (((cccccccccccccccccccccccccccccc33333333333333333333333333333333333333333111
# ------------------------------
# Actual: COc1ccc(NC(=O)COC(=O)COc2cccc3c2OC(C)(C)C3)cc1
# Predicted: ((((ccccccccccccccccccccccccccccccccccccccccc33333333333333333333333333333111
# ------------------------------
# Actual: O=C(Nc1ncc(Cc2ccccc2)s1)c1cccs1
# Predicted: (((ccccccccccccccccccccccccccc333333333333333333333333333333333333333333333Lo
# ------------------------------
# Actual: COC[C@@H](C)Oc1nc(C2CC2)c(s1)C(=O)N[C@@H]3C4CC5CC3C[C@@](O)(C5)C4
# Predicted: ((((cccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc3333333333311
# ------------------------------
# Actual: C[C@@H](NS(=O)(=O)c1ccccc1c2ccc(c(F)c2)c3cnc(N)nc3)C(F)(F)F
# Predicted: (((@@cccccccccccccccccccccccccccccccccccccccccccccccccccccc333333333333333111
# ------------------------------
# Actual: OC(=O)c1ccc(Cc2noc(n2)c3ccc4ccc(OCc5ccc6ccccc6n5)cc4c3)cc1
# Predicted: (((ccccccccccccccccccccccccccccccccccccccccccccccccccccccc33333333333333333LL
# ------------------------------
# [4.179189682006836, 4.1615309715271, 4.143942356109619, 4.126402854919434, 4.108889102935791, 4.091378211975098, 4.073847770690918, 4.056272983551025, 4.038625240325928, 4.020878314971924]
