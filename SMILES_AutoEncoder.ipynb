# %% [markdown]
# # SMILES Autoencoder
#
# Replicating SMILES autoencoder in this article:
# https://www.nature.com/articles/s42004-023-00932-3#Sec19
#
# Supplementary material for above paper:
# https://static-content.springer.com/esm/art%3A10.1038%2Fs42004-023-00932-3/MediaObjects/42004_2023_932_MOESM1_ESM.pdf
#
# Model architecure and training details from above supplementary material:
#
# • Bidirectional GRU with an encoder-decoder architecture and
# – number of encoder and decoder layers: 3
# – hidden dimension for encoder and decoder: 512
# – Dimensionality of the embedding space: 512
# – nonlinearity: tanh
#
# Training Hyperparameters:
# • Batch size: 256
# • Learning rate: 0.0001
#
# Training - The autoencoder is trained as a translation model by translating from a randomized SMILES version of a molecule
# to its canonical version. The model is trained on 135M molecules from Pubchem and ZINC12 datasets.
# The architecture of the translation model and latent dimension of 512 is similar to the one used in Winter et al.
# In order to make the learnt representations more meaningful, we also jointly trained a regression model to predict some
# molecular properties that can be calculated using the molecular structure. The regression model uses two fully connected layers
# with dimensions 512 and 128 and ReLU non-linearity. The properties that are predicted are: logP, molar refractivity, number
# of valence electrons, number of hydrogen bond donors and acceptors, Balaban’s J value, topological polar surface area, drug
# likeliness (QED) and synthetic accessibility (SA).

# %% [markdown]
# - try mol2vec

# %%
# IMPORT NECESSARY PACKAGES
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import seaborn as sns
import random
np.random.seed(42)

# %%
# LOAD DATASETS AND PAD SMILES STRINGS TO LEN=77

# load dataset
sanitized_smiles_df = pd.read_csv('dataset/sanitized_smiles_first100k.csv')     # smiles.csv file with 100K rows
sanitized_smiles_df.rename(columns={'SMILES': 'smiles'}, inplace=True)

# calculate the length of each string in the 'smiles' column
sanitized_smiles_df['length'] = sanitized_smiles_df['smiles'].apply(len)

# filter dataframes to only keep input random SMILES with length 77 or less
sanitized_smiles_df = sanitized_smiles_df[sanitized_smiles_df['length'] <= 77]

# Find the maximum length
max_length_sanitized = sanitized_smiles_df['length'].max()

# Print the maximum length
print(f"The maximum length of a string in the input random 'smiles' column is: {max_length_sanitized}")

print(f"Number of SMILES sequences for input sanitized dataframe: {len(sanitized_smiles_df)}")
# Out:
# The maximum length of a string in the input random 'smiles' column is: 77
# Number of SMILES sequences for input sanitized dataframe: 98414

# %%
# CREATE RANDOM SMILES SEQUENCE BY SHUFFLING SMILES STRING AND ADD TO DATAFRAME
def shuffle_string(smiles):
    list_smiles = list(smiles)
    random.shuffle(list_smiles)
    return ''.join(list_smiles)

random.seed(42)  # Set random seed for reproducibility

sanitized_smiles_df['random_smiles'] = sanitized_smiles_df['smiles'].apply(shuffle_string)

# pad the strings in the 'smiles' column to the desired length using " "
max_length = 77

sanitized_smiles_df['smiles_padded'] = sanitized_smiles_df['smiles'].apply(lambda x: x.ljust(max_length, ' '))
sanitized_smiles_df['random_smiles_padded'] = sanitized_smiles_df['random_smiles'].apply(lambda x: x.ljust(max_length, ' '))

# %%
# TOKENIZE SMILES STRINGS (CONVERT STRING OF CHARACTERS TO LIST OF FLOATS), CONVERT TO INPUT/OUTPUT TENSORS, SAMPLE 5 SMILES SEQUENCES

# Convert SMILES strings to list of characters tokens
sanitized_smiles_df['smiles_tokenized_lists'] = sanitized_smiles_df['smiles_padded'].apply(lambda x: list(x))
sanitized_smiles_df['random_smiles_tokenized_lists'] = sanitized_smiles_df['random_smiles_padded'].apply(lambda x: list(x))

# combines each list of SMILES characters into one list
flattened_list_all_smiles = [item for sublist in sanitized_smiles_df['smiles_tokenized_lists'] for item in sublist]

# get unique characters
unique_characters = set(flattened_list_all_smiles)

# convert back to list
unique_characters = list(unique_characters)
unique_characters = sorted(unique_characters)

print(f"Number of unique characters: {len(unique_characters)}")

# mapping from characters to integers
char_to_int = {char: i for i, char in enumerate(unique_characters)}

# convert SMILES tokenized lists into integer lists
random_smiles_int_lists = [
    [char_to_int[char] for char in sublist]
    for sublist in sanitized_smiles_df['random_smiles_tokenized_lists']
]
smiles_int_lists = [
    [char_to_int[char] for char in sublist]
    for sublist in sanitized_smiles_df['smiles_tokenized_lists']
]

sanitized_smiles_df['random_smiles_integer_lists'] = random_smiles_int_lists
sanitized_smiles_df['smiles_integer_lists'] = smiles_int_lists

# convert the tokenized sequences to tensors
int_lists_random_smiles = sanitized_smiles_df['random_smiles_integer_lists'].tolist()
int_lists_smiles = sanitized_smiles_df['smiles_integer_lists'].tolist()

in_random_smiles_tensor = torch.tensor(int_lists_random_smiles, dtype=torch.float32)
out_smiles_tensor = torch.tensor(int_lists_smiles, dtype=torch.float32)

print(f"Shape of input SMILES tensor: {in_random_smiles_tensor.shape}")
print(f"Shape of output SMILES tensor: {out_smiles_tensor.shape}")

# create random sample of tensors

# five random indices between 0 and 98414
random_indices = torch.randint(0, 98414, (1000,))

# take the random sample of five rows from each tensor
sample_in_smiles_tensor = in_random_smiles_tensor[random_indices]
sample_out_smiles_tensor = out_smiles_tensor[random_indices]

# Print shape of sampled rows
print(f"Shape of sampled input SMILES tensor: {sample_in_smiles_tensor.shape}")
print(f"Shape of sampled output SMILES tensor: {sample_out_smiles_tensor.shape}")
# Out:
# Number of unique characters: 35
# Shape of input SMILES tensor: torch.Size([98414, 77])
# Shape of output SMILES tensor: torch.Size([98414, 77])
# Shape of sampled input SMILES tensor: torch.Size([1000, 77])
# Shape of sampled output SMILES tensor: torch.Size([1000, 77])

# %%
print(char_to_int)
# Out:
# {' ': 0, '#': 1, '(': 2, ')': 3, '+': 4, '-': 5, '1': 6, '2': 7, '3': 8, '4': 9, '5': 10, '6': 11, '7': 12, '8': 13, '=': 14, 'A': 15, 'B': 16, 'C': 17, 'F': 18, 'H': 19, 'I': 20, 'N': 21, 'O': 22, 'P': 23, 'S': 24, '[': 25, ']': 26, 'c': 27, 'e': 28, 'i': 29, 'l': 30, 'n': 31, 'o': 32, 'r': 33, 's': 34}

# %%
print(f"Sampled input SMILES tensor: {sample_in_smiles_tensor}")
# Out:
# Sampled input SMILES tensor: tensor([[27.,  7., 17.,  ...,  0.,  0.,  0.],
#         [26.,  2., 31.,  ...,  0.,  0.,  0.],
#         [27., 27., 22.,  ...,  0.,  0.,  0.],
#         ...,
#         [31., 17., 22.,  ...,  0.,  0.,  0.],
#         [ 7., 32., 17.,  ...,  0.,  0.,  0.],
#         [14.,  6., 27.,  ...,  0.,  0.,  0.]])

# %%
class bidirectional_GRU_AE(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers=3, embedding_dim=10):
        super(bidirectional_GRU_AE, self).__init__()

        # embedding layer to convert integer indices to dense float vectors
        self.embedding = nn.Embedding(input_size, embedding_dim)

        self.encoder = nn.GRU(
            input_size=embedding_dim, 
            hidden_size=hidden_size, 
            num_layers=num_layers, 
            bidirectional=True,
            # input and output tensors are (batch_size, seq_len) format
            batch_first = True      
        )

        self.decoder = nn.GRU(
            # for bidirectional GRU, input size is doubled (each hidden layer as forward and backward state)
            input_size=hidden_size * 2,     
            hidden_size=hidden_size, 
            num_layers=num_layers, 
            bidirectional=True, 
            batch_first = True
        )

        # fully connected layer
        # passing through Tanh activation function (self.tanh = nn.Tanh) for nonlinearity
        self.fc = nn.Sequential(
            nn.Linear(hidden_size * 2, input_size),  # Linear layer
            nn.Tanh(),  # Tanh activation
        )

    def prob_to_char_out(self, output):
        _, predicted_classes = torch.max(output, dim=2)
        return predicted_classes     

    def forward(self, x):
        # encoding
        # embed input integer indices to floating point vectors
        # after embedding, shape of x becomes (batch size, sequence length, embedding dimensions)
        x = self.embedding(x)

        # encoder_output shape is (batch size, sequence length, hidden_size * 2)
        # hidden shape is (num_layers * 2, batch size, hidden_size)
        encoder_output, hidden = self.encoder(x)
        
        # for bidirectional GRU, there are two separate hidden states for each hidden layer
        # forward state goes from start to end of sequence and backward state goes from end to start of sequence
        # we can concatenate forward and backward directions from last hidden layers or pass the hidden layers to the decoder directly
        # we are currently passing hidden layers to decoder directly

        # decoding
        # encoder_output has shape (batch size, sequence length, hidden_size * 2)
        # decoder output has shape (batch size, sequence length, hidden_size * 2)
        decoder_output, _ = self.decoder(encoder_output, hidden)
        print(f"Output shape after decoder: {decoder_output.shape}")

        # pass decoder output through the fully connected layer
        # output has shape of (batch size, sequence length, vocab size) = (5, 77, 64)
        output = self.fc(decoder_output)
        print(f"Output shape after fully connected layer: {output.shape}")

        # Define custom order of classes (e.g., reversing the class order)
        #custom_order = list(range(64))
        #custom_order = torch.tensor(custom_order)  # This means class 3 comes first, then class 2, etc.

        # Reorder the vocab_size dimension of the output tensor based on custom_order
        #reordered_output = output[:, :, custom_order]

        predicted_classes = self.prob_to_char_out(output)
        print(f"Predicted classes: {predicted_classes}") 

        return output
    
int_to_char = {i: char for char, i in char_to_int.items()}

def decode_smiles(tensor):
    decoded_smiles = []
    for sequence in tensor:
        smiles = ''.join([int_to_char[int(idx)] for idx in sequence if int(idx) in int_to_char])
        decoded_smiles.append(smiles.strip())  # Remove trailing spaces
    return decoded_smiles

# %%
# Hyperparameters
seq_len = 77
input_size = len(unique_characters)  # vocabulary size
embed_dim = 64    
hidden_dim = 64  
num_layers = 3
batch_size = 1000
learning_rate = 0.0001

# training data
input = sample_in_smiles_tensor.long()
target = sample_out_smiles_tensor.long()

# instantiate model
model = bidirectional_GRU_AE(input_size, hidden_dim, num_layers, embed_dim)

# optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss(ignore_index=char_to_int[' '])  # ignore " " padding indices

# training loop
losses = []
for epoch in range(10):
    model.train()
    optimizer.zero_grad()
    output = model(input)
    output = output.contiguous().view(-1, input_size)  # Flatten for loss calculation
    target = target.contiguous().view(-1)  # Flatten targets

    loss = criterion(output, target)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())

    print(f"Epoch [{epoch+1}/10], Loss: {loss.item():.4f}")

    # Decode and print the predicted SMILES
    model.eval()
    with torch.no_grad():
        predicted_indices = torch.argmax(output.view(batch_size, seq_len, input_size), dim=2)
        predicted_smiles = decode_smiles(predicted_indices)
        random_smiles = decode_smiles(input)
        actual_smiles = sanitized_smiles_df['smiles'].iloc[random_indices]
        print("Actual vs Predicted SMILES:")
        for actual, random, predicted in zip(actual_smiles, random_smiles, predicted_smiles):
            print(f"Actual: {actual}")
            print(f"Random input: {random}")
            print(f"Predicted: {predicted}")
            print("-" * 30)

print(losses)
# Out:
# Output shape after decoder: torch.Size([1000, 77, 128])
# Output shape after fully connected layer: torch.Size([1000, 77, 35])
# Predicted classes: tensor([[26, 26, 26,  ..., 27, 27, 27],
#         [ 7, 27, 27,  ..., 27, 27, 27],
#         [26, 26, 26,  ..., 27, 27, 27],
#         ...,
#         [27, 27, 27,  ..., 27, 27, 27],
#         [30, 26, 26,  ..., 27, 27, 27],
#         [30, 26, 26,  ..., 27, 27, 27]])
# Epoch [1/10], Loss: 3.5527
# Actual vs Predicted SMILES:
# Actual: Nc1nc(Cl)cc(N2CCOCC2)n1
# Random input: c2CncO1)2CNnc(l)NCCc(C1
# Predicted: ]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCc1ccc(-n2cc(-c3ccc([N+](=O)[O-])cc3)[nH]c2=S)cc1
# Random input: ](nc][cc-)cn1)(-c+)cc)c3=CS[cH(c=23Cc]c-2c(1ccONO[
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1Cc2cc(Cc3ccccc3)ccc2C(=O)N1O
# Random input: ccOC2cccC(OccCcc=321)=N3)(OcCc1c
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1c2ccccc2C(=O)c2c1ccc1c(=O)n(C3CCCCC3)[nH]c21
# Random input: cc(n2)=(=C3Cc)1c=OCCH3Ccc11cC21cCc22(CcOn)[ccc]O
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(C(O)(C(=O)NCCCN2CCC(C#N)(c3ccccc3)CC2)c2ccc(C)cc2)cc1
# Random input: )2C2(Cc(C#)2cc3C1C1N3c)Ccc(cCN(c((2ccc=))COCcC)NcCccc(cc)COC
# Predicted: ]ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccc
# ------------------------------
# Actual: O=[N+]([O-])c1ccc(N2CCCCC2)c(Cl)c1N1CCCCC1
# Random input: N(ClC1[)c1ccCC)2C(1=C(2COCC]OC[+)N]c-CccN1
# Predicted: 2===]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COC(=O)c1cc(=O)n(C2CC2)c(=NC2CC2)s1
# Random input: (n(1c)OCN=2)=OCc=Occ)C((Cs1CCCC2)22
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(O)COc1ccc2c3c(c(=O)oc2c1)CCC3
# Random input: 1CCO)(cc2C()CcO)c=32O3CoOc(=cccc1
# Predicted: ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(S(=O)(=O)Nc2nc(C(F)(F)F)cs2)cc1
# Random input: OFF)c()(cccc(c=CcC2)F)Sc2((sN1O)n()=1cO
# Predicted: cccccc]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=S(=O)(c1ccccc1)N1CCN(C(=S)Nc2ccc(F)cc2)CC1
# Random input: CFN=cc(N(C)CccOScc)2)cC1c1c1=N))C1Occ=((c(S2
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1nn(-c2ccccc2)c(C)c1C=NNC(=O)c1cc(C23CC4CC(CC(C4)C2)C3)[nH]n1
# Random input: 2cC2c(NCC4C(n4)CCn)c131c()-))=C(=Cn1HccCc]n)2COc[23NCcCc1CccC((
# Predicted: ]]]]]]]]]]cccc]]]]]]]]]]]ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccc
# ------------------------------
# Actual: CCOC(=O)N1CCN(C(=O)CN(C2CCCCC2)S(=O)(=O)c2ccc(C)cc2)CC1
# Random input: ccCCC=)=CCCO(ScNNOCN)Oc=()CC))CCc2C(C=C2)O)(2(O(1c1(C2C
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccc
# ------------------------------
# Actual: CC1(C)C2CCC1(CS(=O)(=O)NCc1ccc(C(=O)O)cc1)C(=O)C2
# Random input: 1cc=c(OCC2=C)((2cNC1))cCO)()C=COCCO((C)()cC1S1=OC
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccc]]]]]]ccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1c2ccccc2C(=O)N1CCCCCCCNCc1ccccc1
# Random input: 11NccCCN==OcC(CC2CC1COc)ccCcc2cCc1cc
# Predicted: Icc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Nc1nc(OCCc2ccccc2)nc2c1ncn2C1OC(CO)C(O)C1O
# Random input: cc)n22OOCcncCOOc1ccnOcc1NC))(22cC(1C1nC(Cc
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOc1ccccc1C=c1sc2ncnn2c1=O
# Random input: 2n1O1sc=ccOcCC=ccCccn2c1n1c
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOC(=O)c1ccccc1NC(=O)CC1SC(=NC)N(C)C1=O
# Random input: c=(COCCCOCCO(S)cc1)=(c11NCN=N=)c1CC(Oc)C
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: NC(=NOC(=O)COc1ccccc1Cl)c1ccc(Cl)cc1
# Random input: )1c(cNO)=OCCcl=c(CcOl1(CC)Nccc1cc1cc
# Predicted: lccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: [O-][N+](=Cc1ccc(F)cc1)c1ccccc1
# Random input: ccFc(N-]11cc=)c)1cc1C+Oc[cc[(c]
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)NC(=O)c1ccc(COCC(F)(F)F)cc1
# Random input: cFNOCCc)))1(c(FCCc=C)cCc)1(O(CF(
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Oc1ccc2c3c1OC1c4ncc(-n5cccc5)cc4CC4(O)C(C2)N(CC2CC2)CCC314
# Random input: C14c4c2321(21C-CN3CccC)C()n4(O1cccc)ncC5C2COcCCC5O4c)c(ccc
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(NC(=O)CSc2nnc(C3CCCCC3)n2N)cc1F
# Random input: Cc2c1On32cc)SC3CcCC)C(()(CC=CNN1Fncncc
# Predicted: ]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=c1cn[nH]c(Nc2ccccc2)n1
# Random input: ]cnc2[cncN2H)Oc(ccc11c=n
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1nc2nc(C(=O)NCc3cccs3)cn2c(-c2ccc(Cl)cc2Cl)c1CN
# Random input: Ccncnnc((2C-12CccN312s(CCcc)c)=3c2)lcN)ccCcccO(lc
# Predicted: cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccsc1C=C1C(=O)c2ccccc2C1=O
# Random input: (c1CCO2ccC2=Cc11ccs=ccOc)c=1C
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(NC(=O)COC(=O)c2ccc(NS(=O)(=O)C=Cc3ccccc3)cc2)cc1
# Random input: c=cc=c2)2c(C=Nc)CcCcC))(OO=cc)11(C(ccc3cO3c=cSNOOO(cCc)(
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)Oc1cccc(-c2cc(C(=O)N3CCN(c4ncccn4)CC3)c3ccccc3n2)c1
# Random input: CcCCc1c2)4c(4c3cnN1=Ccc)C2c()(3(n3c3C)cCc-cCccNnccO)Occ(
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(C(=O)Nc2ccc(S(=O)(=O)N3CCCC3)cc2)c(OC)c1
# Random input: CC(=C((NC3cc(=S1c)Oc)cC=cCO)c1(2c(c))OO)O23NcCcc
# Predicted: 2cccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN(C)c1cccc(C(=O)Nc2ccc3nc4n(c(=O)c3c2)CCCCC4)c1
# Random input: cNcC)ncncOcC)CcC)42cccC12=c)C)cN4C((=1cO3(c3Cc((
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(NC(Cc1ccccc1)C(=O)NCc1ccccn1)c1ccco1
# Random input: cc1()(oN1OcCc)cccCn)O=ccNCc1cCCc1(c1c=c1
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(CC(=O)Nc2oc(-c3ccccc3)c(-c3ccccc3)c2C#N)cc1OC
# Random input: NccccCc3)3c-()(cCOc21(CNOCcc32)c1)Cc#c3(cccc-ocOc=ccc
# Predicted: I]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(O)c1ccc(COc2ccc(Cl)cc2)o1
# Random input: c)C2(O1ccc1(2l)c=cCcOOoCcc()c
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOC(=O)c1sc(=NC(=O)c2ccc(OC)c(OC)c2)n(C)c1C
# Random input: C1)CNccOcO2c(=(CC)cC))cc(ncc=O(CO(1s=)CC)O(2
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(C2CN(C)Cc3cc(OCCCN4CCC(F)CC4)ccc32)cc1
# Random input: cCcc2CCCCCccC)c)c(FcCc1C(CcNCC3cN(2)43)(CO41c
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCC1Sc2ccccc2N(CC(=O)NCCC2=CCCCC2)C1=O
# Random input: (CCC=2CCS)c=CO=Cc()C211CcO2CccCCNcC2CN
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: c1cc2nncn2nc1N1CCCC1
# Random input: Cc1cnnCcc1CnC1n21Nc2
# Predicted: 2cc]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CNC(=O)c1cn(-c2ccccc2)c(=O)c2ccccc12
# Random input: -2Occ(ccC(cccNc2cn)O2cCcc)==)c1c1c2(
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1NCN(c2ccccc2)C12CCN(C(c1ccccc1Cl)c1ccccc1Cl)CC2
# Random input: ccCclcclc)ccC)C(=cCNc211cccN1c2211Cc(NCO(Cc2CCc1C)c
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCCCCCCCCCCCCCCCCCCCCC(=O)O
# Random input: CCCCCCOCCCC)CCCC=CCCCCCCO(C
# Predicted: =5555555555555555555555cccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1nc2cc(-n3ncc(C(=O)c4cc5ccc(O)cc5[nH]4)c3N)ccc2[nH]1
# Random input: c4n)c=((32]c12cc5c(C)ccccHC4O[ncNcOc)cnc][(3cHn-5nc1)c
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(c1ccco1)N1CCN(c2ccccc2F)CC1
# Random input: c1NNcOccoc)CC2CF12)=cc(cCC1(1cc
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COCCn1c(=O)c2c(nc(Cc3c(F)cccc3F)n2C)n(Cc2ccco2)c1=O
# Random input: cn(Oc)=FncC(c)cc3(cC2)3C2c2Cn(O1cCCF=()c)1cOoc2cncc
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccc
# ------------------------------
# Actual: CNC1CCC(c2ccc(Cl)c(Cl)c2)c2cc(C(=O)N(C)C)ccc21
# Random input: cOcN22)((cc)))l(CC=cc2CcNc)CCC)CcccCl2C(1C1c((
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(=O)oc(C)c1C(=O)NCC1COc2ccccc2O1
# Random input: c2O11cC1cCc()OCc=))1cO2CO(occ(ccCCcN=
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cn1c(=O)n(C)c2cc(C=Nn3cnnc3)ccc21
# Random input: c1(3c(=NcC2=n2)cOccncnC(Ccnn1)c3)
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1cccc(C=C2SC(=S)N(N3CCOCC3)C2=O)c1OC
# Random input: (C=cSSCCC=C1cccOC22CO)N(cC)=3O(3cNCO1)C
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(Cc1cccs1)N1CCCC(c2nc(-c3ccc(S(=O)(=O)N4CCCC4)cc3)no2)C1
# Random input: ccC1=CcSc((412COc)1C)4On(3C2)(c=o-=scCccO3N))c1(CCCcCNnC(c)
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccc
# ------------------------------
# Actual: c1cc(-c2ccc(CN3CCCCC3)cc2)ccc1CN1CCCCC1
# Random input: Ncc2CCCc)cccNCC(CCCc11(c1cCC-3123)cCcCc
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(CN(Cc1ccccc1)C(=O)c1ccc2c(c1)OCCO2)NCc1ccc2c(c1)OCO2
# Random input: C)1c1(c2N(=O(ccC(CNCc=c2c)C2O1Cccc1(c1)1cc)cO)cCccOC2OcO
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccc
# ------------------------------
# Actual: N#Cc1ccc2[nH]cc(C3CCC(N4CCc5ccccc5C4)CC3)c2c1
# Random input: cC5CcCN)cc(2)4C#3Cccc[n2HC(cc4CcC]cc153c1NcCC
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(CN(C(=O)c2oc3ccccc3c2C)C2CCS(=O)(=O)C2)cc1
# Random input: CcC(ccCcO=1c(=)23)=(C1C(C))ccccCc2S2(OccO2Ccc)oON3
# Predicted: 2]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=c1cc(Cn2c(C3CCC3)nc3nccnc32)c2ccc(F)c(F)c2[nH]1
# Random input: n221n=ccc2Fn)cC)cncc)]C2((Cc)31(cFCcCc33Onc3cHc([
# Predicted: ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(C(=O)NCC(=O)OCc2ccc([N+](=O)[O-])cc2)cc1
# Random input: 1O(c(=][N+C)cc-OC2=(O)cc)OO1O(cCN)cc[C=c](cCc)c2
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc2cc(CN(Cc3ccco3)C(=O)NCc3ccccc3)c(=O)[nH]c2cc1C
# Random input: ()H2ccc3cOoC]()c=cccccC=CcccN2()[)3N3CCcCnc1c(Oc1c3c
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccc
# ------------------------------
# Actual: CN(C)CCC(c1ccc(Cl)cc1)c1ccccn1
# Random input: N)cc((cc1CClc11)nc1ccCc)CCcc(C
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCN(CC)C(=O)CSc1nnc(C2CCCCC2)o1
# Random input: 2)CC(O)nC11CC)coSC(2CCN=CCCc(Cn
# Predicted: ccccccc]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: N#CCSCC(=O)Nc1ccc(Br)cc1
# Random input: #Bc=)Cr)C1c1COccN(cCNc(S
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(Nc1ccc2c(c1)Cc1ccccc1-2)c1ccco1
# Random input: c1c1ocCcC)=(c11ccc)(1cc1cc2Nc-cOcc2
# Predicted: I]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(OCc2nc(C#N)c(N3CCN(c4ccc(OC)cc4)CC3)o2)cc1
# Random input: ccO4(1c)(nCcNNC3ccC(OcccNo2)cC1)Cc#O2()3cCccC)(C4c
# Predicted: 2cccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(C2C(C(N)=O)=C(C)N=C3N=C(c4ccccc4Cl)NN32)c(OC)c1
# Random input: CN1Nl(=4)cCCc(cc()4NcC(Nc2c()))O3c2C=1ccccNCC3C=(C)OCO=
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)Sc1nc(SCC(=O)NCc2ccco2)c2c3c(sc2n1)COC(C)(C)C3
# Random input: CCc(CcScCcSCn1n(c)CCCc(2()=32cs)cO3c()1(OC))C2cN2oC
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1nnc(SCC(=O)N2CCC(Cc3ccccc3)CC2)n(N)c1=O
# Random input: cc=C1COC)c(13)NC2(cc=(NCCn))cC3(ncC2nSccCO
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: c1cc(-c2ccc(CN3CCCCC3)cc2)ccc1CCN1CCCCC1
# Random input: CN33cCccN1C21)c1CC2-(CCCccc1Cc(c)CCCCccc
# Predicted: 2c==]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=S(=O)(c1ccc2ccccc2c1)N(CC(O)COCc1ccco1)c1ccccc1
# Random input: 1oOcC))SNc)Ccc1cOcCc=cO12cCO=(2cccc(cc)c(cc111c(c
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)OC(=O)CC12CN3CC(CC(=O)OC(C)C)(CN(C1)C(=O)c1ccccc1C3=O)C2=O
# Random input: CCC1CCOOCc))()=c)3()(=)NCC((c(CO(cCCOO=OcC)2OC)C=CcC=2(C1C11NC3
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]]]]c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccc
# ------------------------------
# Actual: O=C1CN=C(c2ccc(Br)cc2)c2oc3ccccc3c2N1
# Random input: )c1c3ccCC2ONcCB(cNc=1(cocc2=cr3)c2c2c
# Predicted: l]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cn1c(N2CCCC2)nc2c1c(=O)n(Cc1ccc(Cl)cc1)c(=O)n2C
# Random input: cc12O1cn1N(Cl)CC=n22(n)cCCccC)1(C)nO)((c2cc=cCc
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(=O)NC(CCC(N)=O)C(=O)NC(Cc1ccccc1)C(=O)N1CC(OCc2ccc3ccccc3c2)CC1CCCN=C(N)N
# Random input: OcCC(CCO1O2(C(C(ccON2ccNN1CC)=c((=(N=cC=3CcNccNC1cCCCCONc)CCCc31())c=cC)))c)
# Predicted: =]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]c
# ------------------------------
# Actual: CCOC(=O)N1CCN(C(=O)NC2CCCCC2)CC1
# Random input: O1=(CNCC2N)N2OCCCO1)C)C=(CC(CCCC
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(Cn1c(=O)n(Cc2ccco2)c(=O)c2cc(Cl)ccc21)NCC1CCCO1
# Random input: )=C(1cc)=2cCccc)CcCc(cCc)2OO22O=1nolC(CcN(nc)1CCO1(
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(Cl)cc1NC(=S)NCc1ccccn1
# Random input: Cl(c)1COc=()cncCccS1Ncc1cNcc1C
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCCCNC(=O)c1cn(C)c2ccc(S(=O)(=O)N3CCOCC3)cc2c1=O
# Random input: 3c3CC(c=nC)O1(O1c=COC))(O(c(CcCCN2Scc==CO2N)cCc)
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(=O)Nc1ccc(S(=O)(=O)N(C)c2ccc(O)cc2)cc1
# Random input: (C))(cO2cc))2cS((c1cCc)Cc1(cc)O=Nc=ONO=c(
# Predicted: lccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1cc(OC)c2nnc3c(C)nc(-c4cccnc4C)n3c2c1
# Random input: 3c(c)cnCnc3cnC4()cc1-c2OC2c1c)Occ4Cccn(n
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCn1c(C(=O)N(C2CC2)C2CC2)cc2c3c(ncn3C)c(Nc3nc(C)c(C(=O)NC)s3)nc21
# Random input: C2Nc(CN)(c=cO)cC2nccn()n=cscCcCCn2CCC)3C3N))(Cc()3(n(Cc(3)2C21O12
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccc]]]]]]]]]]]ccccccccccccccc
# ------------------------------
# Actual: Nc1nc(-c2cccnc2)nn1S(=O)(=O)c1ccccc1
# Random input: =21)c(Snc2cccn-)cc1c=c1n1N)(cOncOcc(
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(Nc1ccc(-c2nc(N3CCOCC3)c3ncccc3n2)cc1)Nc1cccc(CO)c1
# Random input: cc=cNc1c)()112cc3(1c(n)NCC)c3c3cC23ncCOcncCcOc(CNccc-O
# Predicted: 2]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(COc1ccc(-c2nnco2)cc1)NC1CCCc2ccccc21
# Random input: c(=1O-()cOcnCC1oc)nNc2cccCcC21Ccc21C2ccc
# Predicted: 2ccccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(OC)c(C2C(C(C)=O)=C(O)C(=O)N2c2ccc(F)cc2)c1
# Random input: C)1)2CcccO(C((c1=N))Fc(OOCcC=C(O=cccc)2)O(2c(Cc)2C
# Predicted: ]cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(C)nc(NS(=O)(=O)c2ccc(NC(=O)c3cccs3)cc2)n1
# Random input: ccn3cNc(=cn)(s(OS)c)c(OcCC2231O())(c1CcN=)cccc=
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccccc1OCC(=O)Nc1ccc(S(=O)(=O)NC(C)=O)cc1
# Random input: =CcOc)cO)(c((=C))Oc1(cCNCcccOO11=ONc(cc=C1)S
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)N(C(=O)CSc1nnc(CNc2ccc(F)cc2)o1)C(C)C
# Random input: Ccc)1(c))ocCS(C((C2cNCO(CcC)=)C(CF1)ccnnN2
# Predicted: ]c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=c1c2[nH]c3ccccc3c2ncn1Cc1ccncc1
# Random input: Ccccc[1c2Hc1n1nc23cc]O1cncccnc3c=
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(C)nc(Sc2nc(C)nc3c2oc2ccccc23)n1
# Random input: 1)cnnc(occcnc23Cc132)2Ccccn2cc)(ccS(C
# Predicted: ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(C)c2c(-n3cccc3)c(C(=O)NNS(=O)(=O)c3ccc(F)cc3)sc2n1
# Random input: F(cc)(SO=)cOc)cOcc2)sc13Ncncn)C3()c3ccN((c=3-Cc)2C=cc(1(
# Predicted: lccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccc
# ------------------------------
# Actual: CC1CCc2c(sc(N)c2C(N)=O)C1
# Random input: (1N1Occ2Cs(c=2CC)C)CCc(N)
# Predicted: 2cc]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: N#Cc1ccc(Oc2cccc(C(=O)O)c2)cc1C#N
# Random input: O(C)ccc2c)c=cC(1N#1c#OCNcO)c(2ccc
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1cccc2c1-c1ccc3c(c1C(c1cccc(OCSC)c1)O2)C(C)=CC(C)(C)N3
# Random input: Cc1)c(N2(CC)c3c(ccc))OC=)31C)ccCc(cccC(Oc2(cccCSCO-111c1C
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccc
# ------------------------------
# Actual: CCn1c2ccccc2c2nnc(SCc3ccccc3)nc21
# Random input: S(c)C23Cc1cccn2ccnccc3n2c2cnCcc1c
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(C)n(CCc2nc(-c3ccco3)cs2)n1
# Random input: Ccc12n231occ(-csCcnC(nc3(c)))ccC
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(C)n2nc(SCC(=O)NCc3ccco3)nc2n1
# Random input: Oc1C21(Co2n))c3c(ncN)ccnnccC3C(SCc=
# Predicted: 2ccccccc]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cccc2sc(NC(=O)CN(C)S(=O)(=O)c3ccc(Br)s3)nc12
# Random input: =1((r3cs)(C=cOc(1)(=n)csOCcc2c3c2N())N)BCCSccOc
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN1C(=O)c2ccc(C(=O)NCc3ccc4c(c3)OCO4)cc2C1=O
# Random input: 2cC3)(2)NOON(4O4c(cCcOcCCccC1Oc=c)c=1(Cc)c=3
# Predicted: lccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(CCNC(=O)Cn2cnc3c(nnn3Cc3ccc(C)cc3)c2=O)cc1OC
# Random input: 1Cc)3C(O1n2c)n=n3nccc3c=CO(cCccO)3NC)CccC(ccOccCn2c(
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(NC(=O)c2cc(C)on2)no1
# Random input: n)c=c(c2n)1OCc(1C2C)ocNo(c
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: OC1C2CCC1C(N1CCCCC1)CC2
# Random input: CCC1O1CCC)1N(CC1C22CCCC
# Predicted: =cccc555555555555555ccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCN1C(=O)CC(C(=O)Nc2ccc(C(=O)O)cc2)SC1=Nc1ccccc1OC
# Random input: =1C)O=C2=N)(Ncc(c(O(Cccc(cCNcc1)C1ccCCOOCSO)C)=1c2
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(C=CNc1ccccc1Br)c1ccccn1
# Random input: 1OC1ccCcc1c)NcccB(=ccc1n=rC
# Predicted: Ic]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN1C(=O)C(O)(CC(=O)c2ccccn2)c2cc(Br)ccc21
# Random input: c1ccO=cCO))(c2cONCc)()2(Cr()cB=(1cCCcn22c
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1nc2nc(C(=O)NCc3ccco3)cn2c(-c2ccc(Cl)cc2Cl)c1CN
# Random input: (c2Cl2c2cc)c(c1lcCcOCccNCnc)(cCCcc)31N-n2c)3on=c(
# Predicted: l]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)(OCC1OC(n2cnc3c(N)ncnc32)C(O)C1O)c1ccccc1
# Random input: 3(CnCC(cc)cCcCO2O)C1c)c1cc()1Ccc31nN(2)OCcn(On
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(c1cccs1)N(Cc1ccccn1)Cc1ccco1
# Random input: (cO=1c1cc(n1cc1c1N)CCoscc1cCc)cc
# Predicted: 2]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccccc1CC(=O)NNS(=O)(=O)c1ccccc1[N+](=O)[O-]
# Random input: C=O)1c[O+c1N=]SOcc)((]ccc(c)=-=cOCN1cO(Cc)NO[c1
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(NCc1ccco1)c1cccc(NC(=O)c2ccccc2)c1
# Random input: oc((ccN))ccccN=cCc1c1cCO212(cccO=)cCc1
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(=O)Nc1cccc(NC(=O)C2CC(=O)N(c3ccc(C)cc3)C2)c1
# Random input: c(cC(cC)NOC=)c(cN3c1cCC1()Ccc()cc=2O)COC23(c=N)
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COC1=CC(=O)C(=C2NNC=C2c2cnc(C)s2)C=C1
# Random input: =O12CcCN2C=C(2s)C(CCCnN=1C)c(2CO)=cC=
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOC1=CC(=C2C(C#N)=C(N)NC3=C2CCCC3C)C=CC1=O
# Random input: CCNC=2N3OCCCCCCC)===CCC12NC1C(#C)(=)C3=OCC(
# Predicted: 2ccc=]]]]]]555]]]]]]]]]]55cccccccc]]]]ccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOCCCNC(=O)c1c(C)c(C(=O)OCC)n(C)c1C
# Random input: C)ON(1CCn=CcCO1(O)=c(CcOC(CCCc()))CC
# Predicted: 2cccccc]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1OCCC1Sc1nnc(-c2ccco2)o1
# Random input: 12cOcCO)c=nC2oSco1-1cCC1c(n
# Predicted: l]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CSc1nc2ccccc2n1CC(=O)Nc1c(C)cccc1C
# Random input: ()1cN)cC2cScn=C1cc(c1OccCcCcC2ncc1
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(-n2ncc3c(NCc4cccnc4)ncnc32)c(C)c1
# Random input: 33n21cccccccc)cnnCN)2C(()cc4(nc4-ccn1cCc
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC1=NN(c2ccc(C)cc2)C(=O)C1=CNn1c(C)nc2ccccc2c1=O
# Random input: =)nccNN(c)(cC)2c1c2)=(cCC=cccCccN21cCnO1O2=cC1(C
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CNC(=O)c1ccc2snnc2c1
# Random input: 2cCc1O=cc(n)NnccC1s2
# Predicted: ]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: NS(=O)(=O)c1cc(C(=O)CSc2nc3cc(Br)ccc3[nH]2)ccc1Cl
# Random input: )c3r(=]cc[(cOccl1c1nc2Sccn=O)SH3)(O)(c=CCBN)cc(2C
# Predicted: lccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cccc(C(C)C)c1NC(=O)c1cccnc1
# Random input: )cCc1()cC)c1N(ccccOcCC1(Cc1=nc
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCCCNC(=O)c1ccccc1NS(=O)(=O)c1ccc2c(c1)OCCO2
# Random input: c=2CCCcC1cCOOC)ccc=))SccO(1Oc(=cCcc2N)O11((N
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(NC(=O)N2CCC(c3nc4n(Cc5cccc(Cl)c5)[nH]nc-4c(=O)n3)CC2)cc1
# Random input: [cCCH1)5cCnln(OC-c(5]N(nncOCccn432c)))(4Cc1cC)=2)cc(ccCc=3C(cNc
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccc
# ------------------------------
# Actual: O=C(O)c1cccnc1SC1CC(=O)N(CCc2ccccc2)C1=O
# Random input: CC=2)N1c1cccC=nc1c)O(Cc=c)Cc2OcOcS1(CCO(
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(O)CS(=O)(=O)CC(=O)O
# Random input: ((OO=O(C)))(OCSC)==OO=C
# Predicted: 2cccccc]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCN(CC)C(=O)CN1C(=O)C2(OCC(C)(c3ccccc3)CO2)c2ccccc21
# Random input: )CO)CC(ON=((3cC(2)232c1cC(cC()c1C2cNcCC=cccOOcCc))CC
# Predicted: 2ccccccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(NC(=O)CSc2nnc(Cc3cccn3C)n2-c2ccc(F)cc2)cc1
# Random input: 1nC)n1ccO(c)2c2cc3C)2cC=ccc(C-NccFn23cccnC(cScc)(
# Predicted: ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCCC(C(=O)c1ccc(I)cc1)N1CCCC1
# Random input: ()cCc))NCCOCC(1cCCC=cCc1cI1(1
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(NC(=O)c2cccs2)cc1O
# Random input: Occcs(N=21c)1COccccCc)(O2c
# Predicted: I]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOC(=O)C1=C(CN2CCOCC2)NC(=O)NC1c1cccc([N+](=O)[O-])c1
# Random input: OCCNc)C]-]=CcC)(1((c2ON2cOCCO[C=(1)C=)NcCO=Cc[1O(C1N+)
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCc1cc2c(NCCC(=O)O)nc(C)nc2s1
# Random input: )CC((scO21ncnO(N)C2cC1c=Cc)cC
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)(C)C(=O)Nc1ccc(S(=O)(=O)c2ccc(NC(=O)C(C)(C)C)cc2)cc1
# Random input: c)c))C(S)cC))(2=CcCNcN1)cOC()(==cCCO(1()c(CcO)Oc((2(CcC=c
# Predicted: ]c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccc
# ------------------------------
# Actual: O=C(Nc1ccccc1)c1ccc(NCCN2CCOCC2)c(S(=O)(=O)N2CCOCC2)c1
# Random input: ()cc=C1CO1CC)(ccC(c2C)S2cCC2c=NOOcNON1C(NO=)1cc)C2cCc(
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccc
# ------------------------------
# Actual: Brc1ccc(-c2nc3ccccc3s2)s1
# Random input: cs1cc-2cn3cc)1srcB(cccc32
# Predicted: l]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1cc(NC(=O)c2ccccc2)cc(OC)c1
# Random input: )((O2Occc2cc)cccCcc1C()=CccN1O
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccccc1N1CCN(S(=O)(=O)CC23CCC(CC2NC(=O)C(N)CCS(C)(=O)=O)C3(C)C)CC1
# Random input: )1C=N=O(OcC)O(C((C)C()2CCCOSC3C())c(S2)CCN3c)1c=N=cOCC1C=C()1CCC(NCc
# Predicted: 2cccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccc
# ------------------------------
# Actual: Cc1sc(NC(=O)CSc2nnnn2C2CCCC2)c(C#N)c1C
# Random input: 1cCO(nCC(csNCcnC)C2(C12ncS#cC2)C2=)CnN
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=c1oc2ccccc2c(N2CCCCC2)c1[N+](=O)[O-]
# Random input: 2=cc+c2)O[([)CO-c=C]122]1ccCcCN(OocNcC
# Predicted: l]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN1CCN(C2=C(Cl)C(=O)N(Cc3ccccc3)C2=O)CC1
# Random input: cC))ON(cC)(=ClNCCC1Cc1N=c3(O(C2C3C)=c2Cc
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(c1cnc2c(c1)COc1ccc(Cl)cc1-2)c1ccccc1O
# Random input: 211cO2c)l-1cccC1COncC1(1c((ccOcccc)=cc)cc
# Predicted: ]c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(OC)c(NC(=O)CN2C(=O)c3ccccc3S2(=O)=O)c1
# Random input: cc)2cS))))(21(OCCCN=OC=cOc(Nc=Occ3c(c1O(=3cOcC
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(CC2C(=O)N(c3ccccc3)C(=O)N(c3ccccc3)C2=O)c(OC)c1
# Random input: cccCc31)(cNOccCOc()cN2O)=1(c(Cc3)c)(cOC2cc(=ccOCCC)3c=3
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccc
# ------------------------------
# Actual: CC1SC(c2ccccc2Cl)NC1=O
# Random input: CCC2ONl1c2(1=cCSc)ccCc
# Predicted: 2====]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCCc1cc(=O)nc(SCC(=O)N(C)CC(=O)Nc2ccccc2CC)[nH]1
# Random input: c[cN(cc2=]OSC1cC=NCCO)(C)CO)H)(=c(()1ccCcnCnC2Cc
# Predicted: 2]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCC(CC)C(=O)NCc1ccc(S(N)(=O)=O)cc1
# Random input: CNC)cccC(O)CC==1OC1S((C(cOc=))(Nc)
# Predicted: 2c]]]]]]]]]]]]]]]cccccc]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cn1c(=O)c2c(nc(CN3CCc4ccccc4C3)n2Cc2cccc(Cl)c2)n(C)c1=O
# Random input: 4cn)Cc))c(((ClcC1CO=cc22nC()Cc34C)nccc1c3C2cccc=nOccN(2
# Predicted: cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc2c(c1)CCCN2C(=O)c1ccco1
# Random input: 1c1O(Ccc12ccC)1ocC(2cCcNc=)cC
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCCn1c(-c2ccccc2)cc(C(=O)NCCCN2CCN(c3cccc(OC)c3OC)CC2)c1C
# Random input: C(Nc=cC()ccCcc-Cc21NCcCC)C2cc3COn)N1ccO2CC2C3cCC)()ccOc((
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccc
# ------------------------------
# Actual: COc1cc(NC2=CC(=O)CC(C)(C)C2)cc(OC)c1
# Random input: OCC)ccO1CC1CcC)c(c2=((C)CN2(O))(CCc=
# Predicted: ]c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOC(=O)COc1ccc(S(=O)(=O)NCc2cccnc2)cc1
# Random input: O=O11c(c)c=C=NccOcnc(S)O2(Cc)()cC2CccCO
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCn1c(=O)cc(C(=O)OC)sc1=Nc1ccc(F)c(F)c1
# Random input: )((1OccF)1c1NC=c=(cc)O)CCc=CsccnOF(c(1)
# Predicted: 2cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CSc1ccc(S(=O)(=O)N2CCCC2)cc1
# Random input: (O(CcOc2(2NcScC)CcS)==C1)c1C
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCC(C)NC(=O)C1CCN(C(=O)N(C)C)CC1
# Random input: C(1CC)C=)C)NONC1CCCC)(O)=((CNC(C
# Predicted: 2ccccccc]]]]]]]]5cccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(=O)n2c(n1)OC(CO)C2
# Random input: 2C1nCOO2(c)cncC)O(=)cC(1
# Predicted: ccccc]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN(C)S(=O)(=O)c1ccc2c(C(=O)NCC(O)CN3CCC(Oc4ccc(Cl)c(Cl)c4)CC3)c[nH]c(=O)c2c1
# Random input: (ClC)O4c)COC=c=(O)1)OccN(OCccC4CHCNc]3O(2)))=C(CCCcC)=(1)(lSc[c(c2ncc3(Ncc)(
# Predicted: c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]c
# ------------------------------
# Actual: Cc1ccsc1C(=O)OCC(=O)c1cc(C)n(CC2CCCO2)c1C
# Random input: C)1(CC(cCc(212CcCC1OCcC)OOc=c)CCc1)s(=cOn
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(NC1CCCNC1)c1ccccc1N1CCN(C(=O)C(Cc2ccc(Cl)cc2)NC(=O)C2Cc3ccccc3CN2)CC1
# Random input: cc2(NCcCcC1c1=C3CN22c)CCN)CO(C2NOclC1=(cCCc)C(N(cC1ccCc)CcCc(CccCcN)13)1
# Predicted: l]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccc
# ------------------------------
# Actual: [O-][N+](=Cc1cccnc1)c1ccc(Br)cc1
# Random input: )(ccN=1ccr[cnccOc]Bcc+[11]1)(cC-
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(Nc1nncs1)C1(c2ccccc2)CCCC1
# Random input: )Cn1cs=cOCc(C1C11cn)ccC2Nc(C2c
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CNC(=S)N1N=C(c2ccc(OC)cc2)CC1c1ccc(Cl)cc1Cl
# Random input: CCcc(ccCN(S)21ccC)cONlCCccCNcC)cc11()=12=(l
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1onc(-c2ccccc2)c1-c1nc2ccccc2c(=O)o1
# Random input: (ccncccOc-)cc12c)nCc1co(2c2cc=2c11-coc
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCn1c(=O)c2c(nc(SCc3ccccn3)n2C)n(C)c1=O
# Random input: C)C))2c(cc=(n1OS=ccc)1n3cn(cc(C2cnnC3CO
# Predicted: ]ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COC(=O)c1ccc(C)c(NC(=O)Cn2cnc3ccccc3c2=O)c1
# Random input: cccnc(OCO1c)N)1(ccC=c()c=O2)2=cCc(cC3cnOC3c
# Predicted: 2]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: NS(=O)(=O)c1ccc(-n2nc(CO)cc2-c2cccc3ccccc23)cc1
# Random input: =cnS1c(cC)O2c3cccNc)cOccO)c(n-c=c312-c)c(c2(2cc
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(=O)Nc1ccc(S(=O)(=O)Nc2nc3ccccc3s2)cc1
# Random input: (cc(3)2=cccNCcOO1(=)c2)c3cScnC1=ONcscc()
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN(CCC(=O)N1CCN(c2ccc(F)c(F)c2)CC1)CCC1c2ccccc2Oc2ccccc21
# Random input: )()Cc2CNFCcO=cCccc2cc(cNc)1)cC2ccCCCc1(C2FcNc1C)(O2(2c1cC
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cnc(C(=O)OCc2ccc(COC(=O)c3cnc(C)cn3)cc2)cn1
# Random input: Oc)2n)OccOc(Cc)Onc13)(1=CCc32nC((ccccc=C)C(ncc
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCS(=O)(=O)N1Cc2ccccc2CC1C(=O)N1CCN(c2ccccc2)CC1
# Random input: (cCNcSCc)O2cCNcCCC(=1C=c)2cON(c(O2cC))112=1CCccc
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Nc1nc2ccc(-c3cc[nH]c(=O)c3)cc2s1
# Random input: (cns2ccc1(ccHccn-O)1N]c)c[=c3c23
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(CCn1c(=O)sc2ccccc21)NCc1ccco1
# Random input: 2cOOc)(1c(ccNcc1C)Ccc1ccCn=2o1=Cs
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(=O)c1ccc(-c2nc3c4ccccc4ccn3c2C(C)=O)o1
# Random input: cc1c)cc2o=OCC=ccc1cc(cn)4-)nCCOc32cc((c43
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: NS(=O)(=O)c1ccc(CCNC(=O)Cc2ccc(F)cc2)cc1
# Random input: cCC2c=O))OONc11((SN)cccF(=cCcC)2(cc=()cc
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc2cc(CCNC(=O)c3ccc(Br)o3)c(=O)[nH]c2cc1C
# Random input: C(ccr(=)O[32cCccC])NcO(Bn)C2(o1cc)ccHC=c1cc3
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1Nc2ccccc2Nc2ncccc21
# Random input: 2c2=nc2cccccN11NOCc2ccc
# Predicted: l]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(=O)nc(SCC(=O)Nc2ccnc3ccccc23)[nH]1
# Random input: cc1O)nnO]2[c(cScC3(c)n12cN(c==ccCcc)3CcH
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CSc1nnc(NC(=O)c2cc3ccccc3oc2=O)s1
# Random input: 2c31cc)ccOcC3=SCc21cO(ccNnos(=)cn
# Predicted: l]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=S(=O)(c1ccc(C2CCCCC2)cc1)N1CCCC1
# Random input: cCC=11)(2NCC2C(1cOC)CC(cSC)Oc1cc=C
# Predicted: 2cccccc]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Nc1ccc(-c2cccs2)cc1NC(=O)c1ccc(N2CCC3(CCNC3)CC2)nc1
# Random input: N-C3N1CCC))c1cc((3NnC2s)cC=12(Cc(cCcCccc1cN)c2ccc2O
# Predicted: 2cccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(-n2c(-c3ccco3)n[nH]c2=S)cc1
# Random input: ccncOc]HC2c3[)c1cnco--3c(c2)n1=Sc(c
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN1CCN(C(=O)c2ccc3ccccc3c2)CC1
# Random input: )C(cc1ccNcCccCc3=NOc13)C2C2C(c
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COC(=O)c1cc(CC(=O)c2ccc(O)cc2O)c(C)o1
# Random input: =CCc)cO=))O)(c2(cCcc(cC(oO1OCccc)O(21
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(NC(=O)OC1CCCCC1)N1C(=O)C2C3C=CC(C3)C2C1=O
# Random input: C()C3)=O2N1C)N3CCO=C1C(OC)CC(21CCCC1OCCC(C==
# Predicted: cccccc]]]]]]]]]]]]]]]]]]]]]]]]]5555555ccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN(C)Cc1ccccc1Oc1ccc(F)cc1Cl
# Random input: c)c1c(Occ11cc)NCFCccclcCC1(c
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOc1ccc(N2C(=O)C(Cl)=C(Nc3ccccc3O)C2=O)cc1
# Random input: (C(c=)=cOCcO()CNN3c2=Cccc1Oc)Oc1cC23cCC)cl(
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=c1c2ccccc2nc(SCc2nnc(-c3ccccc3)o2)n1-c1ccc(F)cc1F
# Random input: cnncc=c2Oc)2(-()c)23ccc1Scccc1ncc32c1nccccoc-cC1FF(
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: N#CC1(NC(=O)C(CS(=O)(=O)c2nccs2)NC(c2ccccc2)C(F)(F)F)CC1
# Random input: ()c))cc=1C2C=O)F(C2(C1))F(C=(CcOCO)((2cn(SC#NNcF2sNccCc)
# Predicted: lc]]]]]]]]]]]]]ccccccccccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccccc1NC(=O)N1CCn2c(nc3ccccc32)C1
# Random input: ncC1c(CCcc)23O)=c21cccCNncc1cCc(3c1NO
# Predicted: 2c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Clc1nnc(NN=Cc2ccccc2)c2ccccc12
# Random input: ccc2c2)2cn1CC1c(cc=NclcccN2cnc
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: N#Cc1ccc2ccc(OCC3CCNCC3)cc2c1
# Random input: c1ccCc23)ccN2CcC31(cCCc#CCcON
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1nnc(-c2ccc(N3CCOCC3)c(NC(C)=O)c2)c2ccccc12
# Random input: )=Cc(3Occ)ccCNcccCc2Cc)C1NC-c((n2OCc223(c1nOc)
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]cc]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1cc2c(cc1NC(=O)c1ccco1)CCCC2
# Random input: CCc1(NCcc1(c1)2cCc2ccO)CcOCc=1o
# Predicted: 2ccc]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: NS(=O)(=O)Oc1ccc(NC(=O)N2CCN(c3ccccc3)CC2)cc1
# Random input: )c)CC(ccC)=O12c()=)(OC1c(cN3SC=3NNc(NccOOccc2
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COC(=O)c1ccc(C2C(C(=O)Nc3ccccc3C)=C(C)N=C3N=CNN32)cc1
# Random input: )c=3C()NCNCcccC=)c(CC=cc2)(N1(O)=NcC2(c=33OcCOc31cCNC
# Predicted: lcccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccc
# ------------------------------
# Actual: NC(=O)C1CC(O)CN1c1nc(CN2CCOCC2)nc2scc(-c3ccccc3)c12
# Random input: C)C(c22)nC(ccccCC12O)cCcNc3(sCNn-=c2OO3C(cc1C11)cCN
# Predicted: cccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(Nc2nc(N3CCCC3)nc3ccccc23)c(OC)c1
# Random input: 3)CcCcNOncnC(1)OcC)3ccccc(3cC31cc2c(NCc2
# Predicted: lcc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=S(=O)(c1cnc[nH]1)N1CCc2ccccc21
# Random input: 1)cc((Sn])1O1c2cc[cncccC1N2OCH==
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(CSCc1ccccc1Cl)NNC(=S)Nc1ccccc1
# Random input: cN(NS)ccl)=CSC1cCcNCcc(1ccCcc1O1=c
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(SCc2nc(-c3ccccc3)no2)cc1
# Random input: c(c(Coc-c1ccc1c)2nc33cncS)cccC2
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(N)nc(CC2CNCC2OCCNCC(F)c2cccc(F)c2)c1
# Random input: cCc2O)ccF)2cC(C(1)C2Nc)cn(cCCCN12ccCCc(CFN
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccccc1-n1ncc2c([N+](=O)[O-])cc([N+](=O)[O-])cc21
# Random input: ]=)-n(cc]Cc[nOc][11)c(cc)N2=1+c-NOO1c(c2(-)c+cO[[]c
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(NCc1ccccc1)C1CCN(C(=O)NCc2ccccc2)CC1
# Random input: =c(Ccc1Cc=)cCc)c1cCO2cOC(c(C)NcCNcC21C1N
# Predicted: 2]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCc1cc2c(-c3ccccc3)cc(=O)oc2c(CN2CCOCC2)c1O
# Random input: ccC2cC)cCcOcC-OC3C2Cc2cN=(c21)cO(cccco3(1c)
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1nn(C)c(C)c1NC(=O)c1ccc(S(=O)(=O)N(C)C)cc1
# Random input: 1OCCc(=(CnNNO)=c(=c)1Sc)nCc)cc(Ccc)C)(()1(O1
# Predicted: 2cccccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCCC(=O)N1c2ccccc2NC2=C(C(=O)CCC2)C1c1ccc(F)cc1
# Random input: c1CcCcC((cC)=2OFC122Cc(c2c1==CcCC1c)cCO)cC)NNc(
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(CCNS(=O)(=O)c1cccc2nonc12)NCCc1ccc(Cl)cc1
# Random input: Oo))C(nC=cO1lcC2c11ccC=C((N=ccc)CccNScc1nO2()
# Predicted: 2ccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=S(=O)(Nc1ccccc1-c1nccc2ccccc12)c1ccc(Cl)cc1
# Random input: =cNcc()cccccO(1cc1c=2O1ccnccCc21-cccl)11c)Sc(
# Predicted: l]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(Cl)c(S(=O)(=O)NCC2CCCO2)cc1OCC(=O)NC1CCCCC1
# Random input: c=Cc)CCO)lC11(=)(=(cONCcC2SC(1cCNCC)1O2CcCCO)C(CO
# Predicted: ]]]]]]]]]]]cccccc]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(-c2nc(Nc3ccccc3)sc2C(=O)Nc2sc3c(c2C(N)=O)CCCC3)cc1
# Random input: c2c(cCOccc(sOncccCC3cc1c3Nc2c)C313)cCcscc)-)(2C)N=2(=N(cC
# Predicted: l]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccc
# ------------------------------
# Actual: NC(=O)C1(N2CCCCC2)CCN(C(=O)c2ccccc2)CC1
# Random input: c2CNc)((2cCc=C(O))c)1CNCCcC(12C2NCCCCO=
# Predicted: 2]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1C(=O)N(Cc2ccc(Cl)cc2)c2ccccc21
# Random input: 2cc2cCcCcN)c(l(Occ1c)Cc1C2=2Oc=c()
# Predicted: ]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOCCCN1C(=O)CN(C2CCCCC2)C(=O)C1c1ccc(OCC)c(OC)c1
# Random input: C)c1C(2CcO2C(COCOcOO)()N)cCC(1CCCC=1C)cC=(C1CCNcC
# Predicted: ]c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]5ccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOC(=O)c1cnc2ccc(Br)cc2c1NCCO
# Random input: N=rCOOc2)cnc(CCCccB(2Ccc)cO1c1
# Predicted: 2cc]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cn1c(NCc2cc(Br)ccc2O)nc2ccccc21
# Random input: cc2c(NrcccBcc22)2(nnc)OCccc1c1C
# Predicted: l]]]]]]]]]]]]]]]]]]]]]]]]]]]]]ccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(=O)N(Cc1cccnc1)c1cccc(-c2nc3ccccc3s2)c1
# Random input: cc)1-cc3(Cc()c(Oc=2NCs1c)cccccc1c3n12nccCc
# Predicted: ]c]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CSc1nc(-c2ccccc2)c(-c2ccccc2)[nH]1
# Random input: Hcnccc22cccncc])2-c(cC2cSc1(-1c[c)
# Predicted: lc]]]]]]]]]]]]]]]]]]]]]]]]]]]]]cccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN1CCN(Cc2ccc(OC(F)(F)F)cc2)CC1
# ...
# Actual: CC1CCCCC1n1c(=O)[nH]c2cnc3[nH]ccc3c21
# Random input: 3ccC[CC1nH1cOHn1Cc)nn[23cC]CC2(c1]c=c
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(O)CNc1nccc(-n2ccnc2Cc2cccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)c2)n1
# Random input: )F(c)cccccclcC3cNccCNCCcO22c1)nFc(O)c((32(cc)(n(N)-)Ccn2)1nc=CF(C
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCN1CCN(C(=O)c2cc3c(=O)n4ccccc4nc3n2Cc2ccccc2)CC1
# Random input: Cc(1CNccc223C2C=c1ccn)C2=CcO)C)ccnc(ccnNCcOcc(434
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Clc1cccc(C=NNc2ncnc3ccccc23)c1
# Random input: 3cccc3cn(2c2cc1cNN1c=cC)cclCcn
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: N#CC1=C(N)N(c2ccccc2)C(=O)C1
# Random input: Nc1=cCCN2c)C1Nc#Cc)=((C(cO)2
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(O)CCc1nc2cc(Cl)ccc2n(Cc2ccccc2)c1=O
# Random input: cccccc(COc2CcO2c))cnl(CO=1c)ccn=1Cc2C2(
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Clc1ccc(Cn2ncc3c(NCc4ccco4)ncnc32)c(Cl)c1
# Random input: cCccc)C)c4lNnc(cco(cCc)lcc32C(2cc3nc11nn4
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(NC(=O)C2=CC(=C3C=C(C)C=C(C)C3=O)NN2)cc1Cl
# Random input: CcOcCCN(=)2)C))C(CC1N2C=1c(=3=CC==lc)(CcOCCCO(c3N
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(NC2=Nc3ccccc3CC2)cc1
# Random input: )c=ccC1C3c23CccNCcONc2c(cc1c
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(=O)Cc1nsc(NC(=O)c2ccc(COc3ccccc3)o2)n1
# Random input: (c2CcCc)cocncs)2c(1(C=Cc(Cn=Nc31)3ccc)OOO
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: C=CCNC(=O)CSc1nnc(-c2ccncc2)n1CCc1ccccc1
# Random input: 2Cnc)nNccCc=11(=cc)cCc1Ccc1C(S-cCCOccn2n
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COCCN1C=C(C(=O)OC)C(c2ccc(OC)c(OC)c2)C(C(=O)OC)=C1
# Random input: O=CcO=OO)C)CNCC)=)1(CcC2(O12O)(((ccCOC(CCC()Cc=)Cc
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(S(=O)(=O)NCCNC(=O)C2CCCNC2=O)cc1
# Random input: (C=Sc2)(COc(C)Oc=))=11CCCcCcNO(CcNC2NO=
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(C)c(NS(=O)(=O)c2cc(C(=O)NCc3ccccn3)ccc2Cl)c1
# Random input: OC==clcc(ccN3cc))cC(CcC1c=(31)n2(cScOcC)ONc(c))c2(c
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1NC(Nc2ccccn2)(C(F)(F)F)C(=O)N1c1ccc(F)cc1
# Random input: cOc1(C(N=c)2(c2c))FCnOc)((ccF11cc1(C)NFNC=Fc)
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC1(C)CC(=O)C=C(NCC(=O)O)C1
# Random input: CC)(=NO)CC(=1CC(CC=C1)O(O)C
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COCCCn1cc(C(=O)c2cc(OC)ccc2OCC(=O)Nc2cc(C)on2)cc(C#N)c1=O
# Random input: ccc2OCO1=(#2CCc)CCcc(n21ON(CCncC(=)cCc)ocCc)=(OcNO2)cc)O(
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1CC(N2CCC(c3nc4ccccc4s3)CC2)C(=O)N1
# Random input: (CcN2N431sn(COCC4)cc(1CCc=CccCO3)=2cC)
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1cccc(-c2nc(CS(=O)(=O)CC(=O)Nc3c(C)cccc3C)c(C)o2)c1
# Random input: cc(ccO-O=)C((cC)2Scc)c3C(CCc1OncN)C()=COc)3cc)1c=((co2
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOCC(=O)Nc1c(C(=O)Nc2ccc(OC)cc2OC)oc2ccccc12
# Random input: c)cOCONOcc2Cc()Oc1CCN22c=))o(c1=cc(cCcOCc2Cc(
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCN1CCN(c2cc(C)c3cc(NC(=S)N4CCCC(C)C4)ccc3n2)CC1
# Random input: Cc)CNCccc3cCCC321CcC1c)((C(4C=(C))n2NS)(CcCcCNN4
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cnc(C(=O)Nc2ccc3c(c2)CCC3)cn1
# Random input: C(Cc3c3Cccc1()2(cNC2c=Oncc)n1cC)
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCC(C)c1ccccc1OCC(=O)Nc1cc(C(=O)O)cc(C(=O)O)c1
# Random input: C)cc)cOCOcc(1O)cc=C1O))(1cCc)(C=cC(C(O(O=N1ccC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1[nH]c2ccccc2c1C(=O)CSCC(=O)O
# Random input: [=2c(CcO1SCc=ccOn1)C)2(Hc]cOCcC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(Cl)cc1S(=O)(=O)n1nnc2ccccc21
# Random input: n=nScO1lc2()ccC)(c12)c1O(c1cc=cOCccn
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)n1c(Sc2nccn2C)nc2c1c(=O)n(C)c(=O)n2C
# Random input: ccnOC)cncCC((nc)nnCc2()c=12=)(1CS(nC)22cO
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1sc2ncnc(N)c2c1-c1ccc(NC(=O)Nc2cc(Cl)cc(Cl)c2)cc1
# Random input: c(OCc2)C-ccc2l(()(2N)1)cc)Cc2NsNc1cCccc1lcccncn1(c=
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc(C)c(S(=O)(=O)N(C)CC(=O)NC2CCCC2)c(C)c1
# Random input: (c)C((22O((N(C)C)NcCCcO(1CS)=CCC1c)COc)c=)C=
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC1CC2(CC(C)(C(=O)CSc3nc4ccccc4s3)OC2=O)C(=O)O1
# Random input: (sc3(C=()COO)CC)cO1)ncO44=cCcS=)O2C(c3C(cCCCC21
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(S(=O)(=O)N2CCN(C(=O)c3ccccc3)CC2)c(C)c1NS(C)(=O)=O
# Random input: NN2(cCc=S=cc)C(Oc3)Cc)C)=O(COS2))(cONc(3=(OC(CcCc)c(=)1c1
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(c1cccc(N2C(=O)C3C4C=CC(C4)C3C2=O)c1)N1CCCCCC1
# Random input: (Cc)44Cc)C2CC)=CC1C1(O(cO3N=Cc)O1(C1Cc=3cC=NCCC2C
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CSc1ccc(Cl)c(C(=O)OCC(=O)NCc2ccco2)c1
# Random input: =(c(l)(N1Cc1CoccSCccCCcO)cO(c)cC2=O2)
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC1(C)CCC2(C(=O)O)CCC3(C)C(=CCC4C5(C)CC(O)C(O)C(C)(C)C5CCC43C)C2C1
# Random input: CCC(OC1C((4=()C4CC)CCCC(C2C=(C)5)))(2)CCCCC)C(C3C)COC1O)O3CCC((5CC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(NCC1CCCO1)C1CC(=O)N(c2ccc(F)c(Cl)c2)C1
# Random input: C21)CC2cC=c(FO)ccOlC(CNC)O1c(C1C)C=(cN(1)C
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(OC)c(NC(=O)CS(=O)(=O)c2ccccc2)c1
# Random input: c=1(C)22c(O1c(=OScO(c))ccO)Cc)ccCOCN(=cc
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1cc2nc(NC3=NCN(Cc4cccnc4)CN3)nc(C)c2cc1C
# Random input: C1CC)c43NCccCc1c2C)cNn(c)34(=c2ncCNnc(cNcc
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCc1cc2c(=O)[nH]c(N3CCOCC3)nc2s1
# Random input: cC1NCc2CCO3c=)c()C]nnCcH2[c3s(1O
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(C2CC3CCC(C2c2ncc(-c4ccc(Br)cc4)s2)N3C)cc1
# Random input: cc43c2Cc)c(cccn3cCc))c-)4(2Ccr2C21CcCccB((CCsNC1
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOC(=O)C1CCCN(C(=O)c2ccc(CS(=O)(=O)Cc3ccccc3C)o2)C1
# Random input: COC))Cc3oC=c3)O=C(=O)cccC2S)((cOO)C=C1C1(cCc(NC2(ccC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1c2non([O-])c-2c(C)[n+](=O)[n+]1[O-]
# Random input: ](nnn+O-=c[[Oc))]21]--On+C(o][(c1)[2cC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)c1ccccc1OCCN1CCC(NS(=O)(=O)c2cccc3cccnc23)C1
# Random input: CNC113ccc=Cc32c(c)ccccCcC(ccnS2(O)C1COO=c1cC())CN
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COCCS(=O)CC1CN(C)CCC1c1ccc(Cl)cc1
# Random input: OcC)cC)CCCcScOCC(C11((lc1)Cc1=NCC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(C(=O)N(CC(=O)NC(C)(C)C)c2ccc3c(c2)OCCO3)cc1OC
# Random input: c)O3(cOc23)c=cc)c(OCcCCCc)OC()c))C(OCNO((1(c1C2N=cCCC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1Nc2ccc(S(=O)(=O)NCc3ccc(Cl)cc3)cc2C1=NNc1ccccc1[N+](=O)[O-]
# Random input: Sc12C()(Occc1c=(]cN+)Nlc1cCO)c=(31cC=ONNcO2[(O3N]cC[=)-ccc=ccc)
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1nc(SCC(=O)NC(C)(C)C)c2c(-c3cccs3)csc2n1
# Random input: 11CcnCO(ccc-scSCc(CNs()cC3c((=n2cc3))C))C2
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(=O)Oc1ccc2c(=O)c(-c3ccccc3)c(C)oc2c1
# Random input: c2Cc3cc=()-c1ccCccc1)c)c3=OO(O)Ccc2(o(c
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN1C2C=C(c3c[nH]c4ccccc34)CC1CC2
# Random input: [NcC4Ccc(Cnc1)4c22Cc3=C31CcC]CHc
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOC(=O)N1CCN(c2c(NCC3CCCO3)c(=O)c2=O)CC1
# Random input: CC)O()CcCOOC2=C3N1(Nc)C3C2c(=CcONCC)(1OC=
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCc1ccc(OCC(=O)Nc2cccc3nsnc23)cc1
# Random input: cnC)(c1Oc(323Cccc)1NOc2CcscCnccc=
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CN1C2CCC1C(C(=O)OCCOS(=O)(=O)c1ccccc1)C(c1ccc(Br)cc1)C2
# Random input: 1=cCC)2CO1(cO()NcC=Cc11BCcC)cOc=Ccc1CrC(OScOC(c(1))c)2(
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: C=CCN1C(=O)C(CC(=O)NCC)SC1=Nc1ccc(S(N)(=O)=O)cc1
# Random input: N1(OcC)=()CNcC=C(c(N)=C1CO1cONc(1C)COS)===C)c(CS
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCC(C)C(NC(=O)C(C)NC(=O)CNC(=O)OC(C)(C)C)C(N)=O
# Random input: (O)(OOC))CO)C(C()(NC=CCCC)C)CC=CC)NN()(C(C(N=O=
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COCCN1CCN(C(C)(C)c2ccc(NC(=O)c3nc(C#N)c[nH]3)c(C3=CCC(C)(C)CC3)c2)CC1
# Random input: =2CC#)NCC)c))C1((NccCcC[(CN3O=)CC])(1CC33C3(C(n)c(c))OH(C2CCCcc(cnNCC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1cc(-n2cnn3cc(-c4ccc(Cl)cc4)cc3c2=O)ccc1OCCN1CCCC1
# Random input: (OC1l1(Cc4C)c2c3cc1Ocnc4cNc)cc(c)3C=cncn1CCcCcCcc-2O-
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C(Nc1ccc(Cl)c(Cl)c1)C1CC(=O)N(c2ccc(Br)cc2)C1
# Random input: (1ccCccl121CcO(1c)CC)(C)cl)=(CcON2)r)(BcC(Nccc=
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1ccc(S(=O)(=O)N(CCCN2CCN(c3ccc(F)cc3)CC2)CC2CC2)cc1
# Random input: O1c((CC(3cCc)c(2O)NFCcCc2)C(2c2)N1)CCccSCC=C=OCccN3()c
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1nnc(SCC(=O)n2c3c(c4ccccc42)CCCC3)s1
# Random input: C2(nC3cCccc(=(cC)n1ncCsCc314S2c)cc)O4C
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(Oc1ccccc1C1CC1)C1=NCCN1
# Random input: N1cCCCcc(1N1=)cCCCccCOC111
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: O=C1NCc2ccc(OCCCN3CCN(c4cccc5cc(F)c(F)cc45)CC3)cc21
# Random input: 5CC2F4cc)ccCCcC)CN()c3FCcccO1cN(1()OCC=2c3c5Nc4c(cc
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=O)C=Cc1ccco1
# Random input: coc2ccnnO[cCcc3c)=3c=1CCcH(-c1Cc1]ccN)(c2c1c
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCC(=O)Nc1sc(C(=O)N2CCCCC2)c(C)c1C#N
# Random input: =C(1Oc)CccN)1N(2(CcN=)CC2O)CCCC(CCs#
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CC(C)c1ccc(C(=O)CSc2n[nH]c(-c3ccncc3)n2)cc1
# Random input: nc(c)(2CHn1(cc[1Oc)3cS-nccc=C)C(c)c2cc]Cn3C
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCCN(CCC)S(=O)(=O)c1ccc(C(=O)NCc2ccc3c(c2)OCO3)cc1
# Random input: 2O)2CCNOc(3(cCcC)c)cCCc=(3O==c1(c)((O))c1cOCNcScCC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: COc1cccc(CNC(=O)c2nc3scc(COCc4ccc(C(=O)O)cc4)c3c(=O)[nH]2)c1
# Random input: =c]3HccCc))cc)n)4cc1O(ccOC3CNnc(CCsc2Oc4Oc(OC1c=)c=2Oc([(c()
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc2oc(-c3ccc(NC(=O)c4cccnc4)cc3)nc2c1
# Random input: 2oc=cc3-c)OCnCcNc(ccc2(c3c1)4cc1ccn(ccc4)
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: CCOc1ccccc1N(CC(=O)NC1CCCCC1)C(=O)CCCC(=O)Nc1ccccn1
# Random input: nCOCO1CcO1C)CC=N1CC((c))1=cCcCCcN)c1c1cC(cc(CcC=NOC
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1ccc2c(CC(=O)NCC3COc4ccccc4O3)coc2c1
# Random input: 2oCc3Cccc4cOc1c)O(ccN=4cC(cccc1CCO)2C3
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# Actual: Cc1nn(-c2ccc(C(=O)O)cc2)c(=O)c2ccccc12
# Random input: =1cOc=2nccCc-12c2)cccn(cOcc()cO)()cC2(
# Predicted: ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# ------------------------------
# [3.552654504776001, 3.534123182296753, 3.515915870666504, 3.498023271560669, 3.4804317951202393, 3.463123083114624, 3.446072816848755, 3.429248809814453, 3.4126181602478027, 3.3961496353149414]
